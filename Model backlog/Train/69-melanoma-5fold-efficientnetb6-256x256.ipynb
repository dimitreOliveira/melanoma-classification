# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
import warnings, json, re, glob, math
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
import efficientnet.tfkeras as efn
# from classification_models.tfkeras import Classifiers
import tensorflow_addons as tfa

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %% [markdown]
# # Model parameters

# %%
config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 128,
  "EPOCHS": 15,
  "LEARNING_RATE": 3e-4,
  "ES_PATIENCE": 5,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 5,
  "TTA_STEPS": 25,
  "BASE_MODEL": 'EfficientNetB6',
  "BASE_MODEL_WEIGHTS": 'noisy-student',
  "DATASET_PATH": 'melanoma-256x256'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'HEIGHT': 256,
#  'WIDTH': 256,
#  'CHANNELS': 3,
#  'BATCH_SIZE': 128,
#  'EPOCHS': 15,
#  'LEARNING_RATE': 0.0003,
#  'ES_PATIENCE': 5,
#  'N_FOLDS': 5,
#  'N_USED_FOLDS': 5,
#  'TTA_STEPS': 25,
#  'BASE_MODEL': 'EfficientNetB6',
#  'BASE_MODEL_WEIGHTS': 'noisy-student',
#  'DATASET_PATH': 'melanoma-256x256'}

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/siim-isic-melanoma-classification/'
k_fold = pd.read_csv(database_base_path + 'train.csv')
test = pd.read_csv(database_base_path + 'test.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())
print(f'Test samples: {len(test)}')
display(test.head())

GCS_PATH = KaggleDatasets().get_gcs_path(config['DATASET_PATH'])
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0
# Test samples: 10982
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Augmentations

# %%
def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotation = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_pixel = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_cutout = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    if p_spatial >= .2:
      if p_spatial >= .6: # Flips
        image['input_image'] = data_augment_spatial(image['input_image'])
      else: # Rotate
        image['input_image'] = data_augment_rotate(image['input_image'])

    if p_crop >= .6: # Crops
      image['input_image'] = data_augment_crop(image['input_image'])

    if p_spatial2 >= .5: 
      if p_spatial2 >= .75: # Shift
        image['input_image'] = data_augment_shift(image['input_image'])
      else: # Shear
        image['input_image'] = data_augment_shear(image['input_image'])
        
    if p_pixel >= .6: # Pixel-level transforms
      if p_pixel >= .9:
        image['input_image'] = data_augment_hue(image['input_image'])
      elif p_pixel >= .8:
        image['input_image'] = data_augment_saturation(image['input_image'])
      elif p_pixel >= .7:
        image['input_image'] = data_augment_contrast(image['input_image'])
      else:
        image['input_image'] = data_augment_brightness(image['input_image'])

    if p_rotation >= .5: # Rotation
      image['input_image'] = data_augment_rotation(image['input_image'])
    
    if p_cutout >= .5: # Cutout
      image['input_image'] = data_augment_cutout(image['input_image'])
    
    return image, label

def data_augment_tta(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotation = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    if p_spatial >= .2:
      if p_spatial >= .6: # Flips
        image['input_image'] = data_augment_spatial(image['input_image'])
      else: # Rotate
        image['input_image'] = data_augment_rotate(image['input_image'])

    if p_crop >= .6: # Crops
      image['input_image'] = data_augment_crop(image['input_image'])

    if p_spatial2 >= .5: 
      if p_spatial2 >= .75: # Shift
        image['input_image'] = data_augment_shift(image['input_image'])
      else: # Shear
        image['input_image'] = data_augment_shear(image['input_image'])

    if p_rotation >= .5: # Rotation
      image['input_image'] = data_augment_rotation(image['input_image'])
    
    return image, label


def data_augment_rotation(image, max_angle=45.):
    image = transform_rotation(image, config['HEIGHT'], max_angle)
    return image

def data_augment_shift(image, h_shift=50., w_shift=50.):
    image = transform_shift(image, config['HEIGHT'], h_shift, w_shift)
    return image

def data_augment_shear(image, shear=25.):
    image = transform_shear(image, config['HEIGHT'], shear)
    return image

def data_augment_hue(image, max_delta=.02):
    image = tf.image.random_hue(image, max_delta)
    return image

def data_augment_saturation(image, lower=.8, upper=1.2):
    image = tf.image.random_saturation(image, lower, upper)
    return image

def data_augment_contrast(image, lower=.8, upper=1.2):
    image = tf.image.random_contrast(image, lower, upper)
    return image

def data_augment_brightness(image, max_delta=.1):
    image = tf.image.random_brightness(image, max_delta)
    return image

def data_augment_spatial(image):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)    
    if p_spatial > .75:
        image = tf.image.transpose(image)

    return image

def data_augment_rotate(image):
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_rotate > .66:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .33:
        image = tf.image.rot90(image, k=2) # rotate 180º
    else:
        image = tf.image.rot90(image, k=1) # rotate 90º

    return image

def data_augment_crop(image):
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_crop > .8:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.7), int(config['WIDTH']*.7), config['CHANNELS']])
    elif p_crop > .6:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']])
    elif p_crop > .4:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']])
    elif p_crop > .2:
        image = tf.image.central_crop(image, central_fraction=.8)
    else:
        image = tf.image.central_crop(image, central_fraction=.7)
    
    image = tf.image.resize(image, size=[config['HEIGHT'], config['WIDTH']])

    return image

def data_augment_cutout(image, min_mask_size=(int(config['HEIGHT'] * .05), int(config['HEIGHT'] * .05)), 
                        max_mask_size=(int(config['HEIGHT'] * .25), int(config['HEIGHT'] * .25))):
    p_cutout = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_cutout > .9: # 3 cut outs
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=3)
    elif p_cutout > .75: # 2 cut outs
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=2)
    else: # 1 cut out
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=1)

    return image

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)

def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Test function
def read_unlabeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_tabular': data}, image_name # returns a dataset of (image, data, image_name)

def load_dataset_test(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_unlabeled_tfrecord, num_parallel_calls=buffer_size)
    # returns a dataset of (image, data, label, image_name) pairs if labeled=True or (image, data, image_name) pairs if labeled=False
    return dataset

def get_test_dataset(filenames, batch_size=32, buffer_size=-1, tta=False):
    dataset = load_dataset_test(filenames, buffer_size=buffer_size)
    if tta:
      dataset = dataset.map(data_augment_tta, num_parallel_calls=AUTO)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %% [markdown]
# ## Learning rate scheduler

# %%
lr_min = 1e-6
# lr_start = 5e-6
lr_max = config['LEARNING_RATE']
steps_per_epoch = 24519 // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * steps_per_epoch
warmup_steps = steps_per_epoch * 5
# hold_max_steps = 0
# step_decay = .8
# step_size = steps_per_epoch * 1

# rng = [i for i in range(0, total_steps, 32)]
# y = [step_schedule_with_warmup(tf.cast(x, tf.float32), step_size=step_size, 
#                                warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
#                                lr_start=lr_start, lr_max=lr_max, step_decay=step_decay) for x in rng]

# sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20, 6))
# plt.plot(rng, y)
# print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))

# %% [markdown]
# # Model

# %%
# Initial bias
pos = len(k_fold[k_fold['target'] == 1])
neg = len(k_fold[k_fold['target'] == 0])
initial_bias = np.log([pos/neg])
print('Bias')
print(pos)
print(neg)
print(initial_bias)

# class weights
total = len(k_fold)
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print('Class weight')
print(class_weight)
# Out:
# Bias
# 584
# 32542
# [-4.02038586]
# Class weight
# {0: 0.5089730194825148, 1: 28.36130136986301}

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB6(weights=config['BASE_MODEL_WEIGHTS'], 
                                    include_top=False)
    
    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    
    output = L.Dense(1, activation='sigmoid', name='output', 
                     bias_initializer=tf.keras.initializers.Constant(initial_bias))(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
# Evaluation
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(TRAINING_FILENAMES)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)
# Resample dataframe
k_fold = k_fold[k_fold['image_name'].isin(image_names)]

# Test
NUM_TEST_IMAGES = len(test)
test_preds = np.zeros((NUM_TEST_IMAGES, 1))
test_preds_last = np.zeros((NUM_TEST_IMAGES, 1))

test_dataset = get_test_dataset(TEST_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO, tta=True)
image_names_test = next(iter(test_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TEST_IMAGES))).numpy().astype('U')
test_image_data = test_dataset.map(lambda data, image_name: data)


history_list = []
k_fold_best = k_fold.copy()
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)

for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    if n_fold < config['N_USED_FOLDS']:
        n_fold +=1
        print('\nFOLD: %d' % (n_fold))
        tf.tpu.experimental.initialize_tpu_system(tpu)
        K.clear_session()

        ### Data
        train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
        valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
        steps_per_epoch  = count_data_items(train_filenames) // config['BATCH_SIZE']

        # Train model
        model_path = f'model_fold_{n_fold}.h5'

        es = EarlyStopping(monitor='val_auc', mode='max', patience=config['ES_PATIENCE'], 
                           restore_best_weights=False, verbose=1)
        checkpoint = ModelCheckpoint(model_path, monitor='val_auc', mode='max', 
                                     save_best_only=True, save_weights_only=True)

        with strategy.scope():
            model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))

            optimizer = tfa.optimizers.RectifiedAdam(lr=lr_max,
                                                     total_steps=total_steps,
                                                     warmup_proportion=(warmup_steps / total_steps),
                                                     min_lr=lr_min)
            model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                          metrics=[metrics.AUC()])

        history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                                   batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            epochs=config['EPOCHS'], 
                            steps_per_epoch=steps_per_epoch,
                            callbacks=[checkpoint, es],
#                             class_weight=class_weight, 
                            verbose=2).history

        # save last epoch weights
        model.save_weights('last_' + model_path)

        history_list.append(history)

        # Get validation IDs
        valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
        valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
        k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        k_fold_best[f'fold_{n_fold}'] = k_fold_best.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        
        ##### Last model #####
        print('Last model evaluation...')
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Last model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds_last += model.predict(test_image_data)

        ##### Best model #####
        print('Best model evaluation...')
        model.load_weights(model_path)
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold_best[f'pred_fold_{n_fold}'] = k_fold_best.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Best model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds += model.predict(test_image_data)


# normalize preds
test_preds /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])
test_preds_last /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])

name_preds = dict(zip(image_names_test, test_preds.reshape(NUM_TEST_IMAGES)))
name_preds_last = dict(zip(image_names_test, test_preds_last.reshape(NUM_TEST_IMAGES)))

test['target'] = test.apply(lambda x: name_preds[x['image_name']], axis=1)
test['target_last'] = test.apply(lambda x: name_preds_last[x['image_name']], axis=1)
# Out:
# FOLD: 1
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b6_noisy-student_notop.h5
# 165232640/165226952 [==============================] - 16s 0us/step
# Epoch 1/15
# 204/204 - 89s - auc: 0.5443 - loss: 0.1796 - val_auc: 0.6107 - val_loss: 0.1793
# Epoch 2/15
# 204/204 - 59s - auc: 0.7026 - loss: 0.1731 - val_auc: 0.7750 - val_loss: 0.1729
# Epoch 3/15
# 204/204 - 59s - auc: 0.7587 - loss: 0.1731 - val_auc: 0.8171 - val_loss: 0.1692
# Epoch 4/15
# 204/204 - 59s - auc: 0.7815 - loss: 0.1699 - val_auc: 0.8291 - val_loss: 0.1676
# Epoch 5/15
# 204/204 - 59s - auc: 0.7967 - loss: 0.1696 - val_auc: 0.8548 - val_loss: 0.1650
# Epoch 6/15
# 204/204 - 55s - auc: 0.8105 - loss: 0.1672 - val_auc: 0.8228 - val_loss: 0.1685
# Epoch 7/15
# 204/204 - 55s - auc: 0.8240 - loss: 0.1674 - val_auc: 0.8544 - val_loss: 0.1664
# Epoch 8/15
# 204/204 - 55s - auc: 0.8581 - loss: 0.1656 - val_auc: 0.8432 - val_loss: 0.1632
# Epoch 9/15
# 204/204 - 59s - auc: 0.8596 - loss: 0.1644 - val_auc: 0.8580 - val_loss: 0.1658
# Epoch 10/15
# 204/204 - 59s - auc: 0.8764 - loss: 0.1631 - val_auc: 0.8665 - val_loss: 0.1634
# Epoch 11/15
# 204/204 - 55s - auc: 0.8770 - loss: 0.1629 - val_auc: 0.8548 - val_loss: 0.1642
# Epoch 12/15
# 204/204 - 55s - auc: 0.8959 - loss: 0.1600 - val_auc: 0.8629 - val_loss: 0.1664
# Epoch 13/15
# 204/204 - 60s - auc: 0.9113 - loss: 0.1582 - val_auc: 0.8731 - val_loss: 0.1655
# Epoch 14/15
# 204/204 - 60s - auc: 0.9241 - loss: 0.1569 - val_auc: 0.8748 - val_loss: 0.1699
# Epoch 15/15
# 204/204 - 56s - auc: 0.9185 - loss: 0.1566 - val_auc: 0.8716 - val_loss: 0.1693
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 2
# Epoch 1/15
# 204/204 - 90s - auc: 0.5358 - loss: 0.1825 - val_auc: 0.5825 - val_loss: 0.1790
# Epoch 2/15
# 204/204 - 59s - auc: 0.7193 - loss: 0.1731 - val_auc: 0.8142 - val_loss: 0.1718
# Epoch 3/15
# 204/204 - 58s - auc: 0.7598 - loss: 0.1708 - val_auc: 0.8219 - val_loss: 0.1690
# Epoch 4/15
# 204/204 - 58s - auc: 0.7838 - loss: 0.1708 - val_auc: 0.8512 - val_loss: 0.1670
# Epoch 5/15
# 204/204 - 54s - auc: 0.8110 - loss: 0.1694 - val_auc: 0.8227 - val_loss: 0.1678
# Epoch 6/15
# 204/204 - 54s - auc: 0.8233 - loss: 0.1666 - val_auc: 0.8475 - val_loss: 0.1656
# Epoch 7/15
# 204/204 - 58s - auc: 0.8426 - loss: 0.1660 - val_auc: 0.8546 - val_loss: 0.1652
# Epoch 8/15
# 204/204 - 58s - auc: 0.8539 - loss: 0.1655 - val_auc: 0.8826 - val_loss: 0.1639
# Epoch 9/15
# 204/204 - 54s - auc: 0.8726 - loss: 0.1648 - val_auc: 0.8821 - val_loss: 0.1650
# Epoch 10/15
# 204/204 - 59s - auc: 0.8778 - loss: 0.1620 - val_auc: 0.8853 - val_loss: 0.1635
# Epoch 11/15
# 204/204 - 59s - auc: 0.8924 - loss: 0.1615 - val_auc: 0.8955 - val_loss: 0.1658
# Epoch 12/15
# 204/204 - 55s - auc: 0.8842 - loss: 0.1606 - val_auc: 0.8913 - val_loss: 0.1657
# Epoch 13/15
# 204/204 - 59s - auc: 0.9021 - loss: 0.1588 - val_auc: 0.8991 - val_loss: 0.1679
# Epoch 14/15
# 204/204 - 55s - auc: 0.9084 - loss: 0.1575 - val_auc: 0.8978 - val_loss: 0.1711
# Epoch 15/15
# 204/204 - 55s - auc: 0.9233 - loss: 0.1556 - val_auc: 0.8979 - val_loss: 0.1708
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 5
# Epoch 1/15
# 204/204 - 89s - auc: 0.5394 - loss: 0.1801 - val_auc: 0.5343 - val_loss: 0.1791
# Epoch 2/15
# 204/204 - 59s - auc: 0.7074 - loss: 0.1746 - val_auc: 0.7688 - val_loss: 0.1697
# Epoch 3/15
# 204/204 - 59s - auc: 0.7620 - loss: 0.1711 - val_auc: 0.7934 - val_loss: 0.1706
# Epoch 4/15
# 204/204 - 55s - auc: 0.7875 - loss: 0.1710 - val_auc: 0.7849 - val_loss: 0.1708
# Epoch 5/15
# 204/204 - 59s - auc: 0.7972 - loss: 0.1692 - val_auc: 0.8127 - val_loss: 0.1683
# Epoch 6/15
# 204/204 - 55s - auc: 0.8285 - loss: 0.1684 - val_auc: 0.7975 - val_loss: 0.1694
# Epoch 7/15
# 204/204 - 55s - auc: 0.8399 - loss: 0.1668 - val_auc: 0.8104 - val_loss: 0.1684
# Epoch 8/15
# 204/204 - 59s - auc: 0.8496 - loss: 0.1662 - val_auc: 0.8412 - val_loss: 0.1680
# Epoch 9/15
# 204/204 - 60s - auc: 0.8672 - loss: 0.1643 - val_auc: 0.8550 - val_loss: 0.1654
# Epoch 10/15
# 204/204 - 56s - auc: 0.8712 - loss: 0.1632 - val_auc: 0.8499 - val_loss: 0.1660
# Epoch 11/15
# 204/204 - 59s - auc: 0.8845 - loss: 0.1618 - val_auc: 0.8742 - val_loss: 0.1650
# Epoch 12/15
# 204/204 - 59s - auc: 0.8975 - loss: 0.1610 - val_auc: 0.8855 - val_loss: 0.1633
# Epoch 13/15
# 204/204 - 56s - auc: 0.9073 - loss: 0.1579 - val_auc: 0.8773 - val_loss: 0.1661
# Epoch 14/15
# 204/204 - 56s - auc: 0.9178 - loss: 0.1566 - val_auc: 0.8717 - val_loss: 0.1669
# Epoch 15/15
# 204/204 - 56s - auc: 0.9180 - loss: 0.1562 - val_auc: 0.8730 - val_loss: 0.1667
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(config['N_USED_FOLDS']):
    print(f'Fold: {n_fold + 1}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# ## Model loss graph aggregated

# %%
plot_metrics_agg(history_list, config['N_USED_FOLDS'])

# %% [markdown]
# # Model evaluation (best)

# %%
display(evaluate_model(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col0 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col3 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col4 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col5 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col7 {
#             color:  orange;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col9 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col10 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col11 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row3_col12 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col0 {
#             color:  orange;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col3 {
#             color:  orange;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col5 {
#             color:  orange;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col9 {
#             color:  orange;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col11 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_145c4b9e_c3ff_11ea_b018_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_145c4b9e_c3ff_11ea_b018_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>
# <style  type="text/css" >
#     #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_14e401e2_c3ff_11ea_b018_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last)

# %%
display(evaluate_model(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col0 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col3 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col4 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col5 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col7 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col9 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col10 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col11 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row3_col12 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col0 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col3 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col5 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col9 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col11 {
#             color:  orange;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_1532ac52_c3ff_11ea_b018_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_1532ac52_c3ff_11ea_b018_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr
# <style  type="text/css" >
#     #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col7 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_15bbfcb4_c3ff_11ea_b018_0242ac130202row6_col9

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_USED_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
k_fold['pred'] = 0
for n_fold in range(config['N_USED_FOLDS']):
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold+1}'] / config['N_FOLDS']

print('Label/prediction distribution')
print(f"Train positive labels: {len(k_fold[k_fold['target'] > .5])}")
print(f"Train positive predictions: {len(k_fold[k_fold['pred'] > .5])}")
print(f"Train positive correct predictions: {len(k_fold[(k_fold['target'] > .5) & (k_fold['pred'] > .5)])}")
    
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))

print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred > .5').head(10))
# Out:
# Label/prediction distribution
# Train positive labels: 581
# Train positive predictions: 322
# Train positive correct predictions: 241
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 0  ISIC_2637011    male        45.0                     head/neck   unknown
# 1  ISIC_0015719  female        45.0               upper extremity   unknown
# 2  ISIC_0052212  female        50.0               lower extremity     nevus
# 3  ISIC_0068279  female        45.0                     head/neck   unknown
# 4  ISIC_0074268  female        55.0               upper extremity   unknown
# 5  ISIC_0074311  female        40.0               lower extremity   unknown
# 6  ISIC_0074542    male        25.0               lower extremity   unknown
# 7  ISIC_0075663  female        35.0                         torso   unknown
# 8  ISIC_0075914    male        30.0                         torso   unknown
# 9  ISIC_0076262  female        50.0               lower extremity   unknown
#
#    target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 0       0  0
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge    target  \
# 0  ISIC_0052060    male        70.0                           NaN  0.028169
# 1  ISIC_0052349    male        40.0               lower extremity  0.025106
# 2  ISIC_0058510  female        55.0                         torso  0.026045
# 3  ISIC_0073313  female        50.0                         torso  0.026711
# 4  ISIC_0073502  female        45.0               lower extremity  0.040663
# 5  ISIC_0074618    male        50.0               lower extremity  0.031274
# 6  ISIC_0076801    male        45.0               upper extremity  0.043438
# 7  ISIC_0077586    male        50.0               lower extremity  0.034351
# 8  ISIC_0082004  female        45.0                         torso  0.041249
# 9  ISIC_0082785    male        65.0               lower extremity  0.048848
#
#    target_last
# 0     0.028271
# 1     0.025203
# 2     0.026110
# 3     0.026230
# 4     0.043645
# 5     0.032061
# 6     0.041878
# 7     0.031546
# 8     0.038161
# 9     0.046982
# Top 10 positive samples
#        image_name     sex  age_approx anatom_site_general_challenge    target  \
# 42   ISIC_0155983    male        70.0                         torso  0.747969
# 109  ISIC_0216447    male        80.0                     head/neck  0.657384
# 175  ISIC_0274789    male        80.0                         torso  0.596742
# 192  ISIC_0287325    male        60.0                         torso  0.500264
# 210  ISIC_0307004    male        30.0                         torso  0.520761
# 288  ISIC_0385415    male        70.0                         torso  0.740544
# 403  ISIC_0481105    male        80.0                         torso  0.830428
# 522  ISIC_0585534    male        70.0                     head/neck  0.730321
# 596  ISIC_0637104  female        80.0                         torso  0.645865
# 943  ISIC_0936377    male        65.0                     head/neck  0.809429
#
#      target_last
# 42      0.770165
# 109     0.745665
# 175     0.604799
# 192     0.472637
# 210     0.524701
# 288     0.755096
# 403     0.881009
# 522     0.710305
# 596     0.705502
# 943     0.897046
# Top 10 positive samples (last)
#        image_name     sex  age_approx anatom_site_general_challenge    target  \
# 18   ISIC_0097719    male        45.0                         torso  0.437935
# 42   ISIC_0155983    male        70.0                         torso  0.747969
# 69   ISIC_0182213  female        80.0                     head/neck  0.487734
# 109  ISIC_0216447    male        80.0                     head/neck  0.657384
# 175  ISIC_0274789    male        80.0                         torso  0.596742
# 210  ISIC_0307004    male        30.0                         torso  0.520761
# 288  ISIC_0385415    male        70.0                         torso  0.740544
# 403  ISIC_0481105    male        80.0                         torso  0.830428
# 522  ISIC_0585534    male        70.0                     head/neck  0.730321
# 552  ISIC_0606244    male        70.0                         torso  0.468496
#
#      target_last
# 18      0.512882
# 42      0.770165
# 69      0.553705
# 109     0.745665
# 175     0.604799
# 210     0.524701
# 288     0.755096
# 403     0.881009
# 522     0.710305
# 552     0.506661

# %% [markdown]
# # Test set predictions

# %%
submission = pd.read_csv(database_base_path + 'sample_submission.csv')
submission['target'] = test['target']
submission['target_last'] = test['target_last']
submission['target_blend'] = (test['target'] * .5) +  (test['target_last'] * .5)
display(submission.head(10))
display(submission.describe())

### BEST ###
submission[['image_name', 'target']].to_csv('submission.csv', index=False)

### LAST ###
submission_last = submission[['image_name', 'target_last']]
submission_last.columns = ['image_name', 'target']
submission_last.to_csv('submission_last.csv', index=False)

### BLEND ###
submission_blend = submission[['image_name', 'target_blend']]
submission_blend.columns = ['image_name', 'target']
submission_blend.to_csv('submission_blend.csv', index=False)
# Out:
#      image_name    target  target_last  target_blend
# 0  ISIC_0052060  0.028169     0.028271      0.028220
# 1  ISIC_0052349  0.025106     0.025203      0.025155
# 2  ISIC_0058510  0.026045     0.026110      0.026077
# 3  ISIC_0073313  0.026711     0.026230      0.026471
# 4  ISIC_0073502  0.040663     0.043645      0.042154
# 5  ISIC_0074618  0.031274     0.032061      0.031668
# 6  ISIC_0076801  0.043438     0.041878      0.042658
# 7  ISIC_0077586  0.034351     0.031546      0.032948
# 8  ISIC_0082004  0.041249     0.038161      0.039705
# 9  ISIC_0082785  0.048848     0.046982      0.047915
#              target   target_last  target_blend
# count  10982.000000  10982.000000  10982.000000
# mean       0.050018      0.050344      0.050181
# std        0.076945      0.080463      0.078613
# min        0.022539      0.022364      0.022465
# 25%        0.026793      0.026473      0.026635
# 50%        0.030428      0.029998      0.030231
# 75%        0.040636      0.039872      0.040289
# max        0.984078      0.989510      0.986794
