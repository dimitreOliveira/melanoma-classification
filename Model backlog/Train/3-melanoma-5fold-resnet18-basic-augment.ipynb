# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
import warnings, json, re
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
# import efficientnet.tfkeras as efn
from classification_models.tfkeras import Classifiers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# REPLICAS:  1

# %% [markdown]
# # Model parameters

# %%
base_model_path = '/kaggle/input/efficientnet/'
dataset_path = 'melanoma-256x256'

config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 64,
  "EPOCHS": 15,
  "LEARNING_RATE": 3e-4, 
  "ES_PATIENCE": 5,
  "N_FOLDS": 5,
  "BASE_MODEL_PATH": base_model_path + 'efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5',
  "DATASET_PATH": dataset_path
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'HEIGHT': 256,
#  'WIDTH': 256,
#  'CHANNELS': 3,
#  'BATCH_SIZE': 64,
#  'EPOCHS': 15,
#  'LEARNING_RATE': 0.0003,
#  'ES_PATIENCE': 5,
#  'N_FOLDS': 5,
#  'BASE_MODEL_PATH': '/kaggle/input/efficientnet/efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5',
#  'DATASET_PATH': 'melanoma-256x256'}

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/siim-isic-melanoma-classification/'
k_fold = pd.read_csv(database_base_path + 'train.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())

GCS_PATH = KaggleDatasets().get_gcs_path(dataset_path)
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %% [markdown]
# ## Auxiliar functions

# %%
# Datasets utility functions
LABELED_TFREC_FORMAT = {
    "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
    "target": tf.io.FixedLenFeature([], tf.int64), # shape [] means single element
    "image_name": tf.io.FixedLenFeature([], tf.string),
    # meta features
    "patient_id": tf.io.FixedLenFeature([], tf.int64),
    "sex": tf.io.FixedLenFeature([], tf.int64),
    "age_approx": tf.io.FixedLenFeature([], tf.int64),
    "anatom_site_general_challenge": tf.io.FixedLenFeature([], tf.int64),
    "diagnosis": tf.io.FixedLenFeature([], tf.int64)
}

def decode_image(image_data, height, width, channels):
    image = tf.image.decode_jpeg(image_data, channels=channels)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.reshape(image, [height, width, channels])
    return image

def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)


def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32', seed=SEED)
#     p_pixel = tf.random.uniform([1], minval=0, maxval=1, dtype='float32', seed=SEED)
#     p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32', seed=SEED)
    
    ### Spatial-level transforms
    if p_spatial >= .2: # flips
        image['input_image'] = tf.image.random_flip_left_right(image['input_image'], seed=SEED)
        image['input_image'] = tf.image.random_flip_up_down(image['input_image'], seed=SEED)
        if p_spatial >= .7:
            image['input_image'] = tf.image.transpose(image['input_image'])
    if p_spatial >= .5: # rotate
        image['input_image'] = tf.image.rot90(image['input_image'])
        if p_spatial >= .75: # double rotate
            image['input_image'] = tf.image.rot90(image['input_image'])
        
#     if p_crop >= .7: # crops
#         if p_crop >= .95:
#             image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.6), int(config['WIDTH']*.6), config['CHANNELS']], seed=SEED)
#         elif p_crop >= .85:
#             image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.7), int(config['WIDTH']*.7), config['CHANNELS']], seed=SEED)
#         elif p_crop >= .8:
#             image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']], seed=SEED)
#         else:
#             image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']], seed=SEED)
#         image['input_image'] = tf.image.resize(image['input_image'], size=[config['HEIGHT'], config['WIDTH']])
    
        
#     ## Pixel-level transforms
#     if p_pixel >= .4: # pixel transformations
#         if p_pixel >= .85:
#             image['input_image'] = tf.image.random_saturation(image['input_image'], lower=0, upper=2, seed=SEED)
#         elif p_pixel >= .65:
#             image['input_image'] = tf.image.random_contrast(image['input_image'], lower=.8, upper=2, seed=SEED)
#         elif p_pixel >= .5:
#             image['input_image'] = tf.image.random_brightness(image['input_image'], max_delta=.2, seed=SEED)
#         else:
#             image['input_image'] = tf.image.adjust_gamma(image['input_image'], gamma=.5)

    return image, label


def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

# %% [markdown]
# ## Learning rate scheduler

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
step_size = 26880 // config['BATCH_SIZE'] #(len(k_fold[k_fold[f'fold_{fold_n}'] == 'train']) * 2) // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
hold_max_steps = 0
warmup_steps = step_size * 5

rng = [i for i in range(0, total_steps, step_size)]
y = [linear_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                 warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                                 lr_start=lr_start, lr_max=lr_max, lr_min=lr_min) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 0.0003 to 3e-05

# %% [markdown]
# # Model

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    ResNet18, preprocess_input = Classifiers.get('resnet18')
    base_model = ResNet18(input_shape=input_shape, 
                          weights='imagenet', 
                          include_top=False)

    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    output = L.Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(len(k_fold)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)

history_list = []
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)
for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
#     tf.tpu.experimental.initialize_tpu_system(tpu)
    K.clear_session()
    
    ### Data
    train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    train_size = count_data_items(train_filenames)

    step_size = train_size // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True, save_weights_only=True)
    
    with strategy.scope():
        model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))
        
        lr = lambda: linear_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                 total_steps=total_steps, warmup_steps=warmup_steps, 
                                                 hold_max_steps=hold_max_steps, lr_start=lr_start, 
                                                 lr_max=lr_max, lr_min=lr_min)
        
        optimizer = optimizers.Adam(learning_rate=lr)
        model.compile(optimizer, loss=losses.BinaryCrossentropy(), 
                      metrics=[metrics.AUC()])
    
    history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                               batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    preds = model.predict(image_data)
    name_preds = dict(zip(image_names, preds.reshape(len(preds))))
    k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds[x['image_name']], axis=1)
    
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
    valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
    k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
# Out:
# FOLD: 1
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 1s 0us/step
# Epoch 1/15
# 388/388 - 110s - loss: 0.2895 - auc: 0.5799 - val_loss: 0.2685 - val_auc: 0.3793
# Epoch 2/15
# 388/388 - 110s - loss: 0.0737 - auc: 0.8386 - val_loss: 0.0969 - val_auc: 0.5908
# Epoch 3/15
# 388/388 - 109s - loss: 0.0705 - auc: 0.8682 - val_loss: 0.0723 - val_auc: 0.8444
# Epoch 4/15
# 388/388 - 109s - loss: 0.0701 - auc: 0.8616 - val_loss: 0.0758 - val_auc: 0.8066
# Epoch 5/15
# 388/388 - 108s - loss: 0.0705 - auc: 0.8672 - val_loss: 0.0825 - val_auc: 0.7724
# Epoch 6/15
# 388/388 - 109s - loss: 0.0690 - auc: 0.8735 - val_loss: 0.0774 - val_auc: 0.8366
# Epoch 7/15
# 388/388 - 109s - loss: 0.0667 - auc: 0.8835 - val_loss: 0.0713 - val_auc: 0.8542
# Epoch 8/15
# 388/388 - 110s - loss: 0.0620 - auc: 0.9090 - val_loss: 0.0687 - val_auc: 0.8805
# Epoch 9/15
# 388/388 - 109s - loss: 0.0593 - auc: 0.9191 - val_loss: 0.0696 - val_auc: 0.8583
# Epoch 10/15
# 388/388 - 109s - loss: 0.0573 - auc: 0.9245 - val_loss: 0.0795 - val_auc: 0.7964
# Epoch 11/15
# 388/388 - 110s - loss: 0.0525 - auc: 0.9372 - val_loss: 0.1081 - val_auc: 0.6715
# Epoch 12/15
# 388/388 - 110s - loss: 0.0476 - auc: 0.9489 - val_loss: 0.0774 - val_auc: 0.8188
# Epoch 13/15
# Restoring model weights from the end of the best epoch.
# 388/388 - 110s - loss: 0.0417 - auc: 0.9605 - val_loss: 0.0709 - val_auc: 0.8723
# Epoch 00013: early stopping
#
# FOLD: 2
# Epoch 1/15
# 420/420 - 116s - loss: 0.4728 - auc: 0.5980 - val_loss: 0.2281 - val_auc: 0.3935
# Epoch 2/15
# 420/420 - 115s - loss: 0.0740 - auc: 0.8439 - val_loss: 0.0908 - val_auc: 0.6639
# Epoch 3/15
# 420/420 - 115s - loss: 0.0711 - auc: 0.8625 - val_loss: 0.0837 - val_auc: 0.7722
# Epoch 4/15
# 420/420 - 115s - loss: 0.0710 - auc: 0.8542 - val_loss: 0.0779 - val_auc: 0.8267
# Epoch 5/15
# 420/420 - 114s - loss: 0.0708 - auc: 0.8669 - val_loss: 0.0780 - val_auc: 0.8274
# Epoch 6/15
# 420/420 - 115s - loss: 0.0665 - auc: 0.8836 - val_loss: 0.0824 - val_auc: 0.7724
# Epoch 7/15
# 420/420 - 115s - loss: 0.0670 - auc: 0.8821 - val_loss: 0.0697 - val_auc: 0.8680
# Epoch 8/15
# 420/420 - 115s - loss: 0.0645 - auc: 0.8931 - val_loss: 0.0823 - val_auc: 0.8494
# Epoch 9/15
# 420/420 - 114s - loss: 0.0596 - auc: 0.9189 - val_loss: 0.0765 - val_auc: 0.8321
# Epoch 10/15
# 420/420 - 115s - loss: 0.0566 - auc: 0.9251 - val_loss: 0.0772 - val_auc: 0.8383
# Epoch 11/15
# 420/420 - 115s - loss: 0.0545 - auc: 0.9348 - val_loss: 0.0835 - val_auc: 0.8144
# Epoch 12/15
# Restoring model weights from the end of the best epoch.
# 420/420 - 114s - loss: 0.0485 - auc: 0.9494 - val_loss: 0.0834 - val_auc: 0.8751
# Epoch 00012: early stopping
#
# FOLD: 3
# Epoch 1/15
# 420/420 - 115s - loss: 0.3104 - auc: 0.6038 - val_loss: 0.2810 - val_auc: 0.4007
# Epoch 2/15
# 420/420 - 115s - loss: 0.0730 - auc: 0.8413 - val_loss: 0.1030 - val_auc: 0.5298
# Epoch 3/15
# 420/420 - 115s - loss: 0.0706 - auc: 0.8557 - val_loss: 0.0742 - val_auc: 0.8557
# Epoch 4/15
# 420/420 - 114s - loss: 0.0707 - auc: 0.8622 - val_loss: 0.0961 - val_auc: 0.7199
# Epoch 5/15
# 420/420 - 115s - loss: 0.0694 - auc: 0.8636 - val_loss: 0.0851 - val_auc: 0.8039
# Epoch 6/15
# 420/420 - 115s - loss: 0.0680 - auc: 0.8805 - val_loss: 0.0792 - val_auc: 0.8151
# Epoch 7/15
# 420/420 - 115s - loss: 0.0651 - auc: 0.8849 - val_loss: 0.0964 - val_auc: 0.8202
# Epoch 8/15
# 420/420 - 115s - loss: 0.0634 - auc: 0.9001 - val_loss: 0.0736 - val_auc: 0.8653
# Epoch 9/15
# 420/420 - 114s - loss: 0.0599 - auc: 0.9181 - val_loss: 0.0740 - val_auc: 0.8414
# Epoch 10/15
# 420/420 - 114s - loss: 0.0584 - auc: 0.9165 - val_loss: 0.0785 - val_auc: 0.8211
# Epoch 11/15
# 420/420 - 115s - loss: 0.0514 - auc: 0.9341 - val_loss: 0.0748 - val_auc: 0.8455
# Epoch 12/15
# 420/420 - 115s - loss: 0.0476 - auc: 0.9535 - val_loss: 0.0728 - val_auc: 0.8652
# Epoch 13/15
# 420/420 - 115s - loss: 0.0415 - auc: 0.9623 - val_loss: 0.0736 - val_auc: 0.8467
# Epoch 14/15
# 420/420 - 115s - loss: 0.0341 - auc: 0.9718 - val_loss: 0.0778 - val_auc: 0.8572
# Epoch 15/15
# 420/420 - 115s - loss: 0.0239 - auc: 0.9869 - val_loss: 0.0771 - val_auc: 0.8310
#
# FOLD: 4
# Epoch 1/15
# 420/420 - 116s - loss: 0.3954 - auc: 0.5925 - val_loss: 0.1135 - val_auc: 0.5157
# Epoch 2/15
# 420/420 - 115s - loss: 0.0720 - auc: 0.8366 - val_loss: 0.0908 - val_auc: 0.6873
# Epoch 3/15
# 420/420 - 115s - loss: 0.0716 - auc: 0.8517 - val_loss: 0.0795 - val_auc: 0.8057
# Epoch 4/15
# 420/420 - 118s - loss: 0.0702 - auc: 0.8603 - val_loss: 0.0731 - val_auc: 0.8529
# Epoch 5/15
# 420/420 - 115s - loss: 0.0700 - auc: 0.8598 - val_loss: 0.0799 - val_auc: 0.7986
# Epoch 6/15
# 420/420 - 114s - loss: 0.0690 - auc: 0.8693 - val_loss: 0.0735 - val_auc: 0.8638
# Epoch 7/15
# 420/420 - 114s - loss: 0.0654 - auc: 0.8880 - val_loss: 0.0765 - val_auc: 0.8532
# Epoch 8/15
# 420/420 - 114s - loss: 0.0617 - auc: 0.9026 - val_loss: 0.0764 - val_auc: 0.8397
# Epoch 9/15
# 420/420 - 115s - loss: 0.0610 - auc: 0.9074 - val_loss: 0.0709 - val_auc: 0.8664
# Epoch 10/15
# 420/420 - 114s - loss: 0.0563 - auc: 0.9307 - val_loss: 0.0819 - val_auc: 0.7790
# Epoch 11/15
# 420/420 - 114s - loss: 0.0508 - auc: 0.9387 - val_loss: 0.0841 - val_auc: 0.7978
# Epoch 12/15
# 420/420 - 115s - loss: 0.0464 - auc: 0.9509 - val_loss: 0.0845 - val_auc: 0.7800
# Epoch 13/15
# 420/420 - 115s - loss: 0.0379 - auc: 0.9697 - val_loss: 0.0759 - val_auc: 0.8405
# Epoch 14/15
# Restoring model weights from the end of the best epoch.
# 420/420 - 115s - loss: 0.0315 - auc: 0.9736 - val_loss: 0.0804 - val_auc: 0.8363
# Epoch 00014: early stopping
#
# FOLD: 5
# Epoch 1/15
# 420/420 - 115s - loss: 0.1697 - auc: 0.6165 - val_loss: 0.2399 - val_auc: 0.6274
# Epoch 2/15
# 420/420 - 115s - loss: 0.0717 - auc: 0.8411 - val_loss: 0.0832 - val_auc: 0.7518
# Epoch 3/15
# 420/420 - 114s - loss: 0.0732 - auc: 0.8550 - val_loss: 0.0723 - val_auc: 0.8768
# Epoch 4/15
# 420/420 - 114s - loss: 0.0697 - auc: 0.8625 - val_loss: 0.0814 - val_auc: 0.8474
# Epoch 5/15
# 420/420 - 114s - loss: 0.0718 - auc: 0.8513 - val_loss: 0.0746 - val_auc: 0.8159
# Epoch 6/15
# 420/420 - 114s - loss: 0.0681 - auc: 0.8681 - val_loss: 0.0807 - val_auc: 0.7871
# Epoch 7/15
# 420/420 - 114s - loss: 0.0686 - auc: 0.8764 - val_loss: 0.0694 - val_auc: 0.8700
# Epoch 8/15
# 420/420 - 114s - loss: 0.0633 - auc: 0.9003 - val_loss: 0.0691 - val_auc: 0.8585
# Epoch 9/15
# 420/420 - 114s - loss: 0.0628 - auc: 0.9067 - val_loss: 0.0684 - val_auc: 0.8637
# Epoch 10/15
# 420/420 - 114s - loss: 0.0593 - auc: 0.9134 - val_loss: 0.0691 - val_auc: 0.8658
# Epoch 11/15
# 420/420 - 115s - loss: 0.0551 - auc: 0.9320 - val_loss: 0.0700 - val_auc: 0.8610
# Epoch 12/15
# 420/420 - 114s - loss: 0.0488 - auc: 0.9479 - val_loss: 0.0706 - val_auc: 0.8500
# Epoch 13/15
# 420/420 - 115s - loss: 0.0419 - auc: 0.9602 - val_loss: 0.0744 - val_auc: 0.8249
# Epoch 14/15
# Restoring model weights from the end of the best epoch.
# 420/420 - 115s - loss: 0.0350 - auc: 0.9715 - val_loss: 0.0763 - val_auc: 0.8155
# Epoch 00014: early stopping

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print(f'Fold: {n_fold}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col2 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col5 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col0 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col3 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col4 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col5 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col9 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col10 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col11 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row3_col12 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col0 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col3 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col5 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col9 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col11 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_df0689ee_b8ca_11ea_85be_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_df0689ee_b8ca_11ea_85be_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <tr>

# %% [markdown]
# # Model evaluation by Subset

# %%
display(evaluate_model_Subset(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_df781758_b8ca_11ea_85be_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col7 {
#             color:  green;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_df781758_b8ca_11ea_85be_0242ac130202row6_col9

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold[k_fold[f'fold_{n_fold}'] == 'train']
    validation_set = k_fold[k_fold[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          validation_set['target'], np.round(validation_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
k_fold['pred'] = 0
for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold}'] / config['N_FOLDS']
    
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))


print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred >= .5').head(10))
# Out:
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 0  ISIC_2637011    male        45.0                     head/neck   unknown
# 1  ISIC_0015719  female        45.0               upper extremity   unknown
# 2  ISIC_0052212  female        50.0               lower extremity     nevus
# 3  ISIC_0068279  female        45.0                     head/neck   unknown
# 4  ISIC_0074268  female        55.0               upper extremity   unknown
# 5  ISIC_0074311  female        40.0               lower extremity   unknown
# 6  ISIC_0074542    male        25.0               lower extremity   unknown
# 7  ISIC_0075663  female        35.0                         torso   unknown
# 8  ISIC_0075914    male        30.0                         torso   unknown
# 9  ISIC_0076262  female        50.0               lower extremity   unknown
#
#    target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 0       0  0.001127     0.000585     0.003003     0.000009     0.000631
# 1       0  0.000829     0.001069     0.001434     0.000102     0.000425
# 2       0  0.001024     0.000164     0.001646     0.000031     0.002267
# 3       0  0.019928     0.011421     0.019745     0.002203     0.001849
# 4       0  0.000100     0.000098     0.000284     0.000006     0.000052
# 5       0  0.000626     0.000735     0.000446     0.000106     0.000434
# 6       0  0.000781     0.000916     0.000906     0.000230     0.001249
# 7       0  0.023942     0.005099     0.042744     0.000278     0.061451
# 8       0  0.000548     0.001218     0.000597     0.000057     0.000340
# 9       0  0.010550     0.040720     0.001569     0.009484     0.000072
#
#    pred_fold_5
# 0     0.001408
# 1     0.001118
# 2     0.001011
# 3     0.064423
# 4     0.000062
# 5     0.001408
# 6     0.000606
# 7     0.010139
# 8     0.000526
# 9     0.000904
# Top 10 positive samples
#        image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 91   ISIC_0149568  female        55.0               upper extremity  melanoma
# 235  ISIC_0188432  female        50.0               upper extremity  melanoma
# 314  ISIC_0207268    male        55.0                         torso  melanoma
# 399  ISIC_0232101    male        65.0                         torso  melanoma
# 459  ISIC_0247330  female        65.0               lower extremity  melanoma
# 475  ISIC_0250839    male        75.0                     head/neck  melanoma
# 544  ISIC_0272509  female        35.0               lower extremity  melanoma
# 546  ISIC_0273046    male        80.0                         torso  melanoma
# 551  ISIC_0274382    male        65.0                         torso  melanoma
# 558  ISIC_0275828    male        30.0               lower extremity  melanoma
#
#      target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 91        1  0.232688     0.006983     0.011593     0.999593     0.004680
# 235       1  0.419374     0.529470     0.158182     0.999780     0.191122
# 314       1  0.043447     0.149006     0.009740     0.000433     0.025537
# 399       1  0.106804     0.016802     0.171859     0.191355     0.014134
# 459       1  0.228016     0.011761     0.022080     0.999248     0.087432
# 475       1  0.310518     0.185703     0.205718     0.971622     0.072594
# 544       1  0.262339     0.201668     0.135082     0.649096     0.162276
# 546       1  0.247514     0.053423     0.024789     0.941983     0.081593
# 551       1  0.277677     0.045533     0.116332     0.862884     0.236735
# 558       1  0.175929     0.132357     0.015446     0.320445     0.141327
#
#      pred_fold_5
# 91      0.140589
# 235     0.218316
# 314     0.032519
# 399     0.139871
# 459     0.019560
# 475     0.116955
# 544     0.163573
# 546     0.135784
# 551     0.126899
# 558     0.270068
# Top 10 predicted positive samples
#          image_name     sex  age_approx anatom_site_general_challenge  \
# 1335   ISIC_0504165  female        60.0               lower extremity
# 8139   ISIC_2535541    male        80.0                     head/neck
# 8623   ISIC_2685593    male        75.0                         torso
# 8927   ISIC_2776906    male        70.0                         torso
# 9984   ISIC_3097354    male        75.0               upper extremity
# 12991  ISIC_3996796    male        70.0                         torso
# 14767  ISIC_4523382  female        60.0                         torso
# 19325  ISIC_5867911    male        55.0               upper extremity
# 20474  ISIC_6228963    male        90.0                         torso
# 25452  ISIC_7724762  female        70.0                         torso
#
#       diagnosis  target      pred  pred_fold_1  pred_fold_2  pred_fold_3  \
# 1335   melanoma       1  0.534629     0.445528     0.328564     0.995301
# 8139   melanoma       1  0.510353     0.562533     0.318533     0.857636
# 8623   melanoma       1  0.508046     0.570105     0.220669     0.978606
# 8927   melanoma       1  0.525244     0.503341     0.173522     0.991210
# 9984   melanoma       1  0.522865     0.505757     0.269108     0.967470
# 12991  melanoma       1  0.514104     0.570632     0.265755     0.983542
# 14767  melanoma       1  0.511022     0.419240     0.351090     0.978740
# 19325  melanoma       1  0.546419     0.613274     0.382800     0.999054
# 20474  melanoma       1  0.582001     0.672857     0.273489     0.984604
# 25452  melanoma       1  0.511879     0.599650     0.247804     0.998330
#
#        pred_fold_4  pred_fold_5
# 1335      0.482615     0.421139
# 8139      0.375932     0.437129
# 8623      0.248107     0.522740
# 8927      0.525894     0.432252
# 9984      0.456185     0.415806
# 12991     0.380895     0.369698
# 14767     0.577248     0.228792
# 19325     0.421479     0.315489
# 20474     0.488586     0.490470
# 25452     0.441911     0.271700
