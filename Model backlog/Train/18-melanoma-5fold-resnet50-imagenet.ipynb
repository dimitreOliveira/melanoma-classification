# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
import warnings, json, re, glob, math
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
# import efficientnet.tfkeras as efn
from classification_models.tfkeras import Classifiers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %% [markdown]
# # Model parameters

# %%
# base_model_path = '/kaggle/input/efficientnet/'
dataset_path = 'melanoma-256x256'

config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 256,
  "EPOCHS": 30,
  "LEARNING_RATE": 3e-4,
  "ES_PATIENCE": 10,
  "N_FOLDS": 5,
#   "BASE_MODEL_PATH": base_model_path + 'efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5',
  "BASE_MODEL_PATH": 'imagenet',
  "DATASET_PATH": dataset_path
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'HEIGHT': 256,
#  'WIDTH': 256,
#  'CHANNELS': 3,
#  'BATCH_SIZE': 256,
#  'EPOCHS': 30,
#  'LEARNING_RATE': 0.0003,
#  'ES_PATIENCE': 10,
#  'N_FOLDS': 5,
#  'BASE_MODEL_PATH': 'imagenet',
#  'DATASET_PATH': 'melanoma-256x256'}

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/siim-isic-melanoma-classification/'
k_fold = pd.read_csv(database_base_path + 'train.csv')
test = pd.read_csv(database_base_path + 'test.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())
print(f'Test samples: {len(test)}')
display(test.head())

GCS_PATH = KaggleDatasets().get_gcs_path(dataset_path)
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0
# Test samples: 10982
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Augmentations

# %%
def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    ### Spatial-level transforms
    if p_spatial >= .2: # flips
        image['input_image'] = tf.image.random_flip_left_right(image['input_image'])
        image['input_image'] = tf.image.random_flip_up_down(image['input_image'])
        if p_spatial >= .7:
            image['input_image'] = tf.image.transpose(image['input_image'])
            
    if p_rotate >= .8: # rotate 270º
        image['input_image'] = tf.image.rot90(image['input_image'], k=3)
    elif p_rotate >= .6: # rotate 180º
        image['input_image'] = tf.image.rot90(image['input_image'], k=2)
    elif p_rotate >= .4: # rotate 90º
        image['input_image'] = tf.image.rot90(image['input_image'], k=1)
        
    if p_spatial2 >= .7: # random rotation range 0º to 45º
        image['input_image'] = transform_rotation(image['input_image'], config['HEIGHT'])
        
    if p_crop >= .6: # crops
        if p_crop >= .95:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.7), int(config['WIDTH']*.7), config['CHANNELS']])
        elif p_crop >= .85:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']])
        elif p_crop >= .7:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']])
        else:
            image['input_image'] = tf.image.central_crop(image['input_image'], central_fraction=.6)
        image['input_image'] = tf.image.resize(image['input_image'], size=[config['HEIGHT'], config['WIDTH']])

    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)

def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Test function
def read_unlabeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_tabular': data}, image_name # returns a dataset of (image, data, image_name)

def load_dataset_test(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_unlabeled_tfrecord, num_parallel_calls=buffer_size)
    # returns a dataset of (image, data, label, image_name) pairs if labeled=True or (image, data, image_name) pairs if labeled=False
    return dataset

def get_test_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_test(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Advanced augmentations
def transform_rotation(image, height):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    rotation = 45. * tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1] ,dtype='float32')
    zero = tf.constant([0], dtype='float32')
    rotation_matrix = tf.reshape( tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0), [3, 3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(rotation_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM, DIM, 3])

# %% [markdown]
# ## Learning rate scheduler

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
step_size = 26880 // config['BATCH_SIZE'] #(len(k_fold[k_fold[f'fold_{fold_n}'] == 'train']) * 2) // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
hold_max_steps = 0
warmup_steps = step_size * 5

rng = [i for i in range(0, total_steps, step_size)]
y = [linear_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                 warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                                 lr_start=lr_start, lr_max=lr_max, lr_min=lr_min) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 0.0003 to 1.2e-05

# %% [markdown]
# # Model

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    BaseModel, preprocess_input = Classifiers.get('resnet50')
    base_model = BaseModel(input_shape=input_shape, 
                           weights=config['BASE_MODEL_PATH'], 
                           include_top=False)

    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    output = L.Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(len(k_fold)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)

history_list = []
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)
for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
    tf.tpu.experimental.initialize_tpu_system(tpu)
#     K.clear_session()
    
    ### Data
    train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    train_size = count_data_items(train_filenames)

    step_size = train_size // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True)
    
    with strategy.scope():
        model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))
        
        lr = lambda: linear_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                 total_steps=total_steps, warmup_steps=warmup_steps, 
                                                 hold_max_steps=hold_max_steps, lr_start=lr_start, 
                                                 lr_max=lr_max, lr_min=lr_min)
        
        optimizer = optimizers.Adam(learning_rate=lr)
        model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                      metrics=[metrics.AUC()])
    
    history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                               batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es], 
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    preds = model.predict(image_data)
    name_preds = dict(zip(image_names, preds.reshape(len(preds))))
    k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds[x['image_name']], axis=1)
    
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
    valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
    k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
# Out:
# FOLD: 1
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet50_imagenet_1000_no_top.h5
# 94593024/94592056 [==============================] - 4s 0us/step
# Epoch 1/30
# 97/97 - 32s - loss: 0.4341 - auc: 0.5394 - val_loss: 0.1809 - val_auc: 0.4773
# Epoch 2/30
# 97/97 - 15s - loss: 0.1688 - auc: 0.8143 - val_loss: 0.2498 - val_auc: 0.3641
# Epoch 3/30
# 97/97 - 17s - loss: 0.1670 - auc: 0.8384 - val_loss: 0.1729 - val_auc: 0.5037
# Epoch 4/30
# 97/97 - 15s - loss: 0.1679 - auc: 0.8254 - val_loss: 0.1779 - val_auc: 0.4656
# Epoch 5/30
# 97/97 - 15s - loss: 0.1680 - auc: 0.8394 - val_loss: 0.1740 - val_auc: 0.3585
# Epoch 6/30
# 97/97 - 17s - loss: 0.1661 - auc: 0.8559 - val_loss: 0.1724 - val_auc: 0.6299
# Epoch 7/30
# 97/97 - 17s - loss: 0.1660 - auc: 0.8680 - val_loss: 0.1708 - val_auc: 0.6532
# Epoch 8/30
# 97/97 - 15s - loss: 0.1643 - auc: 0.8714 - val_loss: 0.1762 - val_auc: 0.7133
# Epoch 9/30
# 97/97 - 15s - loss: 0.1638 - auc: 0.8709 - val_loss: 0.1754 - val_auc: 0.7823
# Epoch 10/30
# 97/97 - 18s - loss: 0.1640 - auc: 0.8741 - val_loss: 0.1697 - val_auc: 0.7449
# Epoch 11/30
# 97/97 - 17s - loss: 0.1628 - auc: 0.8928 - val_loss: 0.1659 - val_auc: 0.8043
# Epoch 12/30
# 97/97 - 17s - loss: 0.1622 - auc: 0.8954 - val_loss: 0.1649 - val_auc: 0.8117
# Epoch 13/30
# 97/97 - 15s - loss: 0.1612 - auc: 0.8959 - val_loss: 0.1672 - val_auc: 0.8557
# Epoch 14/30
# 97/97 - 15s - loss: 0.1597 - auc: 0.8999 - val_loss: 0.1688 - val_auc: 0.7985
# Epoch 15/30
# 97/97 - 15s - loss: 0.1605 - auc: 0.9012 - val_loss: 0.1765 - val_auc: 0.5864
# Epoch 16/30
# 97/97 - 17s - loss: 0.1596 - auc: 0.9083 - val_loss: 0.1633 - val_auc: 0.8610
# Epoch 17/30
# 97/97 - 15s - loss: 0.1588 - auc: 0.9091 - val_loss: 0.1674 - val_auc: 0.7594
# Epoch 18/30
# 97/97 - 17s - loss: 0.1579 - auc: 0.9192 - val_loss: 0.1631 - val_auc: 0.8920
# Epoch 19/30
# 97/97 - 15s - loss: 0.1567 - auc: 0.9208 - val_loss: 0.1640 - val_auc: 0.8859
# Epoch 20/30
# 97/97 - 15s - loss: 0.1555 - auc: 0.9256 - val_loss: 0.1665 - val_auc: 0.8109
# Epoch 21/30
# 97/97 - 15s - loss: 0.1551 - auc: 0.9314 - val_loss: 0.1668 - val_auc: 0.8583
# Epoch 22/30
# 97/97 - 15s - loss: 0.1538 - auc: 0.9361 - val_loss: 0.1822 - val_auc: 0.8676
# Epoch 23/30
# 97/97 - 15s - loss: 0.1522 - auc: 0.9410 - val_loss: 0.1642 - val_auc: 0.8367
# Epoch 24/30
# 97/97 - 15s - loss: 0.1513 - auc: 0.9493 - val_loss: 0.1653 - val_auc: 0.8374
# Epoch 25/30
# 97/97 - 15s - loss: 0.1488 - auc: 0.9570 - val_loss: 0.1643 - val_auc: 0.8466
# Epoch 26/30
# 97/97 - 15s - loss: 0.1462 - auc: 0.9600 - val_loss: 0.1650 - val_auc: 0.8478
# Epoch 27/30
# 97/97 - 15s - loss: 0.1449 - auc: 0.9655 - val_loss: 0.1687 - val_auc: 0.8402
# Epoch 28/30
# Restoring model weights from the end of the best epoch.
# 97/97 - 17s - loss: 0.1427 - auc: 0.9679 - val_loss: 0.1645 - val_auc: 0.8597
# Epoch 00028: early stopping
#
# FOLD: 2
# Epoch 1/30
# 105/105 - 33s - auc_1: 0.5756 - loss: 0.3165 - val_auc_1: 0.5012 - val_loss: 0.1908
# Epoch 2/30
# 105/105 - 15s - auc_1: 0.8222 - loss: 0.1683 - val_auc_1: 0.5423 - val_loss: 0.2575
# Epoch 3/30
# 105/105 - 18s - auc_1: 0.8347 - loss: 0.1675 - val_auc_1: 0.5277 - val_loss: 0.1766
# Epoch 4/30
# 105/105 - 18s - auc_1: 0.8444 - loss: 0.1662 - val_auc_1: 0.4474 - val_loss: 0.1751
# Epoch 5/30
# 105/105 - 15s - auc_1: 0.8442 - loss: 0.1673 - val_auc_1: 0.6311 - val_loss: 0.1969
# Epoch 6/30
# 105/105 - 15s - auc_1: 0.8537 - loss: 0.1647 - val_auc_1: 0.5141 - val_loss: 0.1757
# Epoch 7/30
# 105/105 - 18s - auc_1: 0.8457 - loss: 0.1665 - val_auc_1: 0.7047 - val_loss: 0.1728
# Epoch 8/30
# 105/105 - 16s - auc_1: 0.8771 - loss: 0.1634 - val_auc_1: 0.6210 - val_loss: 0.1777
# Epoch 9/30
# 105/105 - 18s - auc_1: 0.8842 - loss: 0.1630 - val_auc_1: 0.7718 - val_loss: 0.1679
# Epoch 10/30
# 105/105 - 16s - auc_1: 0.8831 - loss: 0.1645 - val_auc_1: 0.7827 - val_loss: 0.1707
# Epoch 11/30
# 105/105 - 16s - auc_1: 0.8859 - loss: 0.1620 - val_auc_1: 0.7497 - val_loss: 0.1693
# Epoch 12/30
# 105/105 - 16s - auc_1: 0.8982 - loss: 0.1614 - val_auc_1: 0.7786 - val_loss: 0.1702
# Epoch 13/30
# 105/105 - 18s - auc_1: 0.9055 - loss: 0.1601 - val_auc_1: 0.8053 - val_loss: 0.1675
# Epoch 14/30
# 105/105 - 15s - auc_1: 0.8962 - loss: 0.1608 - val_auc_1: 0.8317 - val_loss: 0.1692
# Epoch 15/30
# 105/105 - 19s - auc_1: 0.9070 - loss: 0.1588 - val_auc_1: 0.8742 - val_loss: 0.1627
# Epoch 16/30
# 105/105 - 16s - auc_1: 0.9152 - loss: 0.1581 - val_auc_1: 0.7703 - val_loss: 0.1717
# Epoch 17/30
# 105/105 - 16s - auc_1: 0.9104 - loss: 0.1599 - val_auc_1: 0.8555 - val_loss: 0.1650
# Epoch 18/30
# 105/105 - 15s - auc_1: 0.9154 - loss: 0.1574 - val_auc_1: 0.8560 - val_loss: 0.1661
# Epoch 19/30
# 105/105 - 15s - auc_1: 0.9195 - loss: 0.1567 - val_auc_1: 0.8507 - val_loss: 0.1655
# Epoch 20/30
# 105/105 - 16s - auc_1: 0.9309 - loss: 0.1545 - val_auc_1: 0.8191 - val_loss: 0.1681
# Epoch 21/30
# 105/105 - 15s - auc_1: 0.9361 - loss: 0.1538 - val_auc_1: 0.8473 - val_loss: 0.1683
# Epoch 22/30
# 105/105 - 28s - auc_1: 0.9382 - loss: 0.1534 - val_auc_1: 0.8733 - val_loss: 0.1621
# Epoch 23/30
# 105/105 - 15s - auc_1: 0.9479 - loss: 0.1513 - val_auc_1: 0.8644 - val_loss: 0.1650
# Epoch 24/30
# 105/105 - 16s - auc_1: 0.9503 - loss: 0.1491 - val_auc_1: 0.8626 - val_loss: 0.1634
# Epoch 25/30
# 105/105 - 15s - auc_1: 0.9467 - loss: 0.1495 - val_auc_1: 0.8143 - val_loss: 0.1681
# Epoch 26/30
# 105/105 - 18s - auc_1: 0.9602 - loss: 0.1464 - val_auc_1: 0.8459 - val_loss: 0.1619
# Epoch 27/30
# 105/105 - 15s - auc_1: 0.9680 - loss: 0.1442 - val_auc_1: 0.8296 - val_loss: 0.1621
# Epoch 28/30
# 105/105 - 15s - auc_1: 0.9759 - loss: 0.1424 - val_auc_1: 0.8522 - val_loss: 0.1643
# Epoch 29/30
# 105/105 - 16s - auc_1: 0.9765 - loss: 0.1406 - val_auc_1: 0.8770 - val_loss: 0.1626
# Epoch 30/30
# 105/105 - 16s - auc_1: 0.9744 - loss: 0.1392 - val_auc_1: 0.8685 - val_loss: 0.1627
#
# FOLD: 3
# Epoch 1/30
# 105/105 - 34s - auc_2: 0.5397 - loss: 0.4466 - val_auc_2: 0.5479 - val_loss: 0.1781
# Epoch 2/30
# 105/105 - 15s - auc_2: 0.8181 - loss: 0.1676 - val_auc_2: 0.4915 - val_loss: 0.1876
# Epoch 3/30
# 105/105 - 16s - auc_2: 0.8257 - loss: 0.1675 - val_auc_2: 0.5221 - val_loss: 0.1979
# Epoch 4/30
# 105/105 - 18s - auc_2: 0.8293 - loss: 0.1679 - val_auc_2: 0.5601 - val_loss: 0.1772
# Epoch 5/30
# 105/105 - 15s - auc_2: 0.8351 - loss: 0.1658 - val_auc_2: 0.6044 - val_loss: 0.1794
# Epoch 6/30
# 105/105 - 18s - auc_2: 0.8438 - loss: 0.1675 - val_auc_2: 0.5949 - val_loss: 0.1753
# Epoch 7/30
# 105/105 - 18s - auc_2: 0.8606 - loss: 0.1650 - val_auc_2: 0.6783 - val_loss: 0.1750
# Epoch 8/30
# 105/105 - 18s - auc_2: 0.8795 - loss: 0.1634 - val_auc_2: 0.8025 - val_loss: 0.1720
# Epoch 9/30
# 105/105 - 18s - auc_2: 0.8647 - loss: 0.1637 - val_auc_2: 0.7474 - val_loss: 0.1708
# Epoch 10/30
# 105/105 - 18s - auc_2: 0.8752 - loss: 0.1638 - val_auc_2: 0.8504 - val_loss: 0.1680
# Epoch 11/30
# 105/105 - 16s - auc_2: 0.8801 - loss: 0.1632 - val_auc_2: 0.8494 - val_loss: 0.1684
# Epoch 12/30
# 105/105 - 18s - auc_2: 0.8962 - loss: 0.1623 - val_auc_2: 0.8588 - val_loss: 0.1679
# Epoch 13/30
# 105/105 - 16s - auc_2: 0.9031 - loss: 0.1605 - val_auc_2: 0.8557 - val_loss: 0.1708
# Epoch 14/30
# 105/105 - 16s - auc_2: 0.9009 - loss: 0.1610 - val_auc_2: 0.8572 - val_loss: 0.1680
# Epoch 15/30
# 105/105 - 15s - auc_2: 0.9053 - loss: 0.1603 - val_auc_2: 0.8367 - val_loss: 0.1699
# Epoch 16/30
# 105/105 - 16s - auc_2: 0.9127 - loss: 0.1595 - val_auc_2: 0.8567 - val_loss: 0.1693
# Epoch 17/30
# 105/105 - 18s - auc_2: 0.9105 - loss: 0.1578 - val_auc_2: 0.8299 - val_loss: 0.1662
# Epoch 18/30
# 105/105 - 16s - auc_2: 0.9207 - loss: 0.1578 - val_auc_2: 0.8562 - val_loss: 0.1666
# Epoch 19/30
# 105/105 - 15s - auc_2: 0.9258 - loss: 0.1565 - val_auc_2: 0.8603 - val_loss: 0.1668
# Epoch 20/30
# 105/105 - 15s - auc_2: 0.9282 - loss: 0.1550 - val_auc_2: 0.7993 - val_loss: 0.1679
# Epoch 21/30
# 105/105 - 16s - auc_2: 0.9283 - loss: 0.1541 - val_auc_2: 0.8222 - val_loss: 0.1668
# Epoch 22/30
# 105/105 - 18s - auc_2: 0.9404 - loss: 0.1529 - val_auc_2: 0.8656 - val_loss: 0.1636
# Epoch 23/30
# 105/105 - 16s - auc_2: 0.9427 - loss: 0.1514 - val_auc_2: 0.8388 - val_loss: 0.1660
# Epoch 24/30
# 105/105 - 16s - auc_2: 0.9425 - loss: 0.1503 - val_auc_2: 0.8594 - val_loss: 0.1641
# Epoch 25/30
# 105/105 - 15s - auc_2: 0.9605 - loss: 0.1477 - val_auc_2: 0.8432 - val_loss: 0.1650
# Epoch 26/30
# 105/105 - 15s - auc_2: 0.9577 - loss: 0.1474 - val_auc_2: 0.8550 - val_loss: 0.1679
# Epoch 27/30
# 105/105 - 16s - auc_2: 0.9657 - loss: 0.1441 - val_auc_2: 0.8514 - val_loss: 0.1647
# Epoch 28/30
# 105/105 - 15s - auc_2: 0.9707 - loss: 0.1423 - val_auc_2: 0.8329 - val_loss: 0.1643
# Epoch 29/30
# 105/105 - 16s - auc_2: 0.9781 - loss: 0.1413 - val_auc_2: 0.8251 - val_loss: 0.1637
# Epoch 30/30
# 105/105 - 16s - auc_2: 0.9750 - loss: 0.1407 - val_auc_2: 0.8278 - val_loss: 0.1656
#
# FOLD: 4
# Epoch 1/30
# 105/105 - 34s - auc_3: 0.5732 - loss: 0.3343 - val_auc_3: 0.5107 - val_loss: 0.1837
# Epoch 2/30
# 105/105 - 18s - auc_3: 0.8205 - loss: 0.1675 - val_auc_3: 0.5004 - val_loss: 0.1749
# Epoch 3/30
# 105/105 - 16s - auc_3: 0.8270 - loss: 0.1679 - val_auc_3: 0.5134 - val_loss: 0.1753
# Epoch 4/30
# 105/105 - 18s - auc_3: 0.8352 - loss: 0.1666 - val_auc_3: 0.6639 - val_loss: 0.1739
# Epoch 5/30
# 105/105 - 16s - auc_3: 0.8475 - loss: 0.1661 - val_auc_3: 0.5346 - val_loss: 0.1792
# Epoch 6/30
# 105/105 - 16s - auc_3: 0.8692 - loss: 0.1649 - val_auc_3: 0.6540 - val_loss: 0.1770
# Epoch 7/30
# 105/105 - 16s - auc_3: 0.8533 - loss: 0.1654 - val_auc_3: 0.5448 - val_loss: 0.1746
# Epoch 8/30
# 105/105 - 18s - auc_3: 0.8664 - loss: 0.1634 - val_auc_3: 0.7391 - val_loss: 0.1727
# Epoch 9/30
# 105/105 - 16s - auc_3: 0.8795 - loss: 0.1629 - val_auc_3: 0.7019 - val_loss: 0.1735
# Epoch 10/30
# 105/105 - 23s - auc_3: 0.8816 - loss: 0.1632 - val_auc_3: 0.8198 - val_loss: 0.1686
# Epoch 11/30
# 105/105 - 16s - auc_3: 0.8887 - loss: 0.1628 - val_auc_3: 0.7588 - val_loss: 0.1710
# Epoch 12/30
# 105/105 - 16s - auc_3: 0.9032 - loss: 0.1606 - val_auc_3: 0.7339 - val_loss: 0.1708
# Epoch 13/30
# 105/105 - 16s - auc_3: 0.8973 - loss: 0.1600 - val_auc_3: 0.7114 - val_loss: 0.1734
# Epoch 14/30
# 105/105 - 15s - auc_3: 0.9003 - loss: 0.1608 - val_auc_3: 0.7996 - val_loss: 0.1697
# Epoch 15/30
# 105/105 - 18s - auc_3: 0.9061 - loss: 0.1593 - val_auc_3: 0.8579 - val_loss: 0.1682
# Epoch 16/30
# 105/105 - 18s - auc_3: 0.9196 - loss: 0.1593 - val_auc_3: 0.8489 - val_loss: 0.1677
# Epoch 17/30
# 105/105 - 15s - auc_3: 0.9127 - loss: 0.1581 - val_auc_3: 0.8351 - val_loss: 0.1687
# Epoch 18/30
# 105/105 - 18s - auc_3: 0.9209 - loss: 0.1570 - val_auc_3: 0.8579 - val_loss: 0.1672
# Epoch 19/30
# 105/105 - 15s - auc_3: 0.9314 - loss: 0.1548 - val_auc_3: 0.8033 - val_loss: 0.1713
# Epoch 20/30
# 105/105 - 15s - auc_3: 0.9287 - loss: 0.1555 - val_auc_3: 0.7873 - val_loss: 0.1699
# Epoch 21/30
# 105/105 - 18s - auc_3: 0.9391 - loss: 0.1529 - val_auc_3: 0.8424 - val_loss: 0.1667
# Epoch 22/30
# 105/105 - 16s - auc_3: 0.9421 - loss: 0.1529 - val_auc_3: 0.7827 - val_loss: 0.1709
# Epoch 23/30
# 105/105 - 16s - auc_3: 0.9488 - loss: 0.1510 - val_auc_3: 0.8340 - val_loss: 0.1681
# Epoch 24/30
# 105/105 - 16s - auc_3: 0.9484 - loss: 0.1490 - val_auc_3: 0.8159 - val_loss: 0.1699
# Epoch 25/30
# 105/105 - 16s - auc_3: 0.9546 - loss: 0.1478 - val_auc_3: 0.8205 - val_loss: 0.1707
# Epoch 26/30
# 105/105 - 18s - auc_3: 0.9644 - loss: 0.1453 - val_auc_3: 0.8676 - val_loss: 0.1665
# Epoch 27/30
# 105/105 - 15s - auc_3: 0.9680 - loss: 0.1443 - val_auc_3: 0.8223 - val_loss: 0.1693
# Epoch 28/30
# 105/105 - 15s - auc_3: 0.9676 - loss: 0.1422 - val_auc_3: 0.8381 - val_loss: 0.1683
# Epoch 29/30
# 105/105 - 16s - auc_3: 0.9781 - loss: 0.1402 - val_auc_3: 0.8137 - val_loss: 0.1673
# Epoch 30/30
# 105/105 - 16s - auc_3: 0.9820 - loss: 0.1386 - val_auc_3: 0.8202 - val_loss: 0.1684
#
# FOLD: 5
# Epoch 1/30
# 105/105 - 33s - auc_4: 0.5697 - loss: 0.4758 - val_auc_4: 0.6080 - val_loss: 0.1938
# Epoch 2/30
# 105/105 - 16s - auc_4: 0.7921 - loss: 0.1693 - val_auc_4: 0.5643 - val_loss: 0.2094
# Epoch 3/30
# 105/105 - 18s - auc_4: 0.8237 - loss: 0.1681 - val_auc_4: 0.5811 - val_loss: 0.1731
# Epoch 4/30
# 105/105 - 16s - auc_4: 0.8379 - loss: 0.1680 - val_auc_4: 0.5139 - val_loss: 0.1790
# Epoch 5/30
# 105/105 - 16s - auc_4: 0.8513 - loss: 0.1654 - val_auc_4: 0.4664 - val_loss: 0.1757
# Epoch 6/30
# 105/105 - 16s - auc_4: 0.8599 - loss: 0.1665 - val_auc_4: 0.3437 - val_loss: 0.1750
# Epoch 7/30
# 105/105 - 18s - auc_4: 0.8629 - loss: 0.1654 - val_auc_4: 0.7219 - val_loss: 0.1711
# Epoch 8/30
# 105/105 - 18s - auc_4: 0.8755 - loss: 0.1657 - val_auc_4: 0.7790 - val_loss: 0.1685
# Epoch 9/30
# 105/105 - 15s - auc_4: 0.8745 - loss: 0.1640 - val_auc_4: 0.7091 - val_loss: 0.1711
# Epoch 10/30
# 105/105 - 18s - auc_4: 0.8831 - loss: 0.1635 - val_auc_4: 0.8138 - val_loss: 0.1682
# Epoch 11/30
# 105/105 - 18s - auc_4: 0.8986 - loss: 0.1627 - val_auc_4: 0.8366 - val_loss: 0.1646
# Epoch 12/30
# 105/105 - 15s - auc_4: 0.9046 - loss: 0.1612 - val_auc_4: 0.7774 - val_loss: 0.1671
# Epoch 13/30
# 105/105 - 18s - auc_4: 0.9044 - loss: 0.1618 - val_auc_4: 0.8524 - val_loss: 0.1644
# Epoch 14/30
# 105/105 - 18s - auc_4: 0.9110 - loss: 0.1593 - val_auc_4: 0.8594 - val_loss: 0.1632
# Epoch 15/30
# 105/105 - 15s - auc_4: 0.9021 - loss: 0.1608 - val_auc_4: 0.8594 - val_loss: 0.1672
# Epoch 16/30
# 105/105 - 18s - auc_4: 0.9044 - loss: 0.1599 - val_auc_4: 0.8907 - val_loss: 0.1630
# Epoch 17/30
# 105/105 - 16s - auc_4: 0.9164 - loss: 0.1590 - val_auc_4: 0.8334 - val_loss: 0.1648
# Epoch 18/30
# 105/105 - 15s - auc_4: 0.9173 - loss: 0.1570 - val_auc_4: 0.7669 - val_loss: 0.1685
# Epoch 19/30
# 105/105 - 16s - auc_4: 0.9333 - loss: 0.1557 - val_auc_4: 0.8849 - val_loss: 0.1676
# Epoch 20/30
# 105/105 - 16s - auc_4: 0.9319 - loss: 0.1549 - val_auc_4: 0.8369 - val_loss: 0.1694
# Epoch 21/30
# 105/105 - 16s - auc_4: 0.9344 - loss: 0.1530 - val_auc_4: 0.8393 - val_loss: 0.1655
# Epoch 22/30
# 105/105 - 16s - auc_4: 0.9434 - loss: 0.1536 - val_auc_4: 0.8826 - val_loss: 0.1634
# Epoch 23/30
# 105/105 - 16s - auc_4: 0.9460 - loss: 0.1508 - val_auc_4: 0.8961 - val_loss: 0.1643
# Epoch 24/30
# 105/105 - 16s - auc_4: 0.9491 - loss: 0.1507 - val_auc_4: 0.8263 - val_loss: 0.1638
# Epoch 25/30
# 105/105 - 17s - auc_4: 0.9579 - loss: 0.1473 - val_auc_4: 0.8341 - val_loss: 0.1661
# Epoch 26/30
# Restoring model weights from the end of the best epoch.
# 105/105 - 17s - auc_4: 0.9560 - loss: 0.1468 - val_auc_4: 0.8476 - val_loss: 0.1634
# Epoch 00026: early stopping

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print(f'Fold: {n_fold}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# ## Model loss graph aggregated

# %%
plot_metrics_agg(history_list, config['N_FOLDS'])

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col9 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col0 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col9 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col0 {
#             color:  orange;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col3 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col4 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col10 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col11 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row3_col12 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col3 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col11 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_1c223d52_bcb6_11ea_aea4_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_1c223d52_bcb6_11ea_aea4_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>

# %% [markdown]
# # Model evaluation by Subset

# %%
display(evaluate_model_Subset(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col5 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col7 {
#             color:  green;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_1ca8be72_bcb6_11ea_aea4_0242ac130202row6_col9

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold[k_fold[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold[k_fold[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
k_fold['pred'] = 0
for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold}'] / config['N_FOLDS']
    
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))


print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred > .5').head(10))

print('Label/prediction distribution')
print(f"Train positive labels: {len(k_fold[k_fold['target'] > .5])}")
print(f"Train positive predictions: {len(k_fold[k_fold['pred'] > .5])}")
# Out:
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 0  ISIC_2637011    male        45.0                     head/neck   unknown
# 1  ISIC_0015719  female        45.0               upper extremity   unknown
# 2  ISIC_0052212  female        50.0               lower extremity     nevus
# 3  ISIC_0068279  female        45.0                     head/neck   unknown
# 4  ISIC_0074268  female        55.0               upper extremity   unknown
# 5  ISIC_0074311  female        40.0               lower extremity   unknown
# 6  ISIC_0074542    male        25.0               lower extremity   unknown
# 7  ISIC_0075663  female        35.0                         torso   unknown
# 8  ISIC_0075914    male        30.0                         torso   unknown
# 9  ISIC_0076262  female        50.0               lower extremity   unknown
#
#    target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 0       0  0.022851     0.026553     0.019852     0.029166     0.018468
# 1       0  0.027213     0.028984     0.026418     0.029858     0.028802
# 2       0  0.022696     0.018177     0.020205     0.027576     0.025215
# 3       0  0.031561     0.033703     0.022792     0.037127     0.038800
# 4       0  0.022678     0.018982     0.025823     0.024259     0.018251
# 5       0  0.023176     0.021010     0.020442     0.026450     0.025138
# 6       0  0.026574     0.036679     0.019954     0.024782     0.026455
# 7       0  0.016100     0.028856     0.011072     0.014731     0.012171
# 8       0  0.025531     0.027349     0.027703     0.024831     0.021881
# 9       0  0.029711     0.032789     0.033218     0.023024     0.031489
#
#    pred_fold_5
# 0     0.020217
# 1     0.022004
# 2     0.022307
# 3     0.025385
# 4     0.026077
# 5     0.022840
# 6     0.025000
# 7     0.013669
# 8     0.025889
# 9     0.028037
# Top 10 positive samples
#        image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 91   ISIC_0149568  female        55.0               upper extremity  melanoma
# 235  ISIC_0188432  female        50.0               upper extremity  melanoma
# 314  ISIC_0207268    male        55.0                         torso  melanoma
# 399  ISIC_0232101    male        65.0                         torso  melanoma
# 459  ISIC_0247330  female        65.0               lower extremity  melanoma
# 475  ISIC_0250839    male        75.0                     head/neck  melanoma
# 544  ISIC_0272509  female        35.0               lower extremity  melanoma
# 546  ISIC_0273046    male        80.0                         torso  melanoma
# 551  ISIC_0274382    male        65.0                         torso  melanoma
# 558  ISIC_0275828    male        30.0               lower extremity  melanoma
#
#      target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 91        1  0.582635     0.026892     0.941755     0.979216     0.942541
# 235       1  0.573989     0.214451     0.531957     0.952327     0.998308
# 314       1  0.256024     0.061795     0.111694     0.022663     0.986217
# 399       1  0.395630     0.075400     0.889165     0.552343     0.398339
# 459       1  0.623529     0.093758     0.997481     0.978391     0.995210
# 475       1  0.531851     0.821557     0.943031     0.606824     0.152393
# 544       1  0.396769     0.063467     0.083845     0.785622     0.986121
# 546       1  0.591028     0.047672     0.997344     0.922765     0.897780
# 551       1  0.473389     0.094951     0.421499     0.808566     0.881256
# 558       1  0.420060     0.248637     0.809641     0.039392     0.939979
#
#      pred_fold_5
# 91      0.022772
# 235     0.172902
# 314     0.097751
# 399     0.062900
# 459     0.052804
# 475     0.135451
# 544     0.064789
# 546     0.089580
# 551     0.160674
# 558     0.062649
# Top 10 predicted positive samples
#         image_name     sex  age_approx anatom_site_general_challenge  \
# 91    ISIC_0149568  female        55.0               upper extremity
# 235   ISIC_0188432  female        50.0               upper extremity
# 459   ISIC_0247330  female        65.0               lower extremity
# 475   ISIC_0250839    male        75.0                     head/neck
# 546   ISIC_0273046    male        80.0                         torso
# 758   ISIC_0333091    male        25.0               lower extremity
# 810   ISIC_0347824    male        50.0               lower extremity
# 826   ISIC_0351666    male        80.0                     head/neck
# 886   ISIC_0369831    male        80.0               upper extremity
# 1332  ISIC_0502582    male        65.0               lower extremity
#
#      diagnosis  target      pred  pred_fold_1  pred_fold_2  pred_fold_3  \
# 91    melanoma       1  0.582635     0.026892     0.941755     0.979216
# 235   melanoma       1  0.573989     0.214451     0.531957     0.952327
# 459   melanoma       1  0.623529     0.093758     0.997481     0.978391
# 475   melanoma       1  0.531851     0.821557     0.943031     0.606824
# 546   melanoma       1  0.591028     0.047672     0.997344     0.922765
# 758   melanoma       1  0.645403     0.805932     0.995171     0.469502
# 810    unknown       0  0.517609     0.542300     0.764895     0.595541
# 826   melanoma       1  0.643838     0.492838     0.714008     0.999248
# 886   melanoma       1  0.664521     0.319209     0.976513     0.814453
# 1332  melanoma       1  0.848885     0.941376     0.923698     0.999654
#
#       pred_fold_4  pred_fold_5
# 91       0.942541     0.022772
# 235      0.998308     0.172902
# 459      0.995210     0.052804
# 475      0.152393     0.135451
# 546      0.897780     0.089580
# 758      0.678990     0.277418
# 810      0.542659     0.142651
# 826      0.889855     0.123244
# 886      0.979581     0.232847
# 1332     0.999170     0.380526
# Label/prediction distribution
# Train positive labels: 584
# Train positive predictions: 304

# %% [markdown]
# # Make predictions

# %%
model_path_list = glob.glob('/kaggle/working/' + '*.h5')
n_models = len(model_path_list)
model_path_list.sort()

print(f'{n_models} Models to predict:')
print(*model_path_list, sep='\n')
# Out:
# 5 Models to predict:
# /kaggle/working/model_fold_1.h5
# /kaggle/working/model_fold_2.h5
# /kaggle/working/model_fold_3.h5
# /kaggle/working/model_fold_4.h5
# /kaggle/working/model_fold_5.h5

# %%
test_dataset = get_test_dataset(TEST_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
NUM_TEST_IMAGES = len(test)
test_preds = np.zeros((NUM_TEST_IMAGES, 1))


for model_path in model_path_list:
    tf.tpu.experimental.initialize_tpu_system(tpu)
#     K.clear_session()
    print(model_path)
    model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))
    model.load_weights(model_path)
    
    test_preds += model.predict(test_dataset) / n_models


image_names = next(iter(test_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TEST_IMAGES))).numpy().astype('U')
name_preds = dict(zip(image_names, test_preds.reshape(len(test_preds))))
test['target'] = test.apply(lambda x: name_preds[x['image_name']], axis=1)
# Out:
# /kaggle/working/model_fold_1.h5
# /kaggle/working/model_fold_2.h5
# /kaggle/working/model_fold_3.h5
# /kaggle/working/model_fold_4.h5
# /kaggle/working/model_fold_5.h5

# %% [markdown]
# # Visualize test predictions

# %%
print(f"Test predictions {len(test[test['target'] > .5])}|{len(test[test['target'] <= .5])}")
print('Top 10 samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge','target'] + 
             [c for c in test.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target'] + 
             [c for c in test.columns if (c.startswith('pred_fold'))]].query('target > .5').head(10))
# Out:
# Test predictions 24|10958
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge    target
# 0  ISIC_0052060    male        70.0                           NaN  0.021027
# 1  ISIC_0052349    male        40.0               lower extremity  0.019427
# 2  ISIC_0058510  female        55.0                         torso  0.025395
# 3  ISIC_0073313  female        50.0                         torso  0.023912
# 4  ISIC_0073502  female        45.0               lower extremity  0.032351
# 5  ISIC_0074618    male        50.0               lower extremity  0.031315
# 6  ISIC_0076801    male        45.0               upper extremity  0.026082
# 7  ISIC_0077586    male        50.0               lower extremity  0.034323
# 8  ISIC_0082004  female        45.0                         torso  0.027733
# 9  ISIC_0082785    male        65.0               lower extremity  0.036742
# Top 10 positive samples
#         image_name     sex  age_approx anatom_site_general_challenge    target
# 522   ISIC_0585534    male        70.0                     head/neck  0.666572
# 1408  ISIC_1364884  female        35.0               upper extremity  0.620022
# 1525  ISIC_1460169    male        55.0                     head/neck  0.635771
# 2739  ISIC_2560699    male        70.0                         torso  0.632663
# 3045  ISIC_2839742    male        70.0               upper extremity  0.794852
# 3103  ISIC_2900150  female        80.0               lower extremity  0.700588
# 3171  ISIC_2968715  female        65.0               lower extremity  0.629419
# 4332  ISIC_4000026    male        90.0                         torso  0.520340
# 4462  ISIC_4118006  female        50.0                     head/neck  0.588973
# 4637  ISIC_4282399    male        60.0               upper extremity  0.560764

# %% [markdown]
# # Test set predictions

# %%
submission = pd.read_csv(database_base_path + 'sample_submission.csv')
submission['target'] = test['target']
submission.to_csv('submission.csv', index=False)
display(submission.head(10))
display(submission.describe())
# Out:
#      image_name    target
# 0  ISIC_0052060  0.021027
# 1  ISIC_0052349  0.019427
# 2  ISIC_0058510  0.025395
# 3  ISIC_0073313  0.023912
# 4  ISIC_0073502  0.032351
# 5  ISIC_0074618  0.031315
# 6  ISIC_0076801  0.026082
# 7  ISIC_0077586  0.034323
# 8  ISIC_0082004  0.027733
# 9  ISIC_0082785  0.036742
#              target
# count  10982.000000
# mean       0.040764
# std        0.049417
# min        0.016585
# 25%        0.023993
# 50%        0.027588
# 75%        0.037207
# max        0.794852
