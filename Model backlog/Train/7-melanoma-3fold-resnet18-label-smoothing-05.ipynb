# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
import warnings, json, re
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
# import efficientnet.tfkeras as efn
from classification_models.tfkeras import Classifiers

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# REPLICAS:  1

# %% [markdown]
# # Model parameters

# %%
base_model_path = '/kaggle/input/efficientnet/'
dataset_path = 'melanoma-256x256'

config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 64,
  "EPOCHS": 15,
  "LEARNING_RATE": 3e-4, 
  "ES_PATIENCE": 5,
  "N_FOLDS": 3,
  "BASE_MODEL_PATH": base_model_path + 'efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5',
  "DATASET_PATH": dataset_path
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'HEIGHT': 256,
#  'WIDTH': 256,
#  'CHANNELS': 3,
#  'BATCH_SIZE': 64,
#  'EPOCHS': 15,
#  'LEARNING_RATE': 0.0003,
#  'ES_PATIENCE': 5,
#  'N_FOLDS': 3,
#  'BASE_MODEL_PATH': '/kaggle/input/efficientnet/efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5',
#  'DATASET_PATH': 'melanoma-256x256'}

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/siim-isic-melanoma-classification/'
k_fold = pd.read_csv(database_base_path + 'train.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())

GCS_PATH = KaggleDatasets().get_gcs_path(dataset_path)
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    data['diagnosis'] = tf.cast(tf.one_hot(example['diagnosis'], 10), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)


def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32', seed=SEED)
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32', seed=SEED)
    
    ### Spatial-level transforms
    if p_spatial >= .2: # flips
        image['input_image'] = tf.image.random_flip_left_right(image['input_image'], seed=SEED)
        image['input_image'] = tf.image.random_flip_up_down(image['input_image'], seed=SEED)
        if p_spatial >= .7:
            image['input_image'] = tf.image.transpose(image['input_image'])
    if p_rotate >= .8: # rotate 270
        image['input_image'] = tf.image.rot90(image['input_image'], k=3)
    elif p_rotate >= .6: # rotate 180
        image['input_image'] = tf.image.rot90(image['input_image'], k=2)
    elif p_rotate >= .4: # rotate 90
        image['input_image'] = tf.image.rot90(image['input_image'], k=1)

    return image, label


def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %% [markdown]
# ## Learning rate scheduler

# %%
lr_min = 1e-6
lr_start = 0
lr_max = config['LEARNING_RATE']
step_size = 26880 // config['BATCH_SIZE'] #(len(k_fold[k_fold[f'fold_{fold_n}'] == 'train']) * 2) // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * step_size
hold_max_steps = 0
warmup_steps = step_size * 5

rng = [i for i in range(0, total_steps, step_size)]
y = [linear_schedule_with_warmup(tf.cast(x, tf.float32), total_steps=total_steps, 
                                 warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                                 lr_start=lr_start, lr_max=lr_max, lr_min=lr_min) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 0 to 0.0003 to 3e-05

# %% [markdown]
# # Model

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    ResNet18, preprocess_input = Classifiers.get('resnet18')
    base_model = ResNet18(input_shape=input_shape, 
                          weights='imagenet', 
                          include_top=False)

    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    output = L.Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(len(k_fold)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)

history_list = []
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)
for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    n_fold +=1
    print('\nFOLD: %d' % (n_fold))
#     tf.tpu.experimental.initialize_tpu_system(tpu)
    K.clear_session()
    
    ### Data
    train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    train_size = count_data_items(train_filenames)

    step_size = train_size // config['BATCH_SIZE']

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold)
    
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', save_best_only=True, save_weights_only=True)
    
    with strategy.scope():
        model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))
        
        lr = lambda: linear_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                 total_steps=total_steps, warmup_steps=warmup_steps, 
                                                 hold_max_steps=hold_max_steps, lr_start=lr_start, 
                                                 lr_max=lr_max, lr_min=lr_min)
        
        optimizer = optimizers.Adam(learning_rate=lr)
        model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                      metrics=[metrics.AUC()])
    
    history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                               batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        callbacks=[checkpoint, es],
                        verbose=2).history
    
    history_list.append(history)
    
    # Make predictions
    preds = model.predict(image_data)
    name_preds = dict(zip(image_names, preds.reshape(len(preds))))
    k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds[x['image_name']], axis=1)
    
    valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
    valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
    valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
    k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
# Out:
# FOLD: 1
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 0s 0us/step
# Epoch 1/15
# 323/323 - 100s - loss: 0.3741 - auc: 0.5748 - val_loss: 0.4535 - val_auc: 0.5916
# Epoch 2/15
# 323/323 - 98s - loss: 0.1700 - auc: 0.8375 - val_loss: 0.1729 - val_auc: 0.4602
# Epoch 3/15
# 323/323 - 98s - loss: 0.1670 - auc: 0.8630 - val_loss: 0.1714 - val_auc: 0.7357
# Epoch 4/15
# 323/323 - 99s - loss: 0.1640 - auc: 0.8758 - val_loss: 0.1675 - val_auc: 0.7814
# Epoch 5/15
# 323/323 - 98s - loss: 0.1665 - auc: 0.8747 - val_loss: 0.1801 - val_auc: 0.7005
# Epoch 6/15
# 323/323 - 98s - loss: 0.1632 - auc: 0.8845 - val_loss: 0.1701 - val_auc: 0.7224
# Epoch 7/15
# 323/323 - 98s - loss: 0.1635 - auc: 0.8802 - val_loss: 0.1668 - val_auc: 0.8307
# Epoch 8/15
# 323/323 - 98s - loss: 0.1617 - auc: 0.9002 - val_loss: 0.1737 - val_auc: 0.7782
# Epoch 9/15
# 323/323 - 98s - loss: 0.1597 - auc: 0.9078 - val_loss: 0.1669 - val_auc: 0.8450
# Epoch 10/15
# 323/323 - 98s - loss: 0.1579 - auc: 0.9099 - val_loss: 0.1693 - val_auc: 0.7808
# Epoch 11/15
# 323/323 - 98s - loss: 0.1552 - auc: 0.9264 - val_loss: 0.1652 - val_auc: 0.7612
# Epoch 12/15
# 323/323 - 98s - loss: 0.1523 - auc: 0.9361 - val_loss: 0.1676 - val_auc: 0.7438
# Epoch 13/15
# 323/323 - 98s - loss: 0.1510 - auc: 0.9469 - val_loss: 0.1891 - val_auc: 0.8191
# Epoch 14/15
# 323/323 - 97s - loss: 0.1454 - auc: 0.9593 - val_loss: 0.1702 - val_auc: 0.8419
# Epoch 15/15
# 323/323 - 98s - loss: 0.1423 - auc: 0.9678 - val_loss: 0.1660 - val_auc: 0.8425
#
# FOLD: 2
# Epoch 1/15
# 355/355 - 103s - loss: 0.5856 - auc: 0.5531 - val_loss: 0.2556 - val_auc: 0.4925
# Epoch 2/15
# 355/355 - 103s - loss: 0.1661 - auc: 0.8256 - val_loss: 0.1789 - val_auc: 0.4758
# Epoch 3/15
# 355/355 - 102s - loss: 0.1663 - auc: 0.8511 - val_loss: 0.1722 - val_auc: 0.7743
# Epoch 4/15
# 355/355 - 102s - loss: 0.1648 - auc: 0.8611 - val_loss: 0.1725 - val_auc: 0.7962
# Epoch 5/15
# 355/355 - 102s - loss: 0.1632 - auc: 0.8602 - val_loss: 0.1757 - val_auc: 0.8512
# Epoch 6/15
# 355/355 - 103s - loss: 0.1642 - auc: 0.8703 - val_loss: 0.1711 - val_auc: 0.8457
# Epoch 7/15
# 355/355 - 102s - loss: 0.1625 - auc: 0.8790 - val_loss: 0.1744 - val_auc: 0.8433
# Epoch 8/15
# 355/355 - 102s - loss: 0.1589 - auc: 0.9023 - val_loss: 0.1714 - val_auc: 0.8333
# Epoch 9/15
# 355/355 - 103s - loss: 0.1605 - auc: 0.9039 - val_loss: 0.1673 - val_auc: 0.8678
# Epoch 10/15
# 355/355 - 102s - loss: 0.1559 - auc: 0.9202 - val_loss: 0.1720 - val_auc: 0.8067
# Epoch 11/15
# 355/355 - 102s - loss: 0.1553 - auc: 0.9307 - val_loss: 0.1705 - val_auc: 0.8433
# Epoch 12/15
# 355/355 - 103s - loss: 0.1487 - auc: 0.9502 - val_loss: 0.1720 - val_auc: 0.8093
# Epoch 13/15
# 355/355 - 102s - loss: 0.1480 - auc: 0.9526 - val_loss: 0.1732 - val_auc: 0.8158
# Epoch 14/15
# Restoring model weights from the end of the best epoch.
# 355/355 - 102s - loss: 0.1416 - auc: 0.9723 - val_loss: 0.1730 - val_auc: 0.8028
# Epoch 00014: early stopping
#
# FOLD: 3
# Epoch 1/15
# 355/355 - 104s - loss: 0.4031 - auc: 0.5745 - val_loss: 0.4293 - val_auc: 0.3353
# Epoch 2/15
# 355/355 - 103s - loss: 0.1692 - auc: 0.8055 - val_loss: 0.1797 - val_auc: 0.5622
# Epoch 3/15
# 355/355 - 103s - loss: 0.1666 - auc: 0.8399 - val_loss: 0.1851 - val_auc: 0.7673
# Epoch 4/15
# 355/355 - 103s - loss: 0.1664 - auc: 0.8457 - val_loss: 0.1672 - val_auc: 0.8822
# Epoch 5/15
# 355/355 - 104s - loss: 0.1665 - auc: 0.8550 - val_loss: 0.1790 - val_auc: 0.8513
# Epoch 6/15
# 355/355 - 103s - loss: 0.1636 - auc: 0.8712 - val_loss: 0.1795 - val_auc: 0.8404
# Epoch 7/15
# 355/355 - 103s - loss: 0.1642 - auc: 0.8734 - val_loss: 0.1672 - val_auc: 0.8864
# Epoch 8/15
# 355/355 - 103s - loss: 0.1617 - auc: 0.8852 - val_loss: 0.1664 - val_auc: 0.8661
# Epoch 9/15
# 355/355 - 103s - loss: 0.1591 - auc: 0.9065 - val_loss: 0.1721 - val_auc: 0.7776
# Epoch 10/15
# 355/355 - 104s - loss: 0.1588 - auc: 0.9016 - val_loss: 0.1661 - val_auc: 0.8290
# Epoch 11/15
# 355/355 - 103s - loss: 0.1567 - auc: 0.9210 - val_loss: 0.1643 - val_auc: 0.8654
# Epoch 12/15
# 355/355 - 103s - loss: 0.1524 - auc: 0.9394 - val_loss: 0.1650 - val_auc: 0.8305
# Epoch 13/15
# 355/355 - 104s - loss: 0.1493 - auc: 0.9497 - val_loss: 0.1681 - val_auc: 0.8441
# Epoch 14/15
# 355/355 - 103s - loss: 0.1458 - auc: 0.9644 - val_loss: 0.1669 - val_auc: 0.8747
# Epoch 15/15
# 355/355 - 103s - loss: 0.1422 - auc: 0.9703 - val_loss: 0.1678 - val_auc: 0.8937

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(config['N_FOLDS']):
    print(f'Fold: {n_fold}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2

# %% [markdown]
# ## Model loss graph aggregated

# %%
plot_metrics_agg(history_list, config['N_FOLDS'])

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_89773314_b971_11ea_a8bb_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col3 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col0 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col6 {
#             color:  orange;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col0 {
#             color:  orange;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col1 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col4 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col5 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col6 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col7 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row3_col8 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col5 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_89773314_b971_11ea_a8bb_0242ac130202row5_col8 {
#             color:  green;
#         }</style><table id="T_89773314_b971_11ea_a8bb_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>    </tr>    <tr>        <th class="index_name level0" >Metric</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89773314_b971_11ea_a8bb_0242ac130202level0_row0" class="row_heading level0 row0" >ROC AUC</th>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col0" class="data row0 col0" >0.981039</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col1" class="data row0 col1" >0.869151</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col2" class="data row0 col2" >0.111888</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col3" class="data row0 col3" >0.994890</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col4" class="data row0 col4" >0.844608</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col5" class="data row0 col5" >0.953095</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col6" class="data row0 col6" >0.868985</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col7" class="data row0 col7" >0.995133</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row0_col8" class="data row0 col8" >0.893860</td>
#             </tr>
#             <tr>
#                         <th id="T_89773314_b971_11ea_a8bb_0242ac130202level0_row1" class="row_heading level0 row1" >Accuracy</th>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col0" class="data row1 col0" >0.991301</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col1" class="data row1 col1" >0.980465</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col2" class="data row1 col2" >0.010836</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col3" class="data row1 col3" >0.995459</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col4" class="data row1 col4" >0.981490</td>
#                         <td id="T_89773314_b971_11ea_a8bb_0242ac130202row1_col5" cla

# %% [markdown]
# # Model evaluation by Subset

# %%
display(evaluate_model_Subset(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row7_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col6 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col7 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row8_col8 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col0 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col1 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col2 {
#             color:  red;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col3 {
#             color:  green;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col4 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col5 {
#             color:  black;
#         }    #T_89bd4d18_b971_11ea_a8bb_0242ac130202row9_col6 {
#             color:  bl

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold[k_fold[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold[k_fold[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# ## ROC Curve

# %%
k_fold['pred'] = 0
for n_fold in range(config['N_FOLDS']):
    n_fold +=1
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold}'] / config['N_FOLDS']
    
for n_fold in range(config['N_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold[k_fold[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold[k_fold[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    
    plot_auc_curve(train_set['target'], train_set['pred'], valid_set['target'], valid_set['pred'])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Visualize predictions

# %%
   
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))


print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred >= .5').head(10))
# Out:
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 0  ISIC_2637011    male        45.0                     head/neck   unknown
# 1  ISIC_0015719  female        45.0               upper extremity   unknown
# 2  ISIC_0052212  female        50.0               lower extremity     nevus
# 3  ISIC_0068279  female        45.0                     head/neck   unknown
# 4  ISIC_0074268  female        55.0               upper extremity   unknown
# 5  ISIC_0074311  female        40.0               lower extremity   unknown
# 6  ISIC_0074542    male        25.0               lower extremity   unknown
# 7  ISIC_0075663  female        35.0                         torso   unknown
# 8  ISIC_0075914    male        30.0                         torso   unknown
# 9  ISIC_0076262  female        50.0               lower extremity   unknown
#
#    target      pred  pred_fold_1  pred_fold_2  pred_fold_3
# 0       0  0.021278     0.018404     0.027257     0.018172
# 1       0  0.021875     0.019256     0.016846     0.029523
# 2       0  0.022319     0.023295     0.015076     0.028588
# 3       0  0.026898     0.019921     0.034944     0.025827
# 4       0  0.020466     0.021112     0.020442     0.019844
# 5       0  0.021862     0.019716     0.020019     0.025852
# 6       0  0.025751     0.017089     0.036965     0.023199
# 7       0  0.022320     0.012477     0.026754     0.027728
# 8       0  0.022750     0.027527     0.018988     0.021736
# 9       0  0.028932     0.034700     0.017898     0.034196
# Top 10 positive samples
#        image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 91   ISIC_0149568  female        55.0               upper extremity  melanoma
# 235  ISIC_0188432  female        50.0               upper extremity  melanoma
# 314  ISIC_0207268    male        55.0                         torso  melanoma
# 399  ISIC_0232101    male        65.0                         torso  melanoma
# 459  ISIC_0247330  female        65.0               lower extremity  melanoma
# 475  ISIC_0250839    male        75.0                     head/neck  melanoma
# 544  ISIC_0272509  female        35.0               lower extremity  melanoma
# 546  ISIC_0273046    male        80.0                         torso  melanoma
# 551  ISIC_0274382    male        65.0                         torso  melanoma
# 558  ISIC_0275828    male        30.0               lower extremity  melanoma
#
#      target      pred  pred_fold_1  pred_fold_2  pred_fold_3
# 91        1  0.333155     0.022367     0.091134     0.885963
# 235       1  0.423849     0.031691     0.243147     0.996708
# 314       1  0.591037     0.741210     0.072606     0.959296
# 399       1  0.144716     0.013667     0.073868     0.346612
# 459       1  0.381059     0.026817     0.116444     0.999914
# 475       1  0.689382     0.990090     0.078392     0.999663
# 544       1  0.542267     0.741229     0.068597     0.816974
# 546       1  0.331138     0.038630     0.073727     0.881056
# 551       1  0.359950     0.224700     0.204850     0.650300
# 558       1  0.659488     0.925606     0.054235     0.998624
# Top 10 predicted positive samples
#         image_name     sex  age_approx anatom_site_general_challenge  \
# 314   ISIC_0207268    male        55.0                         torso
# 475   ISIC_0250839    male        75.0                     head/neck
# 544   ISIC_0272509  female        35.0               lower extremity
# 558   ISIC_0275828    male        30.0               lower extremity
# 758   ISIC_0333091    male        25.0               lower extremity
# 774   ISIC_0337631  female        55.0                         torso
# 886   ISIC_0369831    male        80.0               upper extremity
# 1335  ISIC_0504165  female        60.0               lower extremity
# 1423  ISIC_0528044    male        65.0                         torso
# 1435  ISIC_0533122    male        75.0               lower extremity
#
#      diagnosis  target      pred  pred_fold_1  pred_fold_2  pred_fold_3
# 314   melanoma       1  0.591037     0.741210     0.072606     0.959296
# 475   melanoma       1  0.689382     0.990090     0.078392     0.999663
# 544   melanoma       1  0.542267     0.741229     0.068597     0.816974
# 558   melanoma       1  0.659488     0.925606     0.054235     0.998624
# 758   melanoma       1  0.698032     0.993877     0.101116     0.999103
# 774   melanoma       1  0.674179     0.971685     0.060613     0.990238
# 886   melanoma       1  0.575548     0.934585     0.260510     0.531550
# 1335  melanoma       1  0.874086     0.974053     0.656936     0.991270
# 1423  melanoma       1  0.847333     0.991419     0.576803     0.973778
# 1435  melanoma       1  0.571060     0.848496     0.257123     0.607562
