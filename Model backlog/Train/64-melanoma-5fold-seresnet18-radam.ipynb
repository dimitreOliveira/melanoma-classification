# %% [markdown]
# ## Dependencies

# %%
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
import warnings, json, re, glob, math
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
# import efficientnet.tfkeras as efn
from classification_models.tfkeras import Classifiers
import tensorflow_addons as tfa

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# REPLICAS:  1

# %% [markdown]
# # Model parameters

# %%
config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 64,
  "EPOCHS": 25,
  "LEARNING_RATE": 3e-4,
  "ES_PATIENCE": 10,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 5,
  "TTA_STEPS": 25,
  "BASE_MODEL": 'seresnet18',
  "BASE_MODEL_WEIGHTS": 'imagenet',
  "DATASET_PATH": 'melanoma-256x256'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'HEIGHT': 256,
#  'WIDTH': 256,
#  'CHANNELS': 3,
#  'BATCH_SIZE': 64,
#  'EPOCHS': 25,
#  'LEARNING_RATE': 0.0003,
#  'ES_PATIENCE': 10,
#  'N_FOLDS': 5,
#  'N_USED_FOLDS': 5,
#  'TTA_STEPS': 25,
#  'BASE_MODEL': 'seresnet18',
#  'BASE_MODEL_WEIGHTS': 'imagenet',
#  'DATASET_PATH': 'melanoma-256x256'}

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/siim-isic-melanoma-classification/'
k_fold = pd.read_csv(database_base_path + 'train.csv')
test = pd.read_csv(database_base_path + 'test.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())
print(f'Test samples: {len(test)}')
display(test.head())

GCS_PATH = KaggleDatasets().get_gcs_path(config['DATASET_PATH'])
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0
# Test samples: 10982
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Augmentations

# %%
def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_pixel = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    ### Spatial-level transforms
    if p_spatial >= .2: # flips
        image['input_image'] = tf.image.random_flip_left_right(image['input_image'])
        image['input_image'] = tf.image.random_flip_up_down(image['input_image'])
        if p_spatial >= .7:
            image['input_image'] = tf.image.transpose(image['input_image'])
            
    if p_rotate >= .8: # rotate 270º
        image['input_image'] = tf.image.rot90(image['input_image'], k=3)
    elif p_rotate >= .6: # rotate 180º
        image['input_image'] = tf.image.rot90(image['input_image'], k=2)
    elif p_rotate >= .4: # rotate 90º
        image['input_image'] = tf.image.rot90(image['input_image'], k=1)
        
    if p_spatial2 >= .6:
        if p_spatial2 >= .9:
            image['input_image'] = transform_rotation(image['input_image'], config['HEIGHT'], 180.)
        elif p_spatial2 >= .8:
            image['input_image'] = transform_zoom(image['input_image'], config['HEIGHT'], 8., 8.)
        elif p_spatial2 >= .7:
            image['input_image'] = transform_shift(image['input_image'], config['HEIGHT'], 8., 8.)
        else:
            image['input_image'] = transform_shear(image['input_image'], config['HEIGHT'], 2.)
        
    if p_crop >= .6: # crops
        if p_crop >= .8:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']])
        elif p_crop >= .7:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']])
        else:
            image['input_image'] = tf.image.central_crop(image['input_image'], central_fraction=.8)
        image['input_image'] = tf.image.resize(image['input_image'], size=[config['HEIGHT'], config['WIDTH']])

    if p_pixel >= .6: # Pixel-level transforms
        if p_pixel >= .9:
            image['input_image'] = tf.image.random_hue(image['input_image'], 0.01)
        elif p_pixel >= .8:
            image['input_image'] = tf.image.random_saturation(image['input_image'], 0.7, 1.3)
        elif p_pixel >= .7:
            image['input_image'] = tf.image.random_contrast(image['input_image'], 0.8, 1.2)
        else:
            image['input_image'] = tf.image.random_brightness(image['input_image'], 0.1)

    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
# Datasets utility functions
def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)

def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Test function
def read_unlabeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_tabular': data}, image_name # returns a dataset of (image, data, image_name)

def load_dataset_test(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_unlabeled_tfrecord, num_parallel_calls=buffer_size)
    # returns a dataset of (image, data, label, image_name) pairs if labeled=True or (image, data, image_name) pairs if labeled=False
    return dataset

def get_test_dataset(filenames, batch_size=32, buffer_size=-1, tta=False):
    dataset = load_dataset_test(filenames, buffer_size=buffer_size)
    if tta:
      dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Advanced augmentations
def transform_rotation(image, height, rotation):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    rotation = rotation * tf.random.normal([1],dtype='float32')
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape( tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(rotation_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_shear(image, height, shear):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly sheared
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    shear = shear * tf.random.normal([1],dtype='float32')
    shear = math.pi * shear / 180.
        
    # SHEAR MATRIX
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape( tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3] )    

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shear_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_shift(image, height, h_shift, w_shift):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly shifted
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    height_shift = h_shift * tf.random.normal([1],dtype='float32') 
    width_shift = w_shift * tf.random.normal([1],dtype='float32') 
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
        
    # SHIFT MATRIX
    shift_matrix = tf.reshape( tf.concat([one,zero,height_shift, zero,one,width_shift, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shift_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_zoom(image, height, h_zoom, w_zoom):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly zoomed
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    height_zoom = 1.0 + tf.random.normal([1],dtype='float32')/h_zoom
    width_zoom = 1.0 + tf.random.normal([1],dtype='float32')/w_zoom
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
        
    # ZOOM MATRIX
    zoom_matrix = tf.reshape( tf.concat([one/height_zoom,zero,zero, zero,one/width_zoom,zero, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(zoom_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

# %% [markdown]
# ## Learning rate scheduler

# %%
lr_min = 1e-6
# lr_start = 0
lr_max = config['LEARNING_RATE']
steps_per_epoch = 24844 // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * steps_per_epoch
warmup_steps = steps_per_epoch * 5
# hold_max_steps = 0
# step_decay = .8
# step_size = steps_per_epoch * 1

# rng = [i for i in range(0, total_steps, 32)]
# y = [step_schedule_with_warmup(tf.cast(x, tf.float32), step_size=step_size, 
#                                warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
#                                lr_start=lr_start, lr_max=lr_max, step_decay=step_decay) for x in rng]

# sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20, 6))
# plt.plot(rng, y)
# print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))

# %% [markdown]
# # Model

# %%
# Initial bias
pos = len(k_fold[k_fold['target'] == 1])
neg = len(k_fold[k_fold['target'] == 0])
initial_bias = np.log([pos/neg])
print('Bias')
print(pos)
print(neg)
print(initial_bias)

# class weights
total = len(k_fold)
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print('Class weight')
print(class_weight)
# Out:
# Bias
# 584
# 32542
# [-4.02038586]
# Class weight
# {0: 0.5089730194825148, 1: 28.36130136986301}

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    BaseModel, preprocess_input = Classifiers.get(config['BASE_MODEL'])
    base_model = BaseModel(input_shape=input_shape, 
                           weights=config['BASE_MODEL_WEIGHTS'], 
                           include_top=False)
    
    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    
    output = L.Dense(1, activation='sigmoid', name='output', 
                     bias_initializer=tf.keras.initializers.Constant(initial_bias))(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
# Evaluation
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(TRAINING_FILENAMES)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)
# Resample dataframe
k_fold = k_fold[k_fold['image_name'].isin(image_names)]

# Test
NUM_TEST_IMAGES = len(test)
test_preds = np.zeros((NUM_TEST_IMAGES, 1))
test_preds_last = np.zeros((NUM_TEST_IMAGES, 1))

test_dataset = get_test_dataset(TEST_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO, tta=True)
image_names_test = next(iter(test_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TEST_IMAGES))).numpy().astype('U')
test_image_data = test_dataset.map(lambda data, image_name: data)


history_list = []
k_fold_best = k_fold.copy()
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)

for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    if n_fold < config['N_USED_FOLDS']:
        n_fold +=1
        print('\nFOLD: %d' % (n_fold))
#         tf.tpu.experimental.initialize_tpu_system(tpu)
        K.clear_session()

        ### Data
        train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
        valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
        steps_per_epoch  = count_data_items(train_filenames) // config['BATCH_SIZE']

        # Train model
        model_path = f'model_fold_{n_fold}.h5'

        es = EarlyStopping(monitor='val_auc', mode='max', patience=config['ES_PATIENCE'], 
                           restore_best_weights=False, verbose=1)
        checkpoint = ModelCheckpoint(model_path, monitor='val_auc', mode='max', 
                                     save_best_only=True, save_weights_only=True)

        with strategy.scope():
            model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))

            optimizer = tfa.optimizers.RectifiedAdam(lr=lr_max,
                                                     total_steps=total_steps,
                                                     warmup_proportion=(warmup_steps / total_steps),
                                                     min_lr=lr_min)
            model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                          metrics=[metrics.AUC()])

        history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                                   batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            epochs=config['EPOCHS'], 
                            steps_per_epoch=steps_per_epoch,
                            callbacks=[checkpoint, es],
                            class_weight=class_weight, 
                            verbose=2).history

        # save last epoch weights
        model.save_weights('last_' + model_path)

        history_list.append(history)

        # Get validation IDs
        valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
        valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
        k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        k_fold_best[f'fold_{n_fold}'] = k_fold_best.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        
        ##### Last model #####
        print('Last model evaluation...')
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Last model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds_last += model.predict(test_image_data)

        ##### Best model #####
        print('Best model evaluation...')
        model.load_weights(model_path)
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold_best[f'pred_fold_{n_fold}'] = k_fold_best.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Best model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds += model.predict(test_image_data)


# normalize preds
test_preds /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])
test_preds_last /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])

name_preds = dict(zip(image_names_test, test_preds.reshape(NUM_TEST_IMAGES)))
name_preds_last = dict(zip(image_names_test, test_preds_last.reshape(NUM_TEST_IMAGES)))

test['target'] = test.apply(lambda x: name_preds[x['image_name']], axis=1)
test['target_last'] = test.apply(lambda x: name_preds_last[x['image_name']], axis=1)
# Out:
# FOLD: 1
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/seresnet18_imagenet_1000_no_top.h5
# 45359104/45351256 [==============================] - 4s 0us/step
# Epoch 1/25
# 408/408 - 147s - loss: 0.7536 - auc: 0.7313 - val_loss: 0.1771 - val_auc: 0.5180
# Epoch 2/25
# 408/408 - 144s - loss: 0.5032 - auc: 0.8513 - val_loss: 0.1900 - val_auc: 0.7332
# Epoch 3/25
# 408/408 - 145s - loss: 0.5233 - auc: 0.8501 - val_loss: 0.3951 - val_auc: 0.8278
# Epoch 4/25
# 408/408 - 146s - loss: 0.5291 - auc: 0.8503 - val_loss: 0.5892 - val_auc: 0.8244
# Epoch 5/25
# 408/408 - 146s - loss: 0.5110 - auc: 0.8528 - val_loss: 0.3490 - val_auc: 0.8255
# Epoch 6/25
# 408/408 - 139s - loss: 0.4682 - auc: 0.8814 - val_loss: 0.6515 - val_auc: 0.8535
# Epoch 7/25
# 408/408 - 142s - loss: 0.4610 - auc: 0.8793 - val_loss: 0.3841 - val_auc: 0.8673
# Epoch 8/25
# 408/408 - 141s - loss: 0.4458 - auc: 0.8894 - val_loss: 0.3039 - val_auc: 0.8412
# Epoch 9/25
# 408/408 - 141s - loss: 0.4535 - auc: 0.8867 - val_loss: 0.5310 - val_auc: 0.8819
# Epoch 10/25
# 408/408 - 142s - loss: 0.4385 - auc: 0.8951 - val_loss: 0.6995 - val_auc: 0.8433
# Epoch 11/25
# 408/408 - 141s - loss: 0.4285 - auc: 0.8992 - val_loss: 0.3153 - val_auc: 0.8760
# Epoch 12/25
# 408/408 - 139s - loss: 0.4083 - auc: 0.9143 - val_loss: 0.5465 - val_auc: 0.8659
# Epoch 13/25
# 408/408 - 142s - loss: 0.4043 - auc: 0.9146 - val_loss: 0.2805 - val_auc: 0.8740
# Epoch 14/25
# 408/408 - 141s - loss: 0.3886 - auc: 0.9253 - val_loss: 0.4161 - val_auc: 0.8632
# Epoch 15/25
# 408/408 - 143s - loss: 0.3700 - auc: 0.9338 - val_loss: 0.4457 - val_auc: 0.8666
# Epoch 16/25
# 408/408 - 141s - loss: 0.3674 - auc: 0.9356 - val_loss: 0.3412 - val_auc: 0.8839
# Epoch 17/25
# 408/408 - 140s - loss: 0.3375 - auc: 0.9480 - val_loss: 0.3924 - val_auc: 0.8703
# Epoch 18/25
# 408/408 - 142s - loss: 0.3237 - auc: 0.9544 - val_loss: 0.2758 - val_auc: 0.8552
# Epoch 19/25
# 408/408 - 143s - loss: 0.3311 - auc: 0.9535 - val_loss: 0.3325 - val_auc: 0.8610
# Epoch 20/25
# 408/408 - 140s - loss: 0.2902 - auc: 0.9680 - val_loss: 0.2184 - val_auc: 0.8552
# Epoch 21/25
# 408/408 - 145s - loss: 0.2846 - auc: 0.9694 - val_loss: 0.2595 - val_auc: 0.8624
# Epoch 22/25
# 408/408 - 143s - loss: 0.2552 - auc: 0.9785 - val_loss: 0.2535 - val_auc: 0.8693
# Epoch 23/25
# 408/408 - 145s - loss: 0.2528 - auc: 0.9791 - val_loss: 0.2828 - val_auc: 0.8782
# Epoch 24/25
# 408/408 - 143s - loss: 0.2380 - auc: 0.9839 - val_loss: 0.2587 - val_auc: 0.8695
# Epoch 25/25
# 408/408 - 140s - loss: 0.2331 - auc: 0.9850 - val_loss: 0.2575 - val_auc: 0.8700
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 2
# Epoch 1/25
# 408/408 - 145s - loss: 1.4535 - auc: 0.6980 - val_loss: 0.1884 - val_auc: 0.4463
# Epoch 2/25
# 408/408 - 143s - loss: 0.5506 - auc: 0.8422 - val_loss: 0.1974 - val_auc: 0.7122
# Epoch 3/25
# 408/408 - 143s - loss: 0.5113 - auc: 0.8634 - val_loss: 0.2947 - val_auc: 0.8525
# Epoch 4/25
# 408/408 - 144s - loss: 0.5339 - auc: 0.8479 - val_loss: 0.6366 - val_auc: 0.7912
# Epoch 5/25
# 408/408 - 139s - loss: 0.5006 - auc: 0.8572 - val_loss: 0.7557 - val_auc: 0.8531
# Epoch 6/25
# 408/408 - 140s - loss: 0.4760 - auc: 0.8725 - val_loss: 0.2821 - val_auc: 0.8140
# Epoch 7/25
# 408/408 - 146s - loss: 0.4729 - auc: 0.8781 - val_loss: 0.4087 - val_auc: 0.8631
# Epoch 8/25
# 408/408 - 139s - loss: 0.4344 - auc: 0.9005 - val_loss: 0.3831 - val_auc: 0.8518
# Epoch 9/25
# 408/408 - 138s - loss: 0.4148 - auc: 0.9081 - val_loss: 0.3328 - val_auc: 0.8447
# Epoch 10/25
# 408/408 - 139s - loss: 0.4234 - auc: 0.9058 - val_loss: 0.2685 - val_auc: 0.8798
# Epoch 11/25
# 408/408 - 142s - loss: 0.4121 - auc: 0.9129 - val_loss: 0.3698 - val_auc: 0.8625
# Epoch 12/25
# 408/408 - 139s - loss: 0.4006 - auc: 0.9194 - val_loss: 0.3287 - val_auc: 0.8915
# Epoch 13/25
# 408/408 - 139s - loss: 0.3891 - auc: 0.9254 - val_loss: 0.6094 - val_auc: 0.8477
# Epoch 14/25
# 408/408 - 141s - loss: 0.3815 - auc: 0.9255 - val_loss: 0.3927 - val_auc: 0.8242
# Epoch 15/25
# 408/408 - 139s - loss: 0.3694 - auc: 0.9361 - val_loss: 0.3596 - val_auc: 0.8811
# Epoch 16/25
# 408/408 - 139s - loss: 0.3507 - auc: 0.9424 - val_loss: 0.3919 - val_auc: 0.8972
# Epoch 17/25
# 408/408 - 139s - loss: 0.3349 - auc: 0.9512 - val_loss: 0.3917 - val_auc: 0.8796
# Epoch 18/25
# 408/408 - 138s - loss: 0.3244 - auc: 0.9568 - val_loss: 0.4386 - val_auc: 0.8936
# Epoch 19/25
# 408/408 - 140s - loss: 0.3032 - auc: 0.9635 - val_loss: 0.2599 - val_auc: 0.8978
# Epoch 20/25
# 408/408 - 139s - loss: 0.2978 - auc: 0.9653 - val_loss: 0.2680 - val_auc: 0.8872
# Epoch 21/25
# 408/408 - 141s - loss: 0.2585 - auc: 0.9775 - val_loss: 0.3013 - val_auc: 0.8902
# Epoch 22/25
# 408/408 - 139s - loss: 0.2553 - auc: 0.9792 - val_loss: 0.2838 - val_auc: 0.9049
# Epoch 23/25
# 408/408 - 141s - loss: 0.2520 - auc: 0.9792 - val_loss: 0.2890 - val_auc: 0.9038
# Epoch 24/25
# 408/408 - 140s - loss: 0.2374 - auc: 0.9841 - val_loss: 0.2680 - val_auc: 0.9005
# Epoch 25/25
# 408/408 - 139s - loss: 0.2374 - auc: 0.9843 - val_loss: 0.2697 - val_auc: 0.9005
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 3
# Epoch 1/25
# 408/408 - 149s - loss: 1.1720 - auc: 0.7271 - val_loss: 0.1744 - val_auc: 0.6360
# Epoch 2/25
# 408/408 - 149s - loss: 0.5507 - auc: 0.8441 - val_loss: 0.1939 - val_auc: 0.6844
# Epoch 3/25
# 408/408 - 148s - loss: 0.5058 - auc: 0.8589 - val_loss: 0.3885 - val_auc: 0.8607
# Epoch 4/25
# 408/408 - 150s - loss: 0.5285 - auc: 0.8505 - val_loss: 0.4079 - val_auc: 0.8370
# Epoch 5/25
# 408/408 - 149s - loss: 0.4942 - auc: 0.8637 - val_loss: 0.5155 - val_auc: 0.8279
# Epoch 6/25
# 408/408 - 150s - loss: 0.4860 - auc: 0.8649 - val_loss: 0.5217 - val_auc: 0.8420
# Epoch 7/25
# 408/408 - 145s - loss: 0.4461 - auc: 0.8891 - val_loss: 0.5477 - val_auc: 0.7847
# Epoch 8/25
# 408/408 - 148s - loss: 0.4492 - auc: 0.8907 - val_loss: 0.4068 - val_auc: 0.8478
# Epoch 9/25
# 408/408 - 145s - loss: 0.4383 - auc: 0.8924 - val_loss: 0.3346 - val_auc: 0.8607
# Epoch 10/25
# 408/408 - 148s - loss: 0.4140 - auc: 0.9097 - val_loss: 0.4308 - val_auc: 0.8583
# Epoch 11/25
# 408/408 - 143s - loss: 0.4326 - auc: 0.9001 - val_loss: 0.3784 - val_auc: 0.8515
# Epoch 12/25
# 408/408 - 145s - loss: 0.4062 - auc: 0.9162 - val_loss: 0.2820 - val_auc: 0.8529
# Epoch 13/25
# 408/408 - 152s - loss: 0.3969 - auc: 0.9224 - val_loss: 0.5535 - val_auc: 0.8801
# Epoch 14/25
# 408/408 - 147s - loss: 0.3705 - auc: 0.9303 - val_loss: 0.3018 - val_auc: 0.8591
# Epoch 15/25
# 408/408 - 150s - loss: 0.3705 - auc: 0.9347 - val_loss: 0.4215 - val_auc: 0.8524
# Epoch 16/25
# 408/408 - 143s - loss: 0.3468 - auc: 0.9420 - val_loss: 0.3081 - val_auc: 0.8652
# Epoch 17/25
# 408/408 - 150s - loss: 0.3313 - auc: 0.9511 - val_loss: 0.2978 - val_auc: 0.8725
# Epoch 18/25
# 408/408 - 146s - loss: 0.3187 - auc: 0.9567 - val_loss: 0.2542 - val_auc: 0.8754
# Epoch 19/25
# 408/408 - 150s - loss: 0.2957 - auc: 0.9648 - val_loss: 0.2455 - val_auc: 0.8672
# Epoch 20/25
# 408/408 - 145s - loss: 0.2855 - auc: 0.9697 - val_loss: 0.2919 - val_auc: 0.8630
# Epoch 21/25
# 408/408 - 148s - loss: 0.2806 - auc: 0.9714 - val_loss: 0.2798 - val_auc: 0.8683
# Epoch 22/25
# 408/408 - 145s - loss: 0.2517 - auc: 0.9785 - val_loss: 0.3469 - val_auc: 0.8822
# Epoch 23/25
# 408/408 - 148s - loss: 0.2355 - auc: 0.9841 - val_loss: 0.3256 - val_auc: 0.8883
# Epoch 24/25
# 408/408 - 147s - loss: 0.2316 - auc: 0.9851 - val_loss: 0.2705 - val_auc: 0.8842
# Epoch 25/25
# 408/408 - 143s - loss: 0.2232 - auc: 0.9873 - val_loss: 0.2706 - val_auc: 0.8848
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 4
# Epoch 1/25
# 408/408 - 150s - loss: 1.3047 - auc: 0.7255 - val_loss: 0.2129 - val_auc: 0.3756
# Epoch 2/25
# 408/408 - 149s - loss: 0.5269 - auc: 0.8519 - val_loss: 0.2027 - val_auc: 0.6503
# Epoch 3/25
# 408/408 - 148s - loss: 0.5088 - auc: 0.8602 - val_loss: 0.3177 - val_auc: 0.8657
# Epoch 4/25
# 408/408 - 146s - loss: 0.4965 - auc: 0.8637 - val_loss: 0.3331 - val_auc: 0.8419
# Epoch 5/25
# 408/408 - 148s - loss: 0.5099 - auc: 0.8562 - val_loss: 0.3309 - val_auc: 0.8765
# Epoch 6/25
# 408/408 - 140s - loss: 0.4817 - auc: 0.8662 - val_loss: 1.0217 - val_auc: 0.8450
# Epoch 7/25
# 408/408 - 143s - loss: 0.4676 - auc: 0.8770 - val_loss: 0.3531 - val_auc: 0.8796
# Epoch 8/25
# 408/408 - 141s - loss: 0.4693 - auc: 0.8751 - val_loss: 0.5131 - val_auc: 0.9037
# Epoch 9/25
# 408/408 - 142s - loss: 0.4275 - auc: 0.8990 - val_loss: 0.3979 - val_auc: 0.8893
# Epoch 10/25
# 408/408 - 142s - loss: 0.4374 - auc: 0.8914 - val_loss: 0.8738 - val_auc: 0.8437
# Epoch 11/25
# 408/408 - 142s - loss: 0.4223 - auc: 0.9046 - val_loss: 0.3543 - val_auc: 0.8808
# Epoch 12/25
# 408/408 - 142s - loss: 0.4182 - auc: 0.9067 - val_loss: 0.3024 - val_auc: 0.8862
# Epoch 13/25
# 408/408 - 144s - loss: 0.4118 - auc: 0.9144 - val_loss: 1.0908 - val_auc: 0.8471
# Epoch 14/25
# 408/408 - 143s - loss: 0.4006 - auc: 0.9190 - val_loss: 0.4312 - val_auc: 0.8784
# Epoch 15/25
# 408/408 - 142s - loss: 0.3657 - auc: 0.9344 - val_loss: 0.2889 - val_auc: 0.8589
# Epoch 16/25
# 408/408 - 142s - loss: 0.3656 - auc: 0.9353 - val_loss: 0.4130 - val_auc: 0.8836
# Epoch 17/25
# 408/408 - 142s - loss: 0.3435 - auc: 0.9453 - val_loss: 0.3969 - val_auc: 0.8719
# Epoch 18/25
# 408/408 - 142s - loss: 0.3292 - auc: 0.9503 - val_loss: 0.5234 - val_auc: 0.8915
# Epoch 00018: early stopping
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...
#
# FOLD: 5
# Epoch 1/25
# 408/408 - 138s - loss: 1.1062 - auc: 0.7312 - val_loss: 0.1750 - val_auc: 0.4583
# Epoch 2/25
# 408/408 - 138s - loss: 0.5368 - auc: 0.8487 - val_loss: 0.2057 - val_auc: 0.5969
# Epoch 3/25
# 408/408 - 141s - loss: 0.5105 - auc: 0.8574 - val_loss: 0.5717 - val_auc: 0.8518
# Epoch 4/25
# 408/408 - 140s - loss: 0.5071 - auc: 0.8597 - val_loss: 0.4976 - val_auc: 0.8366
# Epoch 5/25
# 408/408 - 146s - loss: 0.5105 - auc: 0.8546 - val_loss: 0.3420 - val_auc: 0.8437
# Epoch 6/25
# 408/408 - 140s - loss: 0.4721 - auc: 0.8772 - val_loss: 0.3763 - val_auc: 0.8288
# Epoch 7/25
# 408/408 - 141s - loss: 0.4629 - auc: 0.8822 - val_loss: 0.4596 - val_auc: 0.8585
# Epoch 8/25
# 408/408 - 143s - loss: 0.4467 - auc: 0.8933 - val_loss: 0.5264 - val_auc: 0.8700
# Epoch 9/25
# 408/408 - 142s - loss: 0.4328 - auc: 0.8978 - val_loss: 0.4177 - val_auc: 0.8681
# Epoch 10/25
# 408/408 - 142s - loss: 0.4295 - auc: 0.9040 - val_loss: 0.2681 - val_auc: 0.8794
# Epoch 11/25
# 408/408 - 143s - loss: 0.4001 - auc: 0.9158 - val_loss: 0.3823 - val_auc: 0.8509
# Epoch 12/25
# 408/408 - 141s - loss: 0.4058 - auc: 0.9154 - val_loss: 0.3573 - val_auc: 0.8603
# Epoch 13/25
# 408/408 - 141s - loss: 0.3936 - auc: 0.9226 - val_loss: 0.4060 - val_auc: 0.8714
# Epoch 14/25
# 408/408 - 142s - loss: 0.3788 - auc: 0.9292 - val_loss: 0.5670 - val_auc: 0.8686
# Epoch 15/25
# 408/408 - 141s - loss: 0.3713 - auc: 0.9336 - val_loss: 0.5811 - val_auc: 0.8503
# Epoch 16/25
# 408/408 - 143s - loss: 0.3567 - auc: 0.9418 - val_loss: 0.2765 - val_auc: 0.8795
# Epoch 17/25
# 408/408 - 142s - loss: 0.3378 - auc: 0.9480 - val_loss: 0.5983 - val_auc: 0.8812
# Epoch 18/25
# 408/408 - 141s - loss: 0.3140 - auc: 0.9601 - val_loss: 0.2750 - val_auc: 0.8484
# Epoch 19/25
# 408/408 - 142s - loss: 0.3175 - auc: 0.9590 - val_loss: 0.3299 - val_auc: 0.8727
# Epoch 20/25
# 408/408 - 141s - loss: 0.2859 - auc: 0.9698 - val_loss: 0.3239 - val_auc: 0.8892
# Epoch 21/25
# 408/408 - 143s - loss: 0.2695 - auc: 0.9745 - val_loss: 0.2528 - val_auc: 0.8865
# Epoch 22/25
# 408/408 - 144s - loss: 0.2526 - auc: 0.9795 - val_loss: 0.2476 - val_auc: 0.8705
# Epoch 23/25
# 408/408 - 141s - loss: 0.2444 - auc: 0.9823 - val_loss: 0.2859 - val_auc: 0.8829
# Epoch 24/25
# 408/408 - 143s - loss: 0.2326 - auc: 0.9857 - val_loss: 0.2601 - val_auc: 0.8804
# Epoch 25/25
# 408/408 - 140s - loss: 0.2301 - auc: 0.9853 - val_loss: 0.2612 - val_auc: 0.8816
# Last model evaluation...
# Last model inference (TTA 25 steps)...
# Best model evaluation...
# Best model inference (TTA 25 steps)...

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(config['N_USED_FOLDS']):
    print(f'Fold: {n_fold + 1}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# ## Model loss graph aggregated

# %%
plot_metrics_agg(history_list, config['N_USED_FOLDS'])

# %% [markdown]
# # Model evaluation (best)

# %%
display(evaluate_model(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col0 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col3 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col5 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col7 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col9 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col11 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col0 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col3 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col5 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col7 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col9 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col11 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_5a08fda2_c3b6_11ea_b987_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_5a08fda2_c3b6_11ea_b987_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <tr
# <style  type="text/css" >
#     #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col5 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col11 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col3 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col5 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col7 {
#             color:  green;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_5a809ed4_c3b6_11ea_b987_0242ac130202row6_col9

# %% [markdown]
# # Model evaluation (last)

# %%
display(evaluate_model(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col3 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col11 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col5 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col11 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col0 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col1 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col3 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col4 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col5 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col6 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col7 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col8 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col9 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col10 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col11 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row2_col12 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col0 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col4 {
#             color:  orange;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col5 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col11 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row3_col12 {
#             color:  orange;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col0 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col1 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col3 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col4 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col5 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col6 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col7 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col8 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col9 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col10 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col11 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row4_col12 {
#             color:  red;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col8 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col9 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col10 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_5ac79a8c_c3b6_11ea_b987_0242ac130202row5_col12 {
#             color:  green;
#         }</style><table id="T_5ac79a8c_c3b6_11ea_b987_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <
# <style  type="text/css" >
#     #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col11 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row0_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col11 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row1_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col0 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col11 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row2_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col11 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row3_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col11 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row4_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col9 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col10 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col11 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row5_col12 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col0 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col1 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col2 {
#             color:  red;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col3 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col4 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col5 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col6 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col7 {
#             color:  green;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col8 {
#             color:  black;
#         }    #T_5b5200aa_c3b6_11ea_b987_0242ac130202row6_col9

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_USED_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
k_fold['pred'] = 0
for n_fold in range(config['N_USED_FOLDS']):
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold+1}'] / config['N_FOLDS']

print('Label/prediction distribution')
print(f"Train positive labels: {len(k_fold[k_fold['target'] > .5])}")
print(f"Train positive predictions: {len(k_fold[k_fold['pred'] > .5])}")
print(f"Train positive correct predictions: {len(k_fold[(k_fold['target'] > .5) & (k_fold['pred'] > .5)])}")
    
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))

print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred > .5').head(10))
# Out:
# Label/prediction distribution
# Train positive labels: 581
# Train positive predictions: 2647
# Train positive correct predictions: 578
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 0  ISIC_2637011    male        45.0                     head/neck   unknown
# 1  ISIC_0015719  female        45.0               upper extremity   unknown
# 2  ISIC_0052212  female        50.0               lower extremity     nevus
# 3  ISIC_0068279  female        45.0                     head/neck   unknown
# 4  ISIC_0074268  female        55.0               upper extremity   unknown
# 5  ISIC_0074311  female        40.0               lower extremity   unknown
# 6  ISIC_0074542    male        25.0               lower extremity   unknown
# 7  ISIC_0075663  female        35.0                         torso   unknown
# 8  ISIC_0075914    male        30.0                         torso   unknown
# 9  ISIC_0076262  female        50.0               lower extremity   unknown
#
#    target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 0       0  0.014662     0.012887     0.013090     0.033117     0.006386
# 1       0  0.016894     0.014004     0.021569     0.022702     0.004067
# 2       0  0.011610     0.006381     0.003450     0.035678     0.004493
# 3       0  0.024324     0.046146     0.014499     0.006924     0.016959
# 4       0  0.017168     0.016778     0.013983     0.011967     0.025218
# 5       0  0.020609     0.027454     0.015872     0.019112     0.027538
# 6       0  0.030765     0.015713     0.032051     0.016328     0.053658
# 7       0  0.032347     0.031719     0.018762     0.044314     0.036964
# 8       0  0.024523     0.019697     0.030316     0.021640     0.026620
# 9       0  0.326345     0.098600     0.073360     0.399524     0.902768
#
#    pred_fold_5
# 0     0.007828
# 1     0.022127
# 2     0.008047
# 3     0.037092
# 4     0.017896
# 5     0.013071
# 6     0.036075
# 7     0.029975
# 8     0.024343
# 9     0.157471
# Top 10 positive samples
#        image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 91   ISIC_0149568  female        55.0               upper extremity  melanoma
# 235  ISIC_0188432  female        50.0               upper extremity  melanoma
# 314  ISIC_0207268    male        55.0                         torso  melanoma
# 399  ISIC_0232101    male        65.0                         torso  melanoma
# 459  ISIC_0247330  female        65.0               lower extremity  melanoma
# 475  ISIC_0250839    male        75.0                     head/neck  melanoma
# 544  ISIC_0272509  female        35.0               lower extremity  melanoma
# 546  ISIC_0273046    male        80.0                         torso  melanoma
# 551  ISIC_0274382    male        65.0                         torso  melanoma
# 558  ISIC_0275828    male        30.0               lower extremity  melanoma
#
#      target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 91        1  0.767656     0.973166     0.904676     0.995183     0.944723
# 235       1  0.904102     0.917849     0.910640     0.938695     0.971351
# 314       1  0.877435     0.988048     0.993461     0.977772     0.472039
# 399       1  0.862353     0.970806     0.640756     0.871193     0.899543
# 459       1  0.737916     0.994712     0.993027     0.026639     0.996450
# 475       1  0.777976     0.991561     0.858580     0.914796     0.417336
# 544       1  0.832824     0.899188     0.448256     0.997668     0.845833
# 546       1  0.826963     0.862853     0.949921     0.907263     0.965364
# 551       1  0.926288     0.946939     0.961496     0.941313     0.980507
# 558       1  0.822046     0.903183     0.395876     0.900432     0.952888
#
#      pred_fold_5
# 91      0.020534
# 235     0.781975
# 314     0.955853
# 399     0.929468
# 459     0.678752
# 475     0.707607
# 544     0.973175
# 546     0.449414
# 551     0.801188
# 558     0.957849
# Top 10 predicted positive samples
#        image_name     sex  age_approx anatom_site_general_challenge diagnosis  \
# 10   ISIC_0076545    male        55.0               upper extremity   unknown
# 42   ISIC_0089738  female        70.0                         torso     nevus
# 76   ISIC_0120729    male        65.0               lower extremity   unknown
# 91   ISIC_0149568  female        55.0               upper extremity  melanoma
# 111  ISIC_0155012    male        55.0                         torso     nevus
# 123  ISIC_0159060    male        55.0                     head/neck   unknown
# 128  ISIC_0159996  female        60.0                     head/neck   unknown
# 131  ISIC_0160455    male        75.0               lower extremity     nevus
# 166  ISIC_0170059  female        60.0               lower extremity   unknown
# 168  ISIC_0170285  female        45.0               upper extremity   unknown
#
#      target      pred  pred_fold_1  pred_fold_2  pred_fold_3  pred_fold_4  \
# 10        0  0.836152     0.943696     0.877987     0.626369     0.893749
# 42        0  0.538680     0.743039     0.434614     0.069622     0.947150
# 76        0  0.506862     0.306928     0.579186     0.060722     0.883684
# 91        1  0.767656     0.973166     0.904676     0.995183     0.944723
# 111       0  0.648366     0.919202     0.463607     0.710665     0.608567
# 123       0  0.627013     0.386620     0.813668     0.686527     0.978138
# 128       0  0.686774     0.564385     0.700522     0.595876     0.919031
# 131       0  0.539320     0.845472     0.475449     0.396534     0.862617
# 166       0  0.891886     0.968693     0.909356     0.899883     0.904346
# 168       0  0.536738     0.581071     0.839167     0.630413     0.439674
#
#      pred_fold_5
# 10      0.838961
# 42      0.498974
# 76      0.703792
# 91      0.020534
# 111     0.539790
# 123     0.270113
# 128     0.654054
# 131     0.116526
# 166     0.777150
# 168     0.193367

# %% [markdown]
# # Visualize test predictions

# %%
print(f"Test predictions {len(test[test['target'] > .5])}|{len(test[test['target'] <= .5])}")
print(f"Test predictions (last) {len(test[test['target_last'] > .5])}|{len(test[test['target_last'] <= .5])}")

print('Top 10 samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last'] + 
             [c for c in test.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last'] + 
             [c for c in test.columns if (c.startswith('pred_fold'))]].query('target > .5').head(10))

print('Top 10 positive samples (last)')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last'] + 
             [c for c in test.columns if (c.startswith('pred_fold'))]].query('target_last > .5').head(10))
# Out:
# Test predictions 1506|9476
# Test predictions (last) 1172|9810
# Top 10 samples
#      image_name     sex  age_approx anatom_site_general_challenge    target  \
# 0  ISIC_0052060    male        70.0                           NaN  0.032416
# 1  ISIC_0052349    male        40.0               lower extremity  0.009875
# 2  ISIC_0058510  female        55.0                         torso  0.020250
# 3  ISIC_0073313  female        50.0                         torso  0.016615
# 4  ISIC_0073502  female        45.0               lower extremity  0.162809
# 5  ISIC_0074618    male        50.0               lower extremity  0.221927
# 6  ISIC_0076801    male        45.0               upper extremity  0.101349
# 7  ISIC_0077586    male        50.0               lower extremity  0.370923
# 8  ISIC_0082004  female        45.0                         torso  0.206577
# 9  ISIC_0082785    male        65.0               lower extremity  0.106629
#
#    target_last
# 0     0.046815
# 1     0.013604
# 2     0.027909
# 3     0.019268
# 4     0.056087
# 5     0.132984
# 6     0.035137
# 7     0.076489
# 8     0.203852
# 9     0.067161
# Top 10 positive samples
#       image_name     sex  age_approx anatom_site_general_challenge    target  \
# 22  ISIC_0105104    male        40.0                         torso  0.543415
# 24  ISIC_0112420  female        65.0                         torso  0.911082
# 42  ISIC_0155983    male        70.0                         torso  0.902253
# 56  ISIC_0169906    male        85.0                         torso  0.790530
# 57  ISIC_0171865    male        65.0                   palms/soles  0.644351
# 61  ISIC_0175798  female        55.0                         torso  0.773504
# 64  ISIC_0178235  female        70.0               lower extremity  0.846052
# 69  ISIC_0182213  female        80.0                     head/neck  0.654757
# 71  ISIC_0183449  female        60.0               lower extremity  0.874094
# 77  ISIC_0191895    male        60.0                         torso  0.619434
#
#     target_last
# 22     0.613581
# 24     0.936847
# 42     0.821034
# 56     0.613964
# 57     0.607437
# 61     0.769781
# 64     0.754007
# 69     0.562099
# 71     0.930340
# 77     0.628004
# Top 10 positive samples (last)
#       image_name     sex  age_approx anatom_site_general_challenge    target  \
# 22  ISIC_0105104    male        40.0                         torso  0.543415
# 24  ISIC_0112420  female        65.0                         torso  0.911082
# 42  ISIC_0155983    male        70.0                         torso  0.902253
# 56  ISIC_0169906    male        85.0                         torso  0.790530
# 57  ISIC_0171865    male        65.0                   palms/soles  0.644351
# 61  ISIC_0175798  female        55.0                         torso  0.773504
# 64  ISIC_0178235  female        70.0               lower extremity  0.846052
# 69  ISIC_0182213  female        80.0                     head/neck  0.654757
# 71  ISIC_0183449  female        60.0               lower extremity  0.874094
# 77  ISIC_0191895    male        60.0                         torso  0.619434
#
#     target_last
# 22     0.613581
# 24     0.936847
# 42     0.821034
# 56     0.613964
# 57     0.607437
# 61     0.769781
# 64     0.754007
# 69     0.562099
# 71     0.930340
# 77     0.628004

# %% [markdown]
# # Test set predictions

# %%
submission = pd.read_csv(database_base_path + 'sample_submission.csv')
submission['target'] = test['target']
submission['target_last'] = test['target_last']
submission['target_blend'] = (test['target'] * .5) +  (test['target_last'] * .5)
display(submission.head(10))
display(submission.describe())

### BEST ###
submission[['image_name', 'target']].to_csv('submission.csv', index=False)

### LAST ###
submission_last = submission[['image_name', 'target_last']]
submission_last.columns = ['image_name', 'target']
submission_last.to_csv('submission_last.csv', index=False)

### BLEND ###
submission_blend = submission[['image_name', 'target_blend']]
submission_blend.columns = ['image_name', 'target']
submission_blend.to_csv('submission_blend.csv', index=False)
# Out:
#      image_name    target  target_last  target_blend
# 0  ISIC_0052060  0.032416     0.046815      0.039616
# 1  ISIC_0052349  0.009875     0.013604      0.011740
# 2  ISIC_0058510  0.020250     0.027909      0.024080
# 3  ISIC_0073313  0.016615     0.019268      0.017941
# 4  ISIC_0073502  0.162809     0.056087      0.109448
# 5  ISIC_0074618  0.221927     0.132984      0.177456
# 6  ISIC_0076801  0.101349     0.035137      0.068243
# 7  ISIC_0077586  0.370923     0.076489      0.223706
# 8  ISIC_0082004  0.206577     0.203852      0.205215
# 9  ISIC_0082785  0.106629     0.067161      0.086895
#              target   target_last  target_blend
# count  10982.000000  10982.000000  10982.000000
# mean       0.206725      0.169166      0.187946
# std        0.234769      0.223248      0.225560
# min        0.003810      0.004325      0.005769
# 25%        0.025136      0.025007      0.027641
# 50%        0.108367      0.055565      0.086132
# 75%        0.305521      0.218801      0.257771
# max        0.979557      0.988068      0.980066
