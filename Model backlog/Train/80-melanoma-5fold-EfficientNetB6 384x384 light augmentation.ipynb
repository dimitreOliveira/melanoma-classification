# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#@title
# !cp -r '/content/drive/My Drive/Colab Notebooks/Melanoma/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Melanoma/'
MODEL_NAME = '80-efficientnetb6'
MODEL_BASE_PATH = f'{COLAB_BASE_PATH}Models/Files/{MODEL_NAME}/'
SUBMISSION_BASE_PATH = f'{COLAB_BASE_PATH}Submissions/'
SUBMISSION_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}.csv'
SUBMISSION_LAST_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_last.csv'
SUBMISSION_BLEND_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_blend.csv'

import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
#@title
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
#@title
import warnings, json, re, glob, math
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
import tensorflow_addons as tfa
import efficientnet.tfkeras as efn
# from classification_models.tfkeras import Classifiers

SEED = 42
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## TPU configuration

# %%
#@title
strategy, tpu = set_up_strategy()
REPLICAS = strategy.num_replicas_in_sync
print("REPLICAS: ", REPLICAS)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Running on TPU  grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# REPLICAS:  8

# %% [markdown]
# # Model parameters

# %%
#@title
config = {
  "HEIGHT": 384,
  "WIDTH": 384,
  "CHANNELS": 3,
  "BATCH_SIZE": 256,
  "EPOCHS": 12,
  "LEARNING_RATE": 0.00000125 * REPLICAS * 256,
  "ES_PATIENCE": 5,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 5,
  "TTA_STEPS": 10,
  "BASE_MODEL": 'EfficientNetB6',
  "BASE_MODEL_WEIGHTS": 'imagenet',
  "DATASET_PATH": 'melanoma-384x384'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'BASE_MODEL': 'EfficientNetB6',
#  'BASE_MODEL_WEIGHTS': 'imagenet',
#  'BATCH_SIZE': 256,
#  'CHANNELS': 3,
#  'DATASET_PATH': 'melanoma-384x384',
#  'EPOCHS': 12,
#  'ES_PATIENCE': 5,
#  'HEIGHT': 384,
#  'LEARNING_RATE': 0.00256,
#  'N_FOLDS': 5,
#  'N_USED_FOLDS': 5,
#  'TTA_STEPS': 10,
#  'WIDTH': 384}

# %% [markdown]
# # Load data

# %%
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + 'train.csv')
test = pd.read_csv(database_base_path + 'test.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())
print(f'Test samples: {len(test)}')
display(test.head())

GCS_PATH = 'gs://kds-3c0c447892078c6cb0cb069958214c9fedc65fe9efc33682fef72a3e'
TRAINING_FILENAMES = np.sort(tf.io.gfile.glob(GCS_PATH + '/train*.tfrec'))
TEST_FILENAMES = np.sort(tf.io.gfile.glob(GCS_PATH + '/test*.tfrec'))
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  ...  diagnosis benign_malignant target
# 0  ISIC_2637011  IP_7279968    male  ...    unknown           benign      0
# 1  ISIC_0015719  IP_3075186  female  ...    unknown           benign      0
# 2  ISIC_0052212  IP_2842074  female  ...      nevus           benign      0
# 3  ISIC_0068279  IP_6890425  female  ...    unknown           benign      0
# 4  ISIC_0074268  IP_8723313  female  ...    unknown           benign      0
#
# [5 rows x 8 columns]
# Test samples: 10982
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Augmentations

# %%
#@title
def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotation = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_pixel = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_cutout = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    if p_spatial >= .2:
      if p_spatial >= .6: # Flips
        image['input_image'] = data_augment_spatial(image['input_image'])
      else: # Rotate
        image['input_image'] = data_augment_rotate(image['input_image'])

    if p_crop >= .6: # Crops
      image['input_image'] = data_augment_crop(image['input_image'])

    if p_spatial2 >= .5: 
      if p_spatial2 >= .75: # Shift
        image['input_image'] = data_augment_shift(image['input_image'])
      else: # Shear
        image['input_image'] = data_augment_shear(image['input_image'])
        
    if p_pixel >= .6: # Pixel-level transforms
      if p_pixel >= .9:
        image['input_image'] = data_augment_hue(image['input_image'])
      elif p_pixel >= .8:
        image['input_image'] = data_augment_saturation(image['input_image'])
      elif p_pixel >= .7:
        image['input_image'] = data_augment_contrast(image['input_image'])
      else:
        image['input_image'] = data_augment_brightness(image['input_image'])

    if p_rotation >= .5: # Rotation
      image['input_image'] = data_augment_rotation(image['input_image'])
    
    if p_cutout >= .5: # Cutout
      image['input_image'] = data_augment_cutout(image['input_image'])
    
    return image, label

def data_augment_tta(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotation = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    if p_spatial >= .2:
      if p_spatial >= .6: # Flips
        image['input_image'] = data_augment_spatial(image['input_image'])
      else: # Rotate
        image['input_image'] = data_augment_rotate(image['input_image'])

    if p_crop >= .6: # Crops
      image['input_image'] = data_augment_crop(image['input_image'])

    if p_spatial2 >= .5: 
      if p_spatial2 >= .75: # Shift
        image['input_image'] = data_augment_shift(image['input_image'])
      else: # Shear
        image['input_image'] = data_augment_shear(image['input_image'])

    if p_rotation >= .5: # Rotation
      image['input_image'] = data_augment_rotation(image['input_image'])
    
    return image, label


def data_augment_rotation(image, max_angle=45.):
    image = transform_rotation(image, config['HEIGHT'], max_angle)
    return image

def data_augment_shift(image, h_shift=50., w_shift=50.):
    image = transform_shift(image, config['HEIGHT'], h_shift, w_shift)
    return image

def data_augment_shear(image, shear=25.):
    image = transform_shear(image, config['HEIGHT'], shear)
    return image

def data_augment_hue(image, max_delta=.02):
    image = tf.image.random_hue(image, max_delta)
    return image

def data_augment_saturation(image, lower=.8, upper=1.2):
    image = tf.image.random_saturation(image, lower, upper)
    return image

def data_augment_contrast(image, lower=.8, upper=1.2):
    image = tf.image.random_contrast(image, lower, upper)
    return image

def data_augment_brightness(image, max_delta=.1):
    image = tf.image.random_brightness(image, max_delta)
    return image

def data_augment_spatial(image):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)    
    if p_spatial > .75:
        image = tf.image.transpose(image)

    return image

def data_augment_rotate(image):
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_rotate > .66:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .33:
        image = tf.image.rot90(image, k=2) # rotate 180º
    else:
        image = tf.image.rot90(image, k=1) # rotate 90º

    return image

def data_augment_crop(image):
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_crop > .8:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.7), int(config['WIDTH']*.7), config['CHANNELS']])
    elif p_crop > .6:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']])
    elif p_crop > .4:
        image = tf.image.random_crop(image, size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']])
    elif p_crop > .2:
        image = tf.image.central_crop(image, central_fraction=.8)
    else:
        image = tf.image.central_crop(image, central_fraction=.7)
    
    image = tf.image.resize(image, size=[config['HEIGHT'], config['WIDTH']])

    return image

def data_augment_cutout(image, min_mask_size=(int(config['HEIGHT'] * .05), int(config['HEIGHT'] * .05)), 
                        max_mask_size=(int(config['HEIGHT'] * .25), int(config['HEIGHT'] * .25))):
    p_cutout = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    if p_cutout > .9: # 3 cut outs
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=3)
    elif p_cutout > .75: # 2 cut outs
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=2)
    else: # 1 cut out
        image = random_cutout(image, config['HEIGHT'], config['WIDTH'], 
                              min_mask_size=min_mask_size, max_mask_size=max_mask_size, k=1)

    return image

# %% [markdown]
# ## Auxiliary functions

# %%
#@title
# Datasets utility functions
def read_tfrecord(example, labeled=False, return_names=False, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    if labeled:
        example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
        label = tf.cast(example['target'], tf.float32)
    else:
        example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    if return_names:
        image_name = example['image_name']

    image = decode_image(example['image'], height, width, channels)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    if labeled:
        if return_names:
            return {'input_image': image, 'input_meta': data}, label, image_name
        else:
            return {'input_image': image, 'input_meta': data}, label
    else:
        if return_names:
            return {'input_image': image, 'input_meta': data}, image_name
        else:
            return {'input_image': image, 'input_meta': data}

def load_dataset(filenames, labeled=False, return_names=False, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size)
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(lambda example: read_tfrecord(example, labeled, return_names), num_parallel_calls=buffer_size)   
    return dataset

def get_dataset(filenames, labeled=True, return_names=False, ordered=False, repeated=False, augment=False, 
                batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, labeled, return_names, ordered, buffer_size)
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=buffer_size)
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# %% [markdown]
# ## Learning rate scheduler

# %%
#@title
lr_min = 1e-6
lr_start = 5e-6
lr_max = config['LEARNING_RATE']
steps_per_epoch = 24519 // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * steps_per_epoch
warmup_steps = steps_per_epoch * 5
hold_max_steps = 0
step_decay = .8
step_size = steps_per_epoch * 1

rng = [i for i in range(0, total_steps, 32)]
y = [step_schedule_with_warmup(tf.cast(x, tf.float32), step_size=step_size, 
                               warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                               lr_start=lr_start, lr_max=lr_max, step_decay=step_decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 5e-06 to 0.00256 to 0.000671

# %% [markdown]
# # Model

# %%
#@title
# Initial bias
pos = len(k_fold[k_fold['target'] == 1])
neg = len(k_fold[k_fold['target'] == 0])
initial_bias = np.log([pos/neg])
print('Bias')
print(pos)
print(neg)
print(initial_bias)

# class weights
total = len(k_fold)
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print('Class weight')
print(class_weight)
# Out:
# Bias
# 584
# 32542
# [-4.02038586]
# Class weight
# {0: 0.5089730194825148, 1: 28.36130136986301}

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB6(weights=config['BASE_MODEL_WEIGHTS'], 
                                    include_top=False)
    
    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    
    output = L.Dense(1, activation='sigmoid', name='output', 
                     bias_initializer=tf.keras.initializers.Constant(initial_bias))(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)
NUM_TRAIN_IMAGES = count_data_items(TRAINING_FILENAMES)
# Evaluation
eval_dataset = get_dataset(TRAINING_FILENAMES, labeled=False, return_names=True, ordered=True, repeated=False, augment=False, 
                           batch_size=1024, buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TRAIN_IMAGES))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, image_name: data)

# Test
test_preds = np.zeros((NUM_TEST_IMAGES, 1)); test_preds_last = np.zeros((NUM_TEST_IMAGES, 1))
test_dataset = get_dataset(TEST_FILENAMES, labeled=False, return_names=True, ordered=True, repeated=False, augment=True, 
                           batch_size=1024, buffer_size=AUTO)
image_names_test = next(iter(test_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TEST_IMAGES))).numpy().astype('U')
test_image_data = test_dataset.map(lambda data, image_name: data)

# Resample dataframe
k_fold = k_fold[k_fold['image_name'].isin(image_names)]
k_fold_best = k_fold.copy()

history_list = []
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)
for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    if n_fold < config['N_USED_FOLDS']:
        n_fold +=1
        print('\nFOLD: %d' % (n_fold))
        tf.tpu.experimental.initialize_tpu_system(tpu)
        K.clear_session()

        ### Data
        train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
        valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
        steps_per_epoch  = count_data_items(train_filenames) // config['BATCH_SIZE']

        # Train model
        model_path = f'model_fold_{n_fold}.h5'
        checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                     save_best_only=True, save_weights_only=True)

        with strategy.scope():
            model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))

            lr = lambda: step_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                   step_size=step_size, warmup_steps=warmup_steps, 
                                                   hold_max_steps=hold_max_steps, lr_start=lr_start, 
                                                   lr_max=lr_max, step_decay=step_decay)
            
            optimizer = optimizers.Adam(learning_rate=lr)
            model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                          metrics=[metrics.AUC()])
            
        history = model.fit(get_dataset(train_filenames, labeled=True, return_names=False, ordered=False, repeated=True, 
                                        augment=True, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            validation_data=get_dataset(valid_filenames, labeled=True, return_names=False, ordered=True, 
                                                        repeated=False, augment=False, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            epochs=config['EPOCHS'], 
                            steps_per_epoch=steps_per_epoch,
                            callbacks=[checkpoint],
                            verbose=2).history

        history_list.append(history)

        # Save last epoch weights
        model.save_weights((MODEL_BASE_PATH + 'last_' + model_path))

        # Get validation IDs
        valid_dataset = get_dataset(valid_filenames, labeled=False, return_names=True, ordered=True, repeated=False, 
                                    augment=False, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
        valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
        k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        k_fold_best[f'fold_{n_fold}'] = k_fold_best.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        
        ##### Last model #####
        print(f'Last model evaluation...')
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Last model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds_last += model.predict(test_image_data)

        ##### Best model #####
        print(f'Best model evaluation...')
        model.load_weights(MODEL_BASE_PATH + model_path)
        preds = model.predict(image_data)
        name_preds_eval = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold_best[f'pred_fold_{n_fold}'] = k_fold_best.apply(lambda x: name_preds_eval[x['image_name']], axis=1)

        print(f'Best model inference (TTA {config["TTA_STEPS"]} steps)...')
        for step in range(config['TTA_STEPS']):
            test_preds += model.predict(test_image_data)


# normalize preds
test_preds /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])
test_preds_last /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])

name_preds = dict(zip(image_names_test, test_preds.reshape(NUM_TEST_IMAGES)))
name_preds_last = dict(zip(image_names_test, test_preds_last.reshape(NUM_TEST_IMAGES)))

test['target'] = test.apply(lambda x: name_preds[x['image_name']], axis=1)
test['target_last'] = test.apply(lambda x: name_preds_last[x['image_name']], axis=1)
# Out:
# FOLD: 1
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527552/165527152 [==============================] - 2s 0us/step
# Epoch 1/12
# 102/102 - 162s - auc: 0.7141 - loss: 0.1735 - val_auc: 0.6463 - val_loss: 0.1788
# Epoch 2/12
# 102/102 - 131s - auc: 0.8104 - loss: 0.1689 - val_auc: 0.6611 - val_loss: 0.1738
# Epoch 3/12
# 102/102 - 124s - auc: 0.8209 - loss: 0.1673 - val_auc: 0.8189 - val_loss: 0.1744
# Epoch 4/12
# 102/102 - 124s - auc: 0.8251 - loss: 0.1682 - val_auc: 0.5454 - val_loss: 0.1857
# Epoch 5/12
# 102/102 - 124s - auc: 0.8238 - loss: 0.1689 - val_auc: 0.7934 - val_loss: 14.3072
# Epoch 6/12
# 102/102 - 130s - auc: 0.8125 - loss: 0.1681 - val_auc: 0.7749 - val_loss: 0.1704
# Epoch 7/12
# 102/102 - 131s - auc: 0.8511 - loss: 0.1659 - val_auc: 0.8444 - val_loss: 0.1680
# Epoch 8/12
# 102/102 - 125s - auc: 0.8651 - loss: 0.1647 - val_auc: 0.8505 - val_loss: 0.1687
# Epoch 9/12
# 102/102 - 130s - auc: 0.8804 - loss: 0.1611 - val_auc: 0.8741 - val_loss: 0.1665
# Epoch 10/12
# 102/102 - 130s - auc: 0.8884 - loss: 0.1618 - val_auc: 0.8934 - val_loss: 0.1635
# Epoch 11/12
# 102/102 - 130s - auc: 0.9028 - loss: 0.1604 - val_auc: 0.8932 - val_loss: 0.1635
# Epoch 12/12
# 102/102 - 130s - auc: 0.9189 - loss: 0.1570 - val_auc: 0.8865 - val_loss: 0.1632
# Last model evaluation...
# Last model inference (TTA 10 steps)...
# Best model evaluation...
# Best model inference (TTA 10 steps)...
#
# FOLD: 2
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 102/102 - 164s - auc: 0.7004 - loss: 0.1734 - val_auc: 0.5924 - val_loss: 0.1799
# Epoch 2/12
# 102/102 - 127s - auc: 0.8052 - loss: 0.1693 - val_auc: 0.7722 - val_loss: 0.1845
# Epoch 3/12
# 102/102 - 127s - auc: 0.8292 - loss: 0.1694 - val_auc: 0.6899 - val_loss: 0.2905
# Epoch 4/12
# 102/102 - 127s - auc: 0.8103 - loss: 0.1684 - val_auc: 0.3451 - val_loss: 0.7240
# Epoch 5/12
# 102/102 - 127s - auc: 0.7924 - loss: 0.1709 - val_auc: 0.7798 - val_loss: 0.7249
# Epoch 6/12
# 102/102 - 133s - auc: 0.8299 - loss: 0.1673 - val_auc: 0.8320 - val_loss: 0.1729
# Epoch 7/12
# 102/102 - 133s - auc: 0.8634 - loss: 0.1669 - val_auc: 0.8437 - val_loss: 0.1686
# Epoch 8/12
# 102/102 - 128s - auc: 0.8524 - loss: 0.1651 - val_auc: 0.8467 - val_loss: 0.1774
# Epoch 9/12
# 102/102 - 133s - auc: 0.8775 - loss: 0.1640 - val_auc: 0.8592 - val_loss: 0.1663
# Epoch 10/12
# 102/102 - 133s - auc: 0.9008 - loss: 0.1624 - val_auc: 0.8560 - val_loss: 0.1656
# Epoch 11/12
# 102/102 - 134s - auc: 0.8942 - loss: 0.1611 - val_auc: 0.8738 - val_loss: 0.1654
# Epoch 12/12
# 102/102 - 126s - auc: 0.9123 - loss: 0.1597 - val_auc: 0.8510 - val_loss: 0.1656
# Last model evaluation...
# Last model inference (TTA 10 steps)...
# Best model evaluation...
# Best model inference (TTA 10 steps)...
#
# FOLD: 3
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 102/102 - 163s - auc: 0.6967 - loss: 0.1744 - val_auc: 0.7721 - val_loss: 0.1841
# Epoch 2/12
# 102/102 - 133s - auc: 0.7980 - loss: 0.1699 - val_auc: 0.8299 - val_loss: 0.1680
# Epoch 3/12
# 102/102 - 127s - auc: 0.8342 - loss: 0.1679 - val_auc: 0.8179 - val_loss: 0.1767
# Epoch 4/12
# 102/102 - 127s - auc: 0.8050 - loss: 0.1697 - val_auc: 0.8416 - val_loss: 0.1694
# Epoch 5/12
# 102/102 - 127s - auc: 0.8219 - loss: 0.1676 - val_auc: 0.8311 - val_loss: 0.1952
# Epoch 6/12
# 102/102 - 127s - auc: 0.8176 - loss: 0.1697 - val_auc: 0.8238 - val_loss: 0.1965
# Epoch 7/12
# 102/102 - 126s - auc: 0.8431 - loss: 0.1664 - val_auc: 0.8628 - val_loss: 0.3211
# Epoch 8/12
# 102/102 - 133s - auc: 0.8723 - loss: 0.1651 - val_auc: 0.8485 - val_loss: 0.1665
# Epoch 9/12
# 102/102 - 133s - auc: 0.8784 - loss: 0.1637 - val_auc: 0.8695 - val_loss: 0.1646
# Epoch 10/12
# 102/102 - 133s - auc: 0.8921 - loss: 0.1615 - val_auc: 0.9128 - val_loss: 0.1619
# Epoch 11/12
# 102/102 - 125s - auc: 0.9089 - loss: 0.1602 - val_auc: 0.8732 - val_loss: 0.1640
# Epoch 12/12
# 102/102 - 126s - auc: 0.9015 - loss: 0.1605 - val_auc: 0.9115 - val_loss: 0.1621
# Last model evaluation...
# Last model inference (TTA 10 steps)...
# Best model evaluation...
# Best model inference (TTA 10 steps)...
#
# FOLD: 4
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 102/102 - 163s - auc: 0.6894 - loss: 0.1738 - val_auc: 0.6583 - val_loss: 0.1795
# Epoch 2/12
# 102/102 - 134s - auc: 0.8031 - loss: 0.1699 - val_auc: 0.8386 - val_loss: 0.1684
# Epoch 3/12
# 102/102 - 127s - auc: 0.8189 - loss: 0.1679 - val_auc: 0.6294 - val_loss: 0.1842
# Epoch 4/12
# 102/102 - 127s - auc: 0.8306 - loss: 0.1689 - val_auc: 0.7819 - val_loss: 9.7322
# Epoch 5/12
# 102/102 - 127s - auc: 0.8068 - loss: 0.1686 - val_auc: 0.3785 - val_loss: 0.7422
# Epoch 6/12
# 102/102 - 127s - auc: 0.8007 - loss: 0.1686 - val_auc: 0.6054 - val_loss: 0.2339
# Epoch 7/12
# 102/102 - 126s - auc: 0.8234 - loss: 0.1672 - val_auc: 0.8157 - val_loss: 0.1721
# Epoch 8/12
# 102/102 - 133s - auc: 0.8661 - loss: 0.1645 - val_auc: 0.8859 - val_loss: 0.1663
# Epoch 9/12
# 102/102 - 133s - auc: 0.8758 - loss: 0.1641 - val_auc: 0.9061 - val_loss: 0.1655
# Epoch 10/12
# 102/102 - 132s - auc: 0.8939 - loss: 0.1619 - val_auc: 0.8620 - val_loss: 0.1675
# Epoch 11/12
# 102/102 - 127s - auc: 0.8949 - loss: 0.1607 - val_auc: 0.8868 - val_loss: 0.1657
# Epoch 12/12
# 102/102 - 134s - auc: 0.9028 - loss: 0.1613 - val_auc: 0.9014 - val_loss: 0.1632
# Last model evaluation...
# Last model inference (TTA 10 steps)...
# Best model evaluation...
# Best model inference (TTA 10 steps)...
#
# FOLD: 5
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.54.186.242:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.54.186.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 102/102 - 163s - auc: 0.6914 - loss: 0.1742 - val_auc: 0.7385 - val_loss: 0.1770
# Epoch 2/12
# 102/102 - 133s - auc: 0.8192 - loss: 0.1680 - val_auc: 0.7491 - val_loss: 0.1685
# Epoch 3/12
# 102/102 - 127s - auc: 0.8134 - loss: 0.1690 - val_auc: 0.7285 - val_loss: 0.2149
# Epoch 4/12
# 102/102 - 127s - auc: 0.7922 - loss: 0.1708 - val_auc: 0.8104 - val_loss: 0.4861
# Epoch 5/12
# 102/102 - 128s - auc: 0.8279 - loss: 0.1677 - val_auc: 0.8164 - val_loss: 0.2019
# Epoch 6/12
# 102/102 - 127s - auc: 0.8050 - loss: 0.1691 - val_auc: 0.7565 - val_loss: 0.4501
# Epoch 7/12
# 102/102 - 126s - auc: 0.8683 - loss: 0.1657 - val_auc: 0.8604 - val_loss: 0.1725
# Epoch 8/12
# 102/102 - 128s - auc: 0.8718 - loss: 0.1648 - val_auc: 0.8552 - val_loss: 0.1688
# Epoch 9/12
# 102/102 - 128s - auc: 0.8885 - loss: 0.1635 - val_auc: 0.8529 - val_loss: 0.1702
# Epoch 10/12
# 102/102 - 134s - auc: 0.8919 - loss: 0.1620 - val_auc: 0.8549 - val_loss: 0.1655
# Epoch 11/12
# 102/102 - 134s - auc: 0.9141 - loss: 0.1604 - val_auc: 0.8707 - val_loss: 0.1640
# Epoch 12/12
# 102/102 - 132s - auc: 0.9259 - loss: 0.1590 - val_auc: 0.8715 - val_loss: 0.1627
# Last model evaluation...
# Last model inference (TTA 10 steps)...
# Best model evaluation...
# Best model inference (TTA 10 steps)...

# %% [markdown]
# ## Model loss graph

# %%
#@title
for n_fold in range(config['N_USED_FOLDS']):
    print(f'Fold: {n_fold + 1}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# ## Model loss graph aggregated

# %%
#@title
# plot_metrics_agg(history_list, config['N_USED_FOLDS'])

# %% [markdown]
# # Model evaluation (best)

# %%
#@title
display(evaluate_model(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col1 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col6 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col8 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col10 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row2_col12 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col0 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col1 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col3 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col4 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col5 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col6 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col7 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col8 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col9 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col10 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col11 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row3_col12 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col0 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col1 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col3 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col4 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col5 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col6 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col7 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col8 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col9 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col10 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col11 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row4_col12 {
#             color:  red;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col1 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col2 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col4 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col5 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col6 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col7 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col8 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col9 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col10 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col11 {
#             color:  green;
#         }    #T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002row5_col12 {
#             color:  green;
#         }</style><table id="T_ebd94e94_c6c7_11ea_adeb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <tr>        <
# <style  type="text/css" >
#     #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_ec46bc5e_c6c7_11ea_adeb_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (last)

# %%
#@title
display(evaluate_model(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col1 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col6 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col8 {
#             color:  orange;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col10 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row2_col12 {
#             color:  orange;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col0 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col1 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col3 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col4 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col5 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col6 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col7 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col8 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col9 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col10 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col11 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row3_col12 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col0 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col1 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col3 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col4 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col5 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col6 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col7 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col8 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col9 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col10 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col11 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row4_col12 {
#             color:  red;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col1 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col2 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col4 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col5 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col6 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col7 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col8 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col9 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col10 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col11 {
#             color:  green;
#         }    #T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002row5_col12 {
#             color:  green;
#         }</style><table id="T_ec88c5d6_c6c7_11ea_adeb_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <tr>

# %% [markdown]
# # Confusion matrix

# %%
#@title
for n_fold in range(config['N_USED_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['pred'] = 0
k_fold_best['pred'] = 0
for n_fold in range(config['N_USED_FOLDS']):
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold+1}'] / config['N_USED_FOLDS']
    k_fold_best['pred'] += k_fold_best[f'pred_fold_{n_fold+1}'] / config['N_USED_FOLDS']

k_fold['pred_best'] = k_fold_best['pred']

print('Label/prediction distribution')
print(f"Train positive labels: {len(k_fold[k_fold['target'] > .5])}")
print(f"Train positive predictions: {len(k_fold[k_fold['pred'] > .5])}")
print(f"Train positive correct predictions: {len(k_fold[(k_fold['target'] > .5) & (k_fold['pred'] > .5)])}")
    
print('Top 5 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred', 'pred_best'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(5))

print('Top 5 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred', 'pred_best'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(5))

print('Top 5 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred', 'pred_best'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred > .5').head(5))

display(k_fold.describe())

fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(20, 6))
ax1.hist(k_fold['pred'], bins=100)
ax2.hist(k_fold['pred_best'], bins=100)
ax1.set_title('Last')
ax2.set_title('Best')
plt.show()
# Out:
# Label/prediction distribution
# Train positive labels: 581
# Train positive predictions: 74
# Train positive correct predictions: 69
# Top 5 samples
#      image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 0  ISIC_2637011    male        45.0  ...    0.022788    0.026052     0.025695
# 1  ISIC_0015719  female        45.0  ...    0.023133    0.024829     0.026882
# 2  ISIC_0052212  female        50.0  ...    0.021932    0.021807     0.025294
# 3  ISIC_0068279  female        45.0  ...    0.027670    0.026911     0.024940
# 4  ISIC_0074268  female        55.0  ...    0.022072    0.023227     0.027018
#
# [5 rows x 13 columns]
# Top 5 positive samples
#        image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 91   ISIC_0149568  female        55.0  ...    0.027635    0.027163     0.038417
# 235  ISIC_0188432  female        50.0  ...    0.227749    0.453266     0.144939
# 314  ISIC_0207268    male        55.0  ...    0.065433    0.087199     0.025116
# 399  ISIC_0232101    male        65.0  ...    0.032281    0.073970     0.073662
# 459  ISIC_0247330  female        65.0  ...    0.183973    0.062741     0.108313
#
# [5 rows x 13 columns]
# Top 5 predicted positive samples
#         image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 886   ISIC_0369831    male        80.0  ...    0.248478    0.129508     0.854805
# 1332  ISIC_0502582    male        65.0  ...    0.620329    0.653253     0.203795
# 1335  ISIC_0504165  female        60.0  ...    0.603565    0.627004     0.820394
# 1423  ISIC_0528044    male        65.0  ...    0.482498    0.143956     0.918961
# 4567  ISIC_1473522  female        75.0  ...    0.611030    0.241734     0.839577
#
# [5 rows x 13 columns]
#          age_approx        target  ...          pred     pred_best
# count  32648.000000  32692.000000  ...  32692.000000  32692.000000
# mean      48.812485      0.017772  ...      0.037236      0.036536
# std       14.393434      0.132124  ...      0.046203      0.042324
# min        0.000000      0.000000  ...      0.021437      0.021152
# 25%       40.000000      0.000000  ...      0.023865      0.023722
# 50%       50.000000      0.000000  ...      0.025750      0.025543
# 75%       60.000000      0.000000  ...      0.031958      0.031779
# max       90.000000      1.000000  ...      0.944245      0.905521
#
# [8 rows x 9 columns]

# %% [markdown]
# # Visualize test predictions

# %%
#@title
print(f"Test predictions {len(test[test['target'] > .5])}|{len(test[test['target'] <= .5])}")
print(f"Test predictions (last) {len(test[test['target_last'] > .5])}|{len(test[test['target_last'] <= .5])}")

print('Top 10 samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last']
             + [c for c in test.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last']
             + [c for c in test.columns if (c.startswith('pred_fold'))]].query('target > .5').head(10))

print('Top 10 positive samples (last)')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last']
             + [c for c in test.columns if (c.startswith('pred_fold'))]].query('target_last > .5').head(10))

fig = plt.subplots(figsize=(20, 5))
plt.hist(test['target'], bins=100)
plt.show()
# Out:
# Test predictions 6|10976
# Test predictions (last) 12|10970
# Top 10 samples
#      image_name     sex  ...    target target_last
# 0  ISIC_0052060    male  ...  0.025579    0.026040
# 1  ISIC_0052349    male  ...  0.023108    0.023096
# 2  ISIC_0058510  female  ...  0.022935    0.023643
# 3  ISIC_0073313  female  ...  0.023680    0.023577
# 4  ISIC_0073502  female  ...  0.037811    0.031496
# 5  ISIC_0074618    male  ...  0.025271    0.026855
# 6  ISIC_0076801    male  ...  0.027657    0.027894
# 7  ISIC_0077586    male  ...  0.034333    0.032535
# 8  ISIC_0082004  female  ...  0.030735    0.028661
# 9  ISIC_0082785    male  ...  0.027177    0.025577
#
# [10 rows x 6 columns]
# Top 10 positive samples
#         image_name     sex  ...    target target_last
# 24    ISIC_0112420  female  ...  0.542180    0.539507
# 2739  ISIC_2560699    male  ...  0.530476    0.600687
# 3045  ISIC_2839742    male  ...  0.586395    0.718392
# 3178  ISIC_2976697  female  ...  0.518691    0.569706
# 4332  ISIC_4000026    male  ...  0.533753    0.569355
# 6058  ISIC_5541445    male  ...  0.517212    0.517593
#
# [6 rows x 6 columns]
# Top 10 positive samples (last)
#         image_name     sex  ...    target target_last
# 24    ISIC_0112420  female  ...  0.542180    0.539507
# 2116  ISIC_2002073    male  ...  0.457697    0.507873
# 2739  ISIC_2560699    male  ...  0.530476    0.600687
# 3045  ISIC_2839742    male  ...  0.586395    0.718392
# 3178  ISIC_2976697  female  ...  0.518691    0.569706
# 4332  ISIC_4000026    male  ...  0.533753    0.569355
# 6058  ISIC_5541445    male  ...  0.517212    0.517593
# 7512  ISIC_6814727    male  ...  0.462773    0.573324
# 7980  ISIC_7233451  female  ...  0.424396    0.528097
# 8863  ISIC_8059373    male  ...  0.470685    0.591807
#
# [10 rows x 6 columns]

# %% [markdown]
# # Test set predictions

# %%
#@title
submission = pd.read_csv(database_base_path + 'sample_submission.csv')
submission['target'] = test['target']
submission['target_last'] = test['target_last']
submission['target_blend'] = (test['target'] * .5) +  (test['target_last'] * .5)
display(submission.head(10))
display(submission.describe())

### BEST ###
submission[['image_name', 'target']].to_csv(SUBMISSION_PATH, index=False)

### LAST ###
submission_last = submission[['image_name', 'target_last']]
submission_last.columns = ['image_name', 'target']
submission_last.to_csv(SUBMISSION_LAST_PATH, index=False)

### BLEND ###
submission_blend = submission[['image_name', 'target_blend']]
submission_blend.columns = ['image_name', 'target']
submission_blend.to_csv(SUBMISSION_BLEND_PATH, index=False)
# Out:
#      image_name    target  target_last  target_blend
# 0  ISIC_0052060  0.025579     0.026040      0.025809
# 1  ISIC_0052349  0.023108     0.023096      0.023102
# 2  ISIC_0058510  0.022935     0.023643      0.023289
# 3  ISIC_0073313  0.023680     0.023577      0.023628
# 4  ISIC_0073502  0.037811     0.031496      0.034653
# 5  ISIC_0074618  0.025271     0.026855      0.026063
# 6  ISIC_0076801  0.027657     0.027894      0.027776
# 7  ISIC_0077586  0.034333     0.032535      0.033434
# 8  ISIC_0082004  0.030735     0.028661      0.029698
# 9  ISIC_0082785  0.027177     0.025577      0.026377
#              target   target_last  target_blend
# count  10982.000000  10982.000000  10982.000000
# mean       0.038048      0.038469      0.038258
# std        0.038970      0.042513      0.040595
# min        0.021507      0.021840      0.021674
# 25%        0.023906      0.024053      0.023986
# 50%        0.026618      0.026613      0.026615
# 75%        0.034956      0.034455      0.034715
# max        0.586395      0.718392      0.652394
