# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#@title
# !cp -r '/content/drive/My Drive/Colab Notebooks/Melanoma/Scripts/.' .

# %%
COLAB_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Melanoma/'
MODEL_NAME = '53-efficientnetb0'
MODEL_BASE_PATH = f'{COLAB_BASE_PATH}Models/Files/{MODEL_NAME}/'
SUBMISSION_BASE_PATH = f'{COLAB_BASE_PATH}Submissions/'
SUBMISSION_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}.csv'
SUBMISSION_LAST_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_last.csv'
SUBMISSION_BLEND_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_blend.csv'
SUBMISSION_TTA_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_tta.csv'
SUBMISSION_TTA_LAST_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_tta_last.csv'
SUBMISSION_TTA_BLEND_PATH = SUBMISSION_BASE_PATH + f'{MODEL_NAME}_tta_blend.csv'


import os
os.mkdir(MODEL_BASE_PATH)

# %% [markdown]
# ## Dependencies

# %%
#@title
# !pip install --quiet efficientnet
# !pip install --quiet image-classifiers

# %%
#@title
import warnings, json, re, glob, math
from scripts_step_lr_schedulers import *
from melanoma_utility_scripts import *
from sklearn.model_selection import KFold
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import optimizers, layers, metrics, losses, Model
import efficientnet.tfkeras as efn
# from classification_models.tfkeras import Classifiers
# import tensorflow_addons as tfa

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
#@title
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE

# %% [markdown]
# # Model parameters

# %%
#@title
config = {
  "HEIGHT": 256,
  "WIDTH": 256,
  "CHANNELS": 3,
  "BATCH_SIZE": 128,
  "EPOCHS": 12,
  "LEARNING_RATE": 3e-4,
  "ES_PATIENCE": 10,
  "N_FOLDS": 5,
  "N_USED_FOLDS": 5,
  "TTA_STEPS": 25,
  "BASE_MODEL": 'EfficientNetB0',
  "BASE_MODEL_WEIGHTS": 'noisy-student',
  "DATASET_PATH": 'melanoma-256x256'
}

with open(MODEL_BASE_PATH + 'config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)
    
config
# Out:
# {'BASE_MODEL': 'EfficientNetB0',
#  'BASE_MODEL_WEIGHTS': 'noisy-student',
#  'BATCH_SIZE': 128,
#  'CHANNELS': 3,
#  'DATASET_PATH': 'melanoma-256x256',
#  'EPOCHS': 12,
#  'ES_PATIENCE': 10,
#  'HEIGHT': 256,
#  'LEARNING_RATE': 0.0003,
#  'N_FOLDS': 5,
#  'N_USED_FOLDS': 5,
#  'TTA_STEPS': 25,
#  'WIDTH': 256}

# %% [markdown]
# # Load data

# %%
#@title
database_base_path = COLAB_BASE_PATH + 'Data/'
k_fold = pd.read_csv(database_base_path + 'train.csv')
test = pd.read_csv(database_base_path + 'test.csv')

print('Train samples: %d' % len(k_fold))
display(k_fold.head())
print(f'Test samples: {len(test)}')
display(test.head())

GCS_PATH = 'gs://kds-65548a4c87d02212371fce6e9bd762100c34bf9b9ebbd04b0dd4b65b'
TRAINING_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/train*.tfrec')
TEST_FILENAMES = tf.io.gfile.glob(GCS_PATH + '/test*.tfrec')
# Out:
# Train samples: 33126
#      image_name  patient_id     sex  ...  diagnosis benign_malignant target
# 0  ISIC_2637011  IP_7279968    male  ...    unknown           benign      0
# 1  ISIC_0015719  IP_3075186  female  ...    unknown           benign      0
# 2  ISIC_0052212  IP_2842074  female  ...      nevus           benign      0
# 3  ISIC_0068279  IP_6890425  female  ...    unknown           benign      0
# 4  ISIC_0074268  IP_8723313  female  ...    unknown           benign      0
#
# [5 rows x 8 columns]
# Test samples: 10982
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Augmentations

# %%
#@title
def data_augment(image, label):
    p_spatial = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_spatial2 = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_rotate = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_crop = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    p_pixel = tf.random.uniform([1], minval=0, maxval=1, dtype='float32')
    
    ### Spatial-level transforms
    if p_spatial >= .2: # flips
        image['input_image'] = tf.image.random_flip_left_right(image['input_image'])
        image['input_image'] = tf.image.random_flip_up_down(image['input_image'])
        if p_spatial >= .7:
            image['input_image'] = tf.image.transpose(image['input_image'])
            
    if p_rotate >= .8: # rotate 270º
        image['input_image'] = tf.image.rot90(image['input_image'], k=3)
    elif p_rotate >= .6: # rotate 180º
        image['input_image'] = tf.image.rot90(image['input_image'], k=2)
    elif p_rotate >= .4: # rotate 90º
        image['input_image'] = tf.image.rot90(image['input_image'], k=1)
        
    if p_spatial2 >= .6:
        if p_spatial2 >= .9:
            image['input_image'] = transform_rotation(image['input_image'], config['HEIGHT'], 180.)
        elif p_spatial2 >= .8:
            image['input_image'] = transform_zoom(image['input_image'], config['HEIGHT'], 8., 8.)
        elif p_spatial2 >= .7:
            image['input_image'] = transform_shift(image['input_image'], config['HEIGHT'], 8., 8.)
        else:
            image['input_image'] = transform_shear(image['input_image'], config['HEIGHT'], 2.)
        
    if p_crop >= .6: # crops
        if p_crop >= .8:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.8), int(config['WIDTH']*.8), config['CHANNELS']])
        elif p_crop >= .7:
            image['input_image'] = tf.image.random_crop(image['input_image'], size=[int(config['HEIGHT']*.9), int(config['WIDTH']*.9), config['CHANNELS']])
        else:
            image['input_image'] = tf.image.central_crop(image['input_image'], central_fraction=.8)
        image['input_image'] = tf.image.resize(image['input_image'], size=[config['HEIGHT'], config['WIDTH']])

    if p_pixel >= .6: # Pixel-level transforms
        if p_pixel >= .9:
            image['input_image'] = tf.image.random_hue(image['input_image'], 0.01)
        elif p_pixel >= .8:
            image['input_image'] = tf.image.random_saturation(image['input_image'], 0.7, 1.3)
        elif p_pixel >= .7:
            image['input_image'] = tf.image.random_contrast(image['input_image'], 0.8, 1.2)
        else:
            image['input_image'] = tf.image.random_brightness(image['input_image'], 0.1)

    return image, label

# %% [markdown]
# ## Auxiliary functions

# %%
#@title
# Datasets utility functions
def read_labeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label # returns a dataset of (image, data, label)

def read_labeled_tfrecord_eval(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    label = tf.cast(example['target'], tf.float32)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_meta': data}, label, image_name # returns a dataset of (image, data, label, image_name)

def load_dataset(filenames, ordered=False, buffer_size=-1):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label)

def load_dataset_eval(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_labeled_tfrecord_eval, num_parallel_calls=buffer_size)
    
    return dataset # returns a dataset of (image, data, label, image_name)

def get_training_dataset(filenames, batch_size, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=False, buffer_size=buffer_size)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.repeat() # the training dataset must repeat for several epochs
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=True) # slighly faster with fixed tensor sizes
    dataset = dataset.prefetch(buffer_size) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(filenames, ordered=True, repeated=False, batch_size=32, buffer_size=-1):
    dataset = load_dataset(filenames, ordered=ordered, buffer_size=buffer_size)
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(batch_size, drop_remainder=repeated)
    dataset = dataset.prefetch(buffer_size)
    return dataset

def get_eval_dataset(filenames, batch_size=32, buffer_size=-1):
    dataset = load_dataset_eval(filenames, buffer_size=buffer_size)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Test function
def read_unlabeled_tfrecord(example, height=config['HEIGHT'], width=config['WIDTH'], channels=config['CHANNELS']):
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'], height, width, channels)
    image_name = example['image_name']
    # meta features
    data = {}
    data['patient_id'] = tf.cast(example['patient_id'], tf.int32)
    data['sex'] = tf.cast(example['sex'], tf.int32)
    data['age_approx'] = tf.cast(example['age_approx'], tf.int32)
    data['anatom_site_general_challenge'] = tf.cast(tf.one_hot(example['anatom_site_general_challenge'], 7), tf.int32)
    
    return {'input_image': image, 'input_tabular': data}, image_name # returns a dataset of (image, data, image_name)

def load_dataset_test(filenames, buffer_size=-1):
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=buffer_size) # automatically interleaves reads from multiple files
    dataset = dataset.map(read_unlabeled_tfrecord, num_parallel_calls=buffer_size)
    # returns a dataset of (image, data, label, image_name) pairs if labeled=True or (image, data, image_name) pairs if labeled=False
    return dataset

def get_test_dataset(filenames, batch_size=32, buffer_size=-1, tta=False):
    dataset = load_dataset_test(filenames, buffer_size=buffer_size)
    if tta:
      dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(buffer_size)
    return dataset

# Advanced augmentations
def transform_rotation(image, height, rotation):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    rotation = rotation * tf.random.normal([1],dtype='float32')
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape( tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(rotation_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_shear(image, height, shear):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly sheared
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    shear = shear * tf.random.normal([1],dtype='float32')
    shear = math.pi * shear / 180.
        
    # SHEAR MATRIX
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape( tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3] )    

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shear_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_shift(image, height, h_shift, w_shift):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly shifted
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    height_shift = h_shift * tf.random.normal([1],dtype='float32') 
    width_shift = w_shift * tf.random.normal([1],dtype='float32') 
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
        
    # SHIFT MATRIX
    shift_matrix = tf.reshape( tf.concat([one,zero,height_shift, zero,one,width_shift, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shift_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_zoom(image, height, h_zoom, w_zoom):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly zoomed
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    height_zoom = 1.0 + tf.random.normal([1],dtype='float32')/h_zoom
    width_zoom = 1.0 + tf.random.normal([1],dtype='float32')/w_zoom
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
        
    # ZOOM MATRIX
    zoom_matrix = tf.reshape( tf.concat([one/height_zoom,zero,zero, zero,one/width_zoom,zero, zero,zero,one],axis=0),[3,3] )

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(zoom_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

# %% [markdown]
# ## Learning rate scheduler

# %%
#@title
lr_min = 1e-6
lr_start = 5e-6
lr_max = config['LEARNING_RATE']
steps_per_epoch = 24844 // config['BATCH_SIZE']
total_steps = config['EPOCHS'] * steps_per_epoch
warmup_steps = steps_per_epoch * 5
hold_max_steps = 0
step_decay = .8
step_size = steps_per_epoch * 1

rng = [i for i in range(0, total_steps, 32)]
y = [step_schedule_with_warmup(tf.cast(x, tf.float32), step_size=step_size, 
                               warmup_steps=warmup_steps, hold_max_steps=hold_max_steps, 
                               lr_start=lr_start, lr_max=lr_max, step_decay=step_decay) for x in rng]

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 5e-06 to 0.0003 to 7.86e-05

# %% [markdown]
# # Model

# %%
def model_fn(input_shape):
    input_image = L.Input(shape=input_shape, name='input_image')
    base_model = efn.EfficientNetB0(weights=config['BASE_MODEL_WEIGHTS'], 
                                    include_top=False)
    
    x = base_model(input_image)
    x = L.GlobalAveragePooling2D()(x)
    
    output = L.Dense(1, activation='sigmoid', name='output')(x)
    
    model = Model(inputs=input_image, outputs=output)
    
    return model

# %% [markdown]
# # Training

# %%
# Evaluation
eval_dataset = get_eval_dataset(TRAINING_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
image_names = next(iter(eval_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(TRAINING_FILENAMES)))).numpy().astype('U')
image_data = eval_dataset.map(lambda data, label, image_name: data)
# Test
test_dataset = get_test_dataset(TEST_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
test_dataset_tta = get_test_dataset(TEST_FILENAMES, batch_size=config['BATCH_SIZE'], buffer_size=AUTO, tta=True)
test_image_data = test_dataset.map(lambda data, image_name: data)
test_tta_image_data = test_dataset_tta.map(lambda data, image_name: data)

NUM_TEST_IMAGES = len(test)
test_preds = np.zeros((NUM_TEST_IMAGES, 1))
test_preds_tta = np.zeros((NUM_TEST_IMAGES, 1))
test_preds_last = np.zeros((NUM_TEST_IMAGES, 1))
test_preds_tta_last = np.zeros((NUM_TEST_IMAGES, 1))


history_list = []
k_fold_best = k_fold.copy()
kfold = KFold(config['N_FOLDS'], shuffle=True, random_state=SEED)

for n_fold, (trn_idx, val_idx) in enumerate(kfold.split(TRAINING_FILENAMES)):
    if n_fold < config['N_USED_FOLDS']:
        n_fold +=1
        print('\nFOLD: %d' % (n_fold))
        tf.tpu.experimental.initialize_tpu_system(tpu)
        K.clear_session()

        ### Data
        train_filenames = np.array(TRAINING_FILENAMES)[trn_idx]
        valid_filenames = np.array(TRAINING_FILENAMES)[val_idx]
        steps_per_epoch  = count_data_items(train_filenames) // config['BATCH_SIZE']

        # Train model
        model_path = f'model_fold_{n_fold}.h5'

        es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                           restore_best_weights=False, verbose=1)
        checkpoint = ModelCheckpoint((MODEL_BASE_PATH + model_path), monitor='val_loss', mode='min', 
                                     save_best_only=True, save_weights_only=True)

        with strategy.scope():
            model = model_fn((config['HEIGHT'], config['WIDTH'], config['CHANNELS']))

            lr = lambda: step_schedule_with_warmup(tf.cast(optimizer.iterations, tf.float32), 
                                                   step_size=step_size, warmup_steps=warmup_steps, 
                                                   hold_max_steps=hold_max_steps, lr_start=lr_start, 
                                                   lr_max=lr_max, step_decay=step_decay)
        
            optimizer = optimizers.Adam(learning_rate=lr)
            model.compile(optimizer, loss=losses.BinaryCrossentropy(label_smoothing=0.05), 
                          metrics=[metrics.AUC()])

        history = model.fit(get_training_dataset(train_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            validation_data=get_validation_dataset(valid_filenames, ordered=True, repeated=False, 
                                                                   batch_size=config['BATCH_SIZE'], buffer_size=AUTO),
                            epochs=config['EPOCHS'], 
                            steps_per_epoch=steps_per_epoch ,
                            callbacks=[checkpoint, es], 
                            verbose=2).history

        # save last epoch weights
        model.save_weights((MODEL_BASE_PATH + 'last_' + model_path))

        history_list.append(history)

        # Get validation IDs
        valid_dataset = get_eval_dataset(valid_filenames, batch_size=config['BATCH_SIZE'], buffer_size=AUTO)
        valid_image_names = next(iter(valid_dataset.unbatch().map(lambda data, label, image_name: image_name).batch(count_data_items(valid_filenames)))).numpy().astype('U')
        k_fold[f'fold_{n_fold}'] = k_fold.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        k_fold_best[f'fold_{n_fold}'] = k_fold_best.apply(lambda x: 'validation' if x['image_name'] in valid_image_names else 'train', axis=1)
        
        ##### Last model #####
        print('Last model evaluation...')
        preds = model.predict(image_data)
        name_preds = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold[f'pred_fold_{n_fold}'] = k_fold.apply(lambda x: name_preds[x['image_name']], axis=1)

        print('Last model inference...')
        test_preds_last += model.predict(test_image_data)

        # TTA preds
        print(f'Running TTA (last) {config["TTA_STEPS"]} steps...')
        for step in range(config['TTA_STEPS']):
            test_preds_tta_last += model.predict(test_tta_image_data)

        ##### Best model #####
        print('Best model evaluation...')
        model.load_weights(MODEL_BASE_PATH + model_path)
        preds = model.predict(image_data)
        name_preds = dict(zip(image_names, preds.reshape(len(preds))))
        k_fold_best[f'pred_fold_{n_fold}'] = k_fold_best.apply(lambda x: name_preds[x['image_name']], axis=1)

        print('Best model inference...')
        test_preds += model.predict(test_image_data)

        # TTA preds
        print(f'Running TTA (best) {config["TTA_STEPS"]} steps...')
        for step in range(config['TTA_STEPS']):
            test_preds_tta += model.predict(test_tta_image_data)


# normalize preds
test_preds /= config['N_USED_FOLDS']
test_preds_tta /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])
test_preds_last /= config['N_USED_FOLDS']
test_preds_tta_last /= (config['N_USED_FOLDS'] * config['TTA_STEPS'])

image_names_test = next(iter(test_dataset.unbatch().map(lambda data, image_name: image_name).batch(NUM_TEST_IMAGES))).numpy().astype('U')

name_preds = dict(zip(image_names_test, test_preds.reshape(NUM_TEST_IMAGES)))
name_preds_tta = dict(zip(image_names_test, test_preds_tta.reshape(NUM_TEST_IMAGES)))
name_preds_last = dict(zip(image_names_test, test_preds_last.reshape(NUM_TEST_IMAGES)))
name_preds_tta_last = dict(zip(image_names_test, test_preds_tta_last.reshape(NUM_TEST_IMAGES)))

test['target'] = test.apply(lambda x: name_preds[x['image_name']], axis=1)
test['target_tta'] = test.apply(lambda x: name_preds_tta[x['image_name']], axis=1)
test['target_last'] = test.apply(lambda x: name_preds_last[x['image_name']], axis=1)
test['target_tta_last'] = test.apply(lambda x: name_preds_tta_last[x['image_name']], axis=1)
# Out:
# FOLD: 1
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b0_noisy-student_notop.h5
# 16703488/16696600 [==============================] - 0s 0us/step
# Epoch 1/12
# 194/194 - 37s - loss: 0.3770 - auc: 0.5566 - val_loss: 0.1961 - val_auc: 0.6068
# Epoch 2/12
# 194/194 - 25s - loss: 0.1700 - auc: 0.8152 - val_loss: 0.1658 - val_auc: 0.8631
# Epoch 3/12
# 194/194 - 25s - loss: 0.1658 - auc: 0.8531 - val_loss: 0.1643 - val_auc: 0.8700
# Epoch 4/12
# 194/194 - 25s - loss: 0.1659 - auc: 0.8629 - val_loss: 0.1636 - val_auc: 0.8777
# Epoch 5/12
# 194/194 - 23s - loss: 0.1649 - auc: 0.8773 - val_loss: 0.1686 - val_auc: 0.8131
# Epoch 6/12
# 194/194 - 23s - loss: 0.1645 - auc: 0.8837 - val_loss: 0.1664 - val_auc: 0.8727
# Epoch 7/12
# 194/194 - 25s - loss: 0.1604 - auc: 0.8944 - val_loss: 0.1634 - val_auc: 0.8646
# Epoch 8/12
# 194/194 - 25s - loss: 0.1583 - auc: 0.9217 - val_loss: 0.1627 - val_auc: 0.8596
# Epoch 9/12
# 194/194 - 23s - loss: 0.1559 - auc: 0.9320 - val_loss: 0.1658 - val_auc: 0.8123
# Epoch 10/12
# 194/194 - 23s - loss: 0.1526 - auc: 0.9357 - val_loss: 0.1682 - val_auc: 0.8753
# Epoch 11/12
# 194/194 - 23s - loss: 0.1500 - auc: 0.9548 - val_loss: 0.1656 - val_auc: 0.8608
# Epoch 12/12
# 194/194 - 23s - loss: 0.1494 - auc: 0.9452 - val_loss: 0.1689 - val_auc: 0.8653
# Last model evaluation...
# Last model inference...
# Running TTA (last) 25 steps...
# Best model evaluation...
# Best model inference...
# Running TTA (best) 25 steps...
#
# FOLD: 2
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 210/210 - 40s - loss: 0.3223 - auc: 0.5673 - val_loss: 0.1797 - val_auc: 0.6439
# Epoch 2/12
# 210/210 - 26s - loss: 0.1688 - auc: 0.8239 - val_loss: 0.1652 - val_auc: 0.8644
# Epoch 3/12
# 210/210 - 25s - loss: 0.1655 - auc: 0.8557 - val_loss: 0.1661 - val_auc: 0.8525
# Epoch 4/12
# 210/210 - 24s - loss: 0.1666 - auc: 0.8535 - val_loss: 0.1676 - val_auc: 0.8411
# Epoch 5/12
# 210/210 - 27s - loss: 0.1653 - auc: 0.8713 - val_loss: 0.1645 - val_auc: 0.8465
# Epoch 6/12
# 210/210 - 26s - loss: 0.1623 - auc: 0.8886 - val_loss: 0.1631 - val_auc: 0.8755
# Epoch 7/12
# 210/210 - 27s - loss: 0.1601 - auc: 0.9118 - val_loss: 0.1606 - val_auc: 0.8834
# Epoch 8/12
# 210/210 - 27s - loss: 0.1574 - auc: 0.9218 - val_loss: 0.1599 - val_auc: 0.8654
# Epoch 9/12
# 210/210 - 25s - loss: 0.1557 - auc: 0.9348 - val_loss: 0.1614 - val_auc: 0.8491
# Epoch 10/12
# 210/210 - 25s - loss: 0.1523 - auc: 0.9447 - val_loss: 0.1613 - val_auc: 0.8574
# Epoch 11/12
# 210/210 - 24s - loss: 0.1500 - auc: 0.9487 - val_loss: 0.1608 - val_auc: 0.8641
# Epoch 12/12
# 210/210 - 25s - loss: 0.1481 - auc: 0.9539 - val_loss: 0.1624 - val_auc: 0.8502
# Last model evaluation...
# Last model inference...
# Running TTA (last) 25 steps...
# Best model evaluation...
# Best model inference...
# Running TTA (best) 25 steps...
#
# FOLD: 3
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 210/210 - 40s - loss: 0.3396 - auc: 0.5611 - val_loss: 0.1919 - val_auc: 0.5781
# Epoch 2/12
# 210/210 - 27s - loss: 0.1691 - auc: 0.8172 - val_loss: 0.1679 - val_auc: 0.8605
# Epoch 3/12
# 210/210 - 25s - loss: 0.1662 - auc: 0.8500 - val_loss: 0.1690 - val_auc: 0.8423
# Epoch 4/12
# 210/210 - 27s - loss: 0.1656 - auc: 0.8508 - val_loss: 0.1666 - val_auc: 0.8507
# Epoch 5/12
# 210/210 - 27s - loss: 0.1638 - auc: 0.8819 - val_loss: 0.1660 - val_auc: 0.8677
# Epoch 6/12
# 210/210 - 26s - loss: 0.1625 - auc: 0.8932 - val_loss: 0.1649 - val_auc: 0.8438
# Epoch 7/12
# 210/210 - 27s - loss: 0.1591 - auc: 0.9098 - val_loss: 0.1647 - val_auc: 0.8383
# Epoch 8/12
# 210/210 - 27s - loss: 0.1575 - auc: 0.9223 - val_loss: 0.1620 - val_auc: 0.8608
# Epoch 9/12
# 210/210 - 26s - loss: 0.1545 - auc: 0.9365 - val_loss: 0.1614 - val_auc: 0.8733
# Epoch 10/12
# 210/210 - 25s - loss: 0.1535 - auc: 0.9440 - val_loss: 0.1623 - val_auc: 0.8809
# Epoch 11/12
# 210/210 - 25s - loss: 0.1492 - auc: 0.9594 - val_loss: 0.1628 - val_auc: 0.8421
# Epoch 12/12
# 210/210 - 25s - loss: 0.1486 - auc: 0.9604 - val_loss: 0.1639 - val_auc: 0.8500
# Last model evaluation...
# Last model inference...
# Running TTA (last) 25 steps...
# Best model evaluation...
# Best model inference...
# Running TTA (best) 25 steps...
#
# FOLD: 4
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 210/210 - 38s - loss: 0.3207 - auc: 0.5714 - val_loss: 0.1843 - val_auc: 0.6144
# Epoch 2/12
# 210/210 - 27s - loss: 0.1688 - auc: 0.8100 - val_loss: 0.1687 - val_auc: 0.8329
# Epoch 3/12
# 210/210 - 25s - loss: 0.1658 - auc: 0.8485 - val_loss: 0.1688 - val_auc: 0.8477
# Epoch 4/12
# 210/210 - 25s - loss: 0.1660 - auc: 0.8556 - val_loss: 0.1703 - val_auc: 0.8615
# Epoch 5/12
# 210/210 - 25s - loss: 0.1627 - auc: 0.8761 - val_loss: 0.1706 - val_auc: 0.7952
# Epoch 6/12
# 210/210 - 27s - loss: 0.1625 - auc: 0.8956 - val_loss: 0.1659 - val_auc: 0.8285
# Epoch 7/12
# 210/210 - 34s - loss: 0.1594 - auc: 0.9139 - val_loss: 0.1654 - val_auc: 0.8563
# Epoch 8/12
# 210/210 - 25s - loss: 0.1569 - auc: 0.9239 - val_loss: 0.1662 - val_auc: 0.8575
# Epoch 9/12
# 210/210 - 25s - loss: 0.1538 - auc: 0.9384 - val_loss: 0.1658 - val_auc: 0.8441
# Epoch 10/12
# 210/210 - 25s - loss: 0.1508 - auc: 0.9526 - val_loss: 0.1663 - val_auc: 0.8224
# Epoch 11/12
# 210/210 - 25s - loss: 0.1498 - auc: 0.9524 - val_loss: 0.1655 - val_auc: 0.8082
# Epoch 12/12
# 210/210 - 25s - loss: 0.1464 - auc: 0.9627 - val_loss: 0.1679 - val_auc: 0.8002
# Last model evaluation...
# Last model inference...
# Running TTA (last) 25 steps...
# Best model evaluation...
# Best model inference...
# Running TTA (best) 25 steps...
#
# FOLD: 5
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.121.161.10:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.121.161.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# Epoch 1/12
# 210/210 - 39s - loss: 0.3175 - auc: 0.5771 - val_loss: 0.1829 - val_auc: 0.6222
# Epoch 2/12
# 210/210 - 27s - loss: 0.1686 - auc: 0.8219 - val_loss: 0.1657 - val_auc: 0.8506
# Epoch 3/12
# 210/210 - 27s - loss: 0.1670 - auc: 0.8564 - val_loss: 0.1642 - val_auc: 0.8771
# Epoch 4/12
# 210/210 - 27s - loss: 0.1663 - auc: 0.8519 - val_loss: 0.1634 - val_auc: 0.8845
# Epoch 5/12
# 210/210 - 25s - loss: 0.1643 - auc: 0.8762 - val_loss: 0.1661 - val_auc: 0.8415
# Epoch 6/12
# 210/210 - 27s - loss: 0.1633 - auc: 0.8877 - val_loss: 0.1634 - val_auc: 0.8941
# Epoch 7/12
# 210/210 - 27s - loss: 0.1612 - auc: 0.8967 - val_loss: 0.1608 - val_auc: 0.8693
# Epoch 8/12
# 210/210 - 25s - loss: 0.1575 - auc: 0.9172 - val_loss: 0.1627 - val_auc: 0.8734
# Epoch 9/12
# 210/210 - 26s - loss: 0.1561 - auc: 0.9305 - val_loss: 0.1601 - val_auc: 0.8927
# Epoch 10/12
# 210/210 - 25s - loss: 0.1530 - auc: 0.9502 - val_loss: 0.1607 - val_auc: 0.8498
# Epoch 11/12
# 210/210 - 25s - loss: 0.1503 - auc: 0.9501 - val_loss: 0.1612 - val_auc: 0.8580
# Epoch 12/12
# 210/210 - 25s - loss: 0.1482 - auc: 0.9603 - val_loss: 0.1614 - val_auc: 0.8549
# Last model evaluation...
# Last model inference...
# Running TTA (last) 25 steps...
# Best model evaluation...
# Best model inference...
# Running TTA (best) 25 steps...

# %% [markdown]
# ## Model loss graph

# %%
#@title
for n_fold in range(config['N_USED_FOLDS']):
    print(f'Fold: {n_fold + 1}')
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# ## Model loss graph aggregated

# %%
#@title
plot_metrics_agg(history_list, config['N_USED_FOLDS'])

# %% [markdown]
# # Model evaluation

# %%
#@title
display(evaluate_model(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col11 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col0 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col3 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col7 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col9 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col1 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col4 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col6 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col8 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col10 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row2_col12 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col1 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col4 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col5 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col6 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col8 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col9 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col10 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col11 {
#             color:  orange;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row3_col12 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col1 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col4 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col6 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col8 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col10 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row4_col12 {
#             color:  red;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col1 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col2 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col4 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col5 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col6 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col7 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col8 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col9 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col10 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col11 {
#             color:  green;
#         }    #T_36f105be_c2ab_11ea_ae9b_0242ac1c0002row5_col12 {
#             color:  green;
#         }</style><table id="T_36f105be_c2ab_11ea_ae9b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fol

# %% [markdown]
# # Model evaluation by Subset

# %%
#@title
display(evaluate_model_Subset(k_fold, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col5 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col9 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col5 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col11 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col7 {
#             color:  green;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_3765bc56_c2ab_11ea_ae9b_0242ac1c0002row6_col9

# %% [markdown]
# # Model evaluation (best)

# %%
#@title
display(evaluate_model(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
display(evaluate_model_Subset(k_fold_best, config['N_USED_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col1 {
#             color:  orange;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col4 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col8 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col10 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row2_col12 {
#             color:  orange;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col0 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col1 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col3 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col4 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col5 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col6 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col7 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col8 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col9 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col10 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col11 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row3_col12 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col0 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col1 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col3 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col4 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col5 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col6 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col7 {
#             color:  orange;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col8 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col9 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col10 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col11 {
#             color:  orange;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row4_col12 {
#             color:  red;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col0 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col1 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col2 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col3 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col4 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col5 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col6 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col7 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col8 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col9 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col10 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col11 {
#             color:  green;
#         }    #T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002row5_col12 {
#             color:  green;
#         }</style><table id="T_37b247f6_c2ab_11ea_ae9b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train_fold_5</th>        <th class="col_heading level0 col12" >Valid_fold_5</th>    </tr>    <
# <style  type="text/css" >
#     #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col2 {
#             color:  red;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col3 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col4 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col5 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col6 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col7 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col8 {
#             color:  black;
#         }    #T_38203f36_c2ab_11ea_ae9b_0242ac1c0002row6_col9

# %% [markdown]
# # Confusion matrix

# %%
#@title
for n_fold in range(config['N_USED_FOLDS']):
    n_fold += 1
    pred_col = f'pred_fold_{n_fold}' 
    train_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'train']
    valid_set = k_fold_best[k_fold_best[f'fold_{n_fold}'] == 'validation'] 
    print(f'Fold: {n_fold}')
    plot_confusion_matrix(train_set['target'], np.round(train_set[pred_col]),
                          valid_set['target'], np.round(valid_set[pred_col]))
# Out:
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5

# %% [markdown]
# # Visualize predictions

# %%
#@title
k_fold['pred'] = 0
for n_fold in range(config['N_USED_FOLDS']):
    k_fold['pred'] += k_fold[f'pred_fold_{n_fold+1}'] / config['N_FOLDS']

print('Label/prediction distribution')
print(f"Train positive labels: {len(k_fold[k_fold['target'] > .5])}")
print(f"Train positive predictions: {len(k_fold[k_fold['pred'] > .5])}")
print(f"Train positive correct predictions: {len(k_fold[(k_fold['target'] > .5) & (k_fold['pred'] > .5)])}")
    
print('Top 10 samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('target == 1').head(10))


print('Top 10 predicted positive samples')
display(k_fold[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'diagnosis',
                'target', 'pred'] + [c for c in k_fold.columns if (c.startswith('pred_fold'))]].query('pred > .5').head(10))
# Out:
# Label/prediction distribution
# Train positive labels: 584
# Train positive predictions: 353
# Train positive correct predictions: 325
# Top 10 samples
#      image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 0  ISIC_2637011    male        45.0  ...    0.014658    0.049973     0.025434
# 1  ISIC_0015719  female        45.0  ...    0.029603    0.025393     0.024023
# 2  ISIC_0052212  female        50.0  ...    0.021513    0.014591     0.023128
# 3  ISIC_0068279  female        45.0  ...    0.025559    0.041154     0.029881
# 4  ISIC_0074268  female        55.0  ...    0.020048    0.019657     0.026842
# 5  ISIC_0074311  female        40.0  ...    0.023617    0.033254     0.024258
# 6  ISIC_0074542    male        25.0  ...    0.023246    0.027002     0.016857
# 7  ISIC_0075663  female        35.0  ...    0.031182    0.005798     0.026813
# 8  ISIC_0075914    male        30.0  ...    0.020855    0.015906     0.017768
# 9  ISIC_0076262  female        50.0  ...    0.030071    0.027371     0.027377
#
# [10 rows x 12 columns]
# Top 10 positive samples
#        image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 91   ISIC_0149568  female        55.0  ...    0.102189    0.038424     0.880184
# 235  ISIC_0188432  female        50.0  ...    0.756162    0.938701     0.706194
# 314  ISIC_0207268    male        55.0  ...    0.120007    0.943783     0.762574
# 399  ISIC_0232101    male        65.0  ...    0.259445    0.129433     0.118054
# 459  ISIC_0247330  female        65.0  ...    0.073840    0.816019     0.961588
# 475  ISIC_0250839    male        75.0  ...    0.617207    0.484757     0.928312
# 544  ISIC_0272509  female        35.0  ...    0.887224    0.435093     0.564865
# 546  ISIC_0273046    male        80.0  ...    0.745791    0.664199     0.900532
# 551  ISIC_0274382    male        65.0  ...    0.798779    0.138304     0.426231
# 558  ISIC_0275828    male        30.0  ...    0.021362    0.152578     0.154084
#
# [10 rows x 12 columns]
# Top 10 predicted positive samples
#        image_name     sex  age_approx  ... pred_fold_3 pred_fold_4  pred_fold_5
# 235  ISIC_0188432  female        50.0  ...    0.756162    0.938701     0.706194
# 314  ISIC_0207268    male        55.0  ...    0.120007    0.943783     0.762574
# 459  ISIC_0247330  female        65.0  ...    0.073840    0.816019     0.961588
# 475  ISIC_0250839    male        75.0  ...    0.617207    0.484757     0.928312
# 544  ISIC_0272509  female        35.0  ...    0.887224    0.435093     0.564865
# 546  ISIC_0273046    male        80.0  ...    0.745791    0.664199     0.900532
# 580  ISIC_0280912    male        70.0  ...    0.623689    0.906259     0.974311
# 707  ISIC_0314462    male        80.0  ...    0.400594    0.615707     0.650761
# 758  ISIC_0333091    male        25.0  ...    0.950700    0.976299     0.994162
# 826  ISIC_0351666    male        80.0  ...    0.898401    0.555035     0.648564
#
# [10 rows x 12 columns]

# %% [markdown]
# # Visualize test predictions

# %%
#@title
print(f"Test predictions {len(test[test['target'] > .5])}|{len(test[test['target'] <= .5])}")
print(f"Test predictions (last) {len(test[test['target_last'] > .5])}|{len(test[test['target_last'] <= .5])}")
print(f"Test predictions (tta) {len(test[test['target_tta'] > .5])}|{len(test[test['target_tta'] <= .5])}")
print(f"Test predictions (last tta) {len(test[test['target_tta_last'] > .5])}|{len(test[test['target_tta_last'] <= .5])}")

print('Top 10 samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last', 
              'target_tta', 'target_tta_last'] + [c for c in test.columns if (c.startswith('pred_fold'))]].head(10))

print('Top 10 positive samples')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last', 
              'target_tta', 'target_tta_last'] + [c for c in test.columns if (c.startswith('pred_fold'))]].query('target > .5').head(10))

print('Top 10 positive samples (last)')
display(test[['image_name', 'sex', 'age_approx','anatom_site_general_challenge', 'target', 'target_last', 
              'target_tta', 'target_tta_last'] + [c for c in test.columns if (c.startswith('pred_fold'))]].query('target_last > .5').head(10))
# Out:
# Test predictions 24|10958
# Test predictions (last) 66|10916
# Test predictions (tta) 17|10965
# Test predictions (last tta) 51|10931
# Top 10 samples
#      image_name     sex  age_approx  ... target_last  target_tta  target_tta_last
# 0  ISIC_0052060    male        70.0  ...    0.021196    0.023803         0.021385
# 1  ISIC_0052349    male        40.0  ...    0.027608    0.023193         0.026012
# 2  ISIC_0058510  female        55.0  ...    0.025617    0.024525         0.025287
# 3  ISIC_0073313  female        50.0  ...    0.024019    0.023643         0.023588
# 4  ISIC_0073502  female        45.0  ...    0.027548    0.032271         0.030608
# 5  ISIC_0074618    male        50.0  ...    0.025843    0.027651         0.024525
# 6  ISIC_0076801    male        45.0  ...    0.024023    0.031006         0.031213
# 7  ISIC_0077586    male        50.0  ...    0.050206    0.040215         0.045975
# 8  ISIC_0082004  female        45.0  ...    0.024339    0.030490         0.025968
# 9  ISIC_0082785    male        65.0  ...    0.025280    0.026910         0.025332
#
# [10 rows x 8 columns]
# Top 10 positive samples
#         image_name     sex  ...  target_tta target_tta_last
# 403   ISIC_0481105    male  ...    0.583234        0.937133
# 471   ISIC_0539432  female  ...    0.281013        0.439926
# 943   ISIC_0936377    male  ...    0.534332        0.717815
# 1408  ISIC_1364884  female  ...    0.471240        0.404827
# 1677  ISIC_1593714  female  ...    0.715256        0.903394
# 2116  ISIC_2002073    male  ...    0.501348        0.536436
# 2195  ISIC_2078598    male  ...    0.615745        0.780961
# 2646  ISIC_2481946  female  ...    0.244893        0.362060
# 2739  ISIC_2560699    male  ...    0.670702        0.914910
# 3045  ISIC_2839742    male  ...    0.774772        0.986844
#
# [10 rows x 8 columns]
# Top 10 positive samples (last)
#         image_name     sex  ...  target_tta target_tta_last
# 42    ISIC_0155983    male  ...    0.299493        0.400872
# 109   ISIC_0216447    male  ...    0.472276        0.845261
# 403   ISIC_0481105    male  ...    0.583234        0.937133
# 522   ISIC_0585534    male  ...    0.237485        0.436258
# 533   ISIC_0591142    male  ...    0.158272        0.147376
# 552   ISIC_0606244    male  ...    0.372965        0.513639
# 764   ISIC_0775584  female  ...    0.141135        0.269605
# 943   ISIC_0936377    male  ...    0.534332        0.717815
# 951   ISIC_0945202    male  ...    0.292085        0.393596
# 1250  ISIC_1212424    male  ...    0.334857        0.474273
#
# [10 rows x 8 columns]

# %% [markdown]
# # Test set predictions

# %%
#@title
submission = pd.read_csv(database_base_path + 'sample_submission.csv')
submission['target'] = test['target']
submission['target_last'] = test['target_last']
submission['target_blend'] = (test['target'] * .5) +  (test['target_last'] * .5)
submission['target_tta'] = test['target_tta']
submission['target_tta_last'] = test['target_tta_last']
submission['target_tta_blend'] = (test['target_tta'] * .5) +  (test['target_tta_last'] * .5)
display(submission.head(10))
display(submission.describe())

### BEST ###
submission[['image_name', 'target']].to_csv(SUBMISSION_PATH, index=False)

### LAST ###
submission_last = submission[['image_name', 'target_last']]
submission_last.columns = ['image_name', 'target']
submission_last.to_csv(SUBMISSION_LAST_PATH, index=False)

### BLEND ###
submission_blend = submission[['image_name', 'target_blend']]
submission_blend.columns = ['image_name', 'target']
submission_blend.to_csv(SUBMISSION_BLEND_PATH, index=False)

### TTA ###
submission_tta = submission[['image_name', 'target_tta']]
submission_tta.columns = ['image_name', 'target']
submission_tta.to_csv(SUBMISSION_TTA_PATH, index=False)

### TTA LAST ###
submission_tta_last = submission[['image_name', 'target_tta_last']]
submission_tta_last.columns = ['image_name', 'target']
submission_tta_last.to_csv(SUBMISSION_TTA_LAST_PATH, index=False)

### TTA BLEND ###
submission_blend_tta = submission[['image_name', 'target_tta_blend']]
submission_blend_tta.columns = ['image_name', 'target']
submission_blend_tta.to_csv(SUBMISSION_TTA_BLEND_PATH, index=False)
# Out:
#      image_name    target  ...  target_tta_last  target_tta_blend
# 0  ISIC_0052060  0.022448  ...         0.021385          0.022594
# 1  ISIC_0052349  0.025480  ...         0.026012          0.024602
# 2  ISIC_0058510  0.025874  ...         0.025287          0.024906
# 3  ISIC_0073313  0.024172  ...         0.023588          0.023615
# 4  ISIC_0073502  0.028754  ...         0.030608          0.031440
# 5  ISIC_0074618  0.028089  ...         0.024525          0.026088
# 6  ISIC_0076801  0.021116  ...         0.031213          0.031110
# 7  ISIC_0077586  0.038148  ...         0.045975          0.043095
# 8  ISIC_0082004  0.029594  ...         0.025968          0.028229
# 9  ISIC_0082785  0.027704  ...         0.025332          0.026121
#
# [10 rows x 7 columns]
#              target   target_last  ...  target_tta_last  target_tta_blend
# count  10982.000000  10982.000000  ...     10982.000000      10982.000000
# mean       0.041973      0.043545  ...         0.043050          0.042577
# std        0.049651      0.068300  ...         0.062723          0.053840
# min        0.012978      0.013027  ...         0.014002          0.014419
# 25%        0.024359      0.023335  ...         0.024062          0.024616
# 50%        0.028528      0.026862  ...         0.027446          0.028231
# 75%        0.038503      0.035472  ...         0.035662          0.037575
# max        0.756106      0.984135  ...         0.986844          0.880808
#
# [8 rows x 6 columns]
